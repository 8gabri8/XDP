# %% [markdown]
# # Goal
# This notebook will show how to map data using the MapMyCells data products released with the HMBA consensus Basal Ganglia taxonomy.
#
# [Original Notebook here](https://github.com/AllenInstitute/HMBA_BasalGanglia_Consensus_Taxonomy/blob/main/examples/using_MapMyCells_data.ipynb)
#
# # Install MapMyCell dependencies
# We are going to start by installing the `cell_type_mapper` (actual backend for MapMyCells) and `abc_atlas_access` (convenient download of other data provided by the AllenInstitute) libraries.
# ```bash
# uv add "cell_type_mapper@git+https://github.com/alleninstitute/cell_type_mapper.git@rc/v1.5.2"
# uv add "abc_atlas_access[notebooks] @ git+https://github.com/alleninstitute/abc_atlas_access.git"
# ```

# %% [markdown]
# # Dowload mapping files for basal ganglia
#
# To run MapMyCells, you need two supporting data files:
# - [an HDF5 file](https://github.com/AllenInstitute/cell_type_mapper/blob/main/docs/input_data_files/precomputed_stats_file.md) which defines your taxonomy and the average gene expression profiles of the taxons there in
# - [lookup table of marker genes](https://github.com/AllenInstitute/cell_type_mapper/blob/main/docs/input_data_files/marker_gene_lookup.md) for your taxonomy.
#
# Let's download those two files for the **human** basal ganglia data.
# Refer back [to the main page](https://github.com/AllenInstitute/HMBA_BasalGanglia_Consensus_Taxonomy/blob/main/index.md#cell-type-mapping-with-mapmycells) for the locations of the relevant files for all three species (human, marmoset, and macaque).
#
# ```bash
# wget https://released-taxonomies-802451596237-us-west-2.s3.us-west-2.amazonaws.com/HMBA/BasalGanglia/BICAN_05072025_pre-print_release/MapMyCells/Human.precomputed_stats.20250507.h5
# wget https://released-taxonomies-802451596237-us-west-2.s3.us-west-2.amazonaws.com/HMBA/BasalGanglia/BICAN_05072025_pre-print_release/MapMyCells/Human.query_markers.20250507.json
# ```

# %% [markdown]
# ---

# %%
import json
import matplotlib.pyplot as plt
import pandas as pd
import scanpy as sc
from pathlib import Path
import os
from dotenv import load_dotenv; load_dotenv()

# MUST BE FIRST - before any imports from cell_type_mapper --> error if FromSpecifiedMarkersRunner run wiht GPU
os.environ['CUDA_VISIBLE_DEVICES'] = ''

import cell_type_mapper
from abc_atlas_access.abc_atlas_cache.abc_project_cache import AbcProjectCache
from cell_type_mapper.cli.from_specified_markers import FromSpecifiedMarkersRunner

# %%
# Hyperparamyters
BASE_PATH = os.getenv("BASE_PATH_FOR_SAVING")
SAMPLE_ID = "sample_03"
BCL = "260313_SL-EXA_0758_B23GHNHLT4"#"251027_SL-EXD_0706_A233KGFLT4", "FAKE_BCL", "260313_SL-EXA_0758_B23GHNHLT4"
LIBRARY = "SI-TT-C5"#"SI-TT-H3"

# %%
print(f"BASE_PATH: {BASE_PATH}")
print(f"SAMPLE_ID: {SAMPLE_ID}")
print(f"BCL: {BCL}")
print(f"LIBRARY: {LIBRARY}")

# %% [markdown]
# # Prepare Query data
#
# Your query data must be:
# - **Format**: `.h5ad` file (AnnData format)
# - **Structure**:
#   - `X` layer with **RAW** gene expression data (cells × genes)
#   - `obs` with cell metadata
#   - `var` with gene names, **Ensembl IDs** for MapMyCells-supported taxonomies

# %%
# FIXED (always mappign againf basal ganglia)
query_marker_path = os.getenv("ALLEN_ATLAS_BG_MMC_MARKER_JSON") # the lookup table of marker genes which we downloaded from S3
precomputed_path = os.getenv("ALLEN_ATLAS_BG_MMC_STAT_H5") # the human-specific precomputed stats file which we downloaded from S3

# %%
QUERY_PATH = f"{BASE_PATH}/SlideTags_single_libraries/{SAMPLE_ID}/{BCL}/{LIBRARY}/adata/raw_adata.h5ad"

# paths to files where mapping output will be written
json_dst_path = str(Path(QUERY_PATH).parent.parent / "map_my_cell" / "mapping.json")
csv_dst_path = str(Path(QUERY_PATH).parent.parent / "map_my_cell" / "mapping.csv")

# saving adata path
adata_labelled_path = str(Path(QUERY_PATH).parent / "labelled_adata.h5ad")

# %%
# # ONLY IF YOU WANT TO SPECIFIY

# if True:
#     QUERY_PATH = f"/home/gdallagl/myworkdir/XDP/data/XDP/NucSec/original_data/NucSeq_all.h5ad"

#     # paths to files where mapping output will be written
#     json_dst_path = f"{os.path.split(QUERY_PATH)[0]}/map_my_cell/mapping.json"
#     csv_dst_path = f"{os.path.split(QUERY_PATH)[0]}/map_my_cell/mapping.csv"
#     os.makedirs(f"{os.path.split(QUERY_PATH)[0]}/map_my_cell", exist_ok=True)

#     # saving adata path
#     adata_labelled_path = f"{os.path.split(QUERY_PATH)[0]}/NucSeq_all_labelled.h5ad"

# adata_labelled_path

# %%
os.path.split(QUERY_PATH)[0]
# Out:
# '/home/gdallagl/myworkdir/data/XDP/SlideTags_single_libraries/sample_03/260313_SL-EXA_0758_B23GHNHLT4/SI-TT-C5/adata'

# %% [markdown]
# # Run Mapping

# %% [markdown]
# Now we will actually [perform the mapping](https://github.com/AllenInstitute/cell_type_mapper/blob/main/docs/mapping_cells.md).

# %%
config = {
    # output paths
    "query_path": QUERY_PATH,
    "extended_result_path": json_dst_path,
    "csv_result_path": csv_dst_path,
    "verbose_csv": True,

    # inout paths
    "query_markers": {
       "serialized_lookup": query_marker_path
    },
    "precomputed_stats": {
        "path": precomputed_path
    },

    "type_assignment": {
        "n_processors": 16,
        "normalization": "raw", # Use raw counts (not normalized)
        "bootstrap_factor": 0.5,
        "bootstrap_iteration": 100
    }
}

# %%
runner = FromSpecifiedMarkersRunner(
    args=[],
    input_data=config
)
runner.run()
print("Done!")
# Out:
# === Running Hierarchical Mapping 1.5.2 with config ===
# {
#   "extended_result_path": "/home/gdallagl/myworkdir/data/XDP/SlideTags_single_libraries/sample_03/260313_SL-EXA_0758_B23GHNHLT4/SI-TT-C5/map_my_cell/mapping.json",
#   "cloud_safe": false,
#   "csv_result_path": "/home/gdallagl/myworkdir/data/XDP/SlideTags_single_libraries/sample_03/260313_SL-EXA_0758_B23GHNHLT4/SI-TT-C5/map_my_cell/mapping.csv",
#   "obsm_key": null,
#   "max_gb": 100.0,
#   "query_gene_id_col": null,
#   "hdf5_result_path": null,
#   "map_to_ensembl": false,
#   "log_level": "ERROR",
#   "flatten": false,
#   "precomputed_stats": {
#     "log_level": "ERROR",
#     "path": "/home/gdallagl/myworkdir/XDP/data/AllenAtlas/BGT_human_20250507/Human.precomputed_stats.20250507.h5"
#   },
#   "summary_metadata_path": null,
#   "nodes_to_drop": null,
#   "query_path": "/home/gdallagl/myworkdir/data/XDP/SlideTags_single_libraries/sample_03/260313_SL-EXA_0758_B23GHNHLT4/SI-TT-C5/adata/raw_adata.h5ad",
#   "verbose_csv": true,
#   "verbose_stdout": true,
#   "tmp_dir": null,
#   "query_markers": {
#     "serialized_lookup": "/home/gdallagl/myworkdir/XDP/data/AllenAtlas/BGT_human_20250507/Human.query_markers.20250507.json",
#     "collapse_markers": false,
#     "log_level": "ERROR"
#   },
#   "type_assignment": {
#     "n_runners_up": 5,
#     "chunk_size": 10000,
#     "rng_seed": 11235813,
#     "min_markers": 10,
#     "log_level": "ERROR",
#     "bootstrap_iteration": 100,
#     "bootstrap_factor_lookup": null,
#     "n_processors": 16,
#     "bootstrap_factor": 0.5,
#     "normalization": "raw"
#   },
#   "log_path": null,
#   "obsm_clobber": false,
#   "drop_level": null,
#   "extended_result_dir": null
# }
# ENV: is_torch_available: True
# ENV: is_cuda_available: False
# ENV: use_torch: False
# ENV: multiprocessing start method: fork
# ENV: Python version: 3.11.8 (main, Sep 24 2025, 14:13:47) [GCC 12.2.0]
# ENV: anndata version: 0.12.6
# ENV: numpy version: 2.2.6
# ENV: torch version: 2.10.0+cu128
# BENCHMARK: spent 6.2037e-04 seconds validating config and copying data
# using ../Human.precomputed_stats.20250507.h5 for precomputed_stats
# reading taxonomy_tree from ../Human.precomputed_stats.20250507.h5
# /home/gdallagl/myworkdir/XDP/.venv/lib/python3.11/site-packages/cell_type_mapper/cli/cli_log.py:73: UserWarning: numpy's internal parallelization is enabled. This could cause independent worker processes to compete for resources, degrading performance. We recommend setting the following environment variables to '1' to improve performance
# {
#   "NUMEXPR_NUM_THREADS": "",
#   "MKL_NUM_THREADS": "",
#   "OMP_NUM_THREADS": ""
# }
#   warnings.warn(msg)
# /home/gdallagl/myworkdir/XDP/.venv/lib/python3.11/site-packages/cell_type_mapper/cli/cli_log.py:104: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('anndata')` instead.
#   self.env(f"anndata version: {anndata.__version__}")
# /home/gdallagl/myworkdir/XDP/.venv/lib/python3.11/site-packages/cell_type_mapper/taxonomy/utils.py:253: UserWarning: This taxonomy has no mapping from leaf_node -> rows in the cell by gene matrix
#   warnings.warn("This taxonomy has no mapping from leaf_node -> rows "
# /home/gdallagl/myworkdir/XDP/.venv/lib/python3.11/site-packages/cell_type_mapper/cli/cli_log.py:73: UserWarning: 32 marker genes were not present in the query dataset. They have been ignored
#   warnings.warn(msg)
# BENCHMARK: spent 1.5016e-01 seconds creating query marker cache
# Running CPU implementation of type assignment.
# BENCHMARK: spent 3.6297e+02 seconds assigning cell types
# Writing marker genes to output file
# MAPPING FROM SPECIFIED MARKERS RAN SUCCESSFULLY
# CLEANING UP
# Done!

# %% [markdown]
# # Output of mapping file
#
# The results of our mapping are now in two files: the csv file pointed to by `csv_dst_path` and the JSON file pointed to by `json_dst_path`. Dedicated documentation of the the contents of the mapping output [can be found here.](https://github.com/AllenInstitute/cell_type_mapper/blob/main/docs/output.md)
#
# ## CSV output file
#
# The CSV file is effectively just a dataframe. For every cell at every taxonomy level, you have its assigned cell type (both as a guaranteed unique "label" and a more human readable "name") along with quality metrics assessing the confidence in the mapping (see the detailed documentation above).

# %%
mapping_csv = pd.read_csv(csv_dst_path, comment='#')
mapping_csv = mapping_csv.set_index("cell_id")

display(mapping_csv)
# Out:
#                        Neighborhood_label Neighborhood_name  \
# cell_id
# AAACCAAAGATCTTCC-1  CS20250428_NEIGH_0002   Subpallium GABA
# AAACCAAAGCGGGGAT-1  CS20250428_NEIGH_0002   Subpallium GABA
# AAACCAAAGCTATAAC-1  CS20250428_NEIGH_0002   Subpallium GABA
# AAACCAAAGGGAAGCC-1  CS20250428_NEIGH_0002   Subpallium GABA
# AAACCAAAGGTCGCCA-1  CS20250428_NEIGH_0002   Subpallium GABA
# ...                                   ...               ...
# GTTGTGCAGGGGTTTC-1  CS20250428_NEIGH_0001         Nonneuron
# GTTGTGGGTACCTTTG-1  CS20250428_NEIGH_0002   Subpallium GABA
# GTTGTGGGTAGCTTGG-1  CS20250428_NEIGH_0002   Subpallium GABA
# GTTGTGGGTCCTGCGC-1  CS20250428_NEIGH_0002   Subpallium GABA
# GTTGTGGGTCGGTGTA-1  CS20250428_NEIGH_0001         Nonneuron
#
#                     Neighborhood_bootstrapping_probability  \
# cell_id
# AAACCAAAGATCTTCC-1                                    1.00
# AAACCAAAGCGGGGAT-1                                    0.86
# AAACCAAAGCTATAAC-1                                    1.00
# AAACCAAAGGGAAGCC-1                                    1.00
# AAACCAAAGGTCGCCA-1                                    1.00
# ...                                                    ...
# GTTGTGCAGGGGTTTC-1                                    1.00
# GTTGTGGGTACCTTTG-1                                    1.00
# GTTGTGGGTAGCTTGG-1                                    1.00
# GTTGTGGGTCCTGCGC-1                                    1.00
# GTTGTGGGTCGGTGTA-1                                    1.00
#
#                     Neighborhood_aggregate_probability  \
# cell_id
# AAACCAAAGATCTTCC-1                                1.00
# AAACCAAAGCGGGGAT-1                                0.86
# AAACCAAAGCTATAAC-1                                1.00
# AAACCAAAGGGAAGCC-1                                1.00
# AAACCAAAGGTCGCCA-1                                1.00
# ...                                                ...
# GTTGTGCAGGGGTTTC-1                                1.00
# GTTGTGGGTACCTTTG-1                                1.00
# GTTGTGGGTAGCTTGG-1                                1.00
# GTTGTGGGTCCTGCGC-1                                1.00
# GTTGTGGGTCGGTGTA-1                                1.00
#
#                     Neighborhood_correlation_coefficient  \
# cell_id
# AAACCAAAGATCTTCC-1                                0.7268
# AAACCAAAGCGGGGAT-1                                0.4929
# AAACCAAAGCTATAAC-1                                0.7826
# AAACCAAAGGGAAGCC-1                                0.8513
# AAACCAAAGGTCGCCA-1                                0.8435
# ...                                                  ...
# GTTGTGCAGGGGTTTC-1                                0.7954
# GTTGTGGGTACCTTTG-1                                0.7873
# GTTGTGGGTAGCTTGG-1                                0.7708
# GTTGTGGGTCCTGCGC-1                                0.7665
# GTTGTGGGTCGGTGTA-1                                0.5963
#
#                               Class_label   Class_name  \
# cell_id
# AAACCAAAGATCTTCC-1  CS20250428_CLASS_0003  CN LGE GABA
# AAACCAAAGCGGGGAT-1  CS20250428_CLASS_0006     F M GABA
# AAACCAAAGCTATAAC-1  CS20250428_CLASS_0003  CN LGE GABA
# AAACCAAAGGGAAGCC-1  CS20250428_CLASS_0003  CN LGE GABA
# AAACCAAAGGTCGCCA-1  CS20250428_CLASS_0003  CN LGE GABA
# ...                                   ...          ...
# GTTGTGCAGGGGTTTC-1  CS20250428_CLASS_0010    OPC-Oligo
# GTTGTGGGTACCTTTG-1  CS20250428_CLASS_0003  CN LGE GABA
# GTTGTGGGTAGCTTGG-1  CS20250428_CLASS_0003  CN LGE GABA
# GTTGTGGGTCCTGCGC-1  CS20250428_CLASS_0003  CN LGE GABA
# GTTGTGGGTCGGTGTA-1  CS20250428_CLASS_0000   Astro-Epen
#
#                     Class_bootstrapping_probability  \
# cell_id
# AAACCAAAGATCTTCC-1                             1.00
# AAACCAAAGCGGGGAT-1                             0.52
# AAACCAAAGCTATAAC-1                             1.00
# AAACCAAAGGGAAGCC-1                             1.00
# AAACCAAAGGTCGCCA-1                             1.00
# ...                                             ...
# GTTGTGCAGGGGTTTC-1                             1.00
# GTTGTGGGTACCTTTG-1                             1.00
# GTTGTGGGTAGCTTGG-1                             1.00
# GTTGTGGGTCCTGCGC-1                             1.00
# GTTGTGGGTCGGTGTA-1                             1.00
#
#                     Class_aggregate_probability  \
# cell_id
# AAACCAAAGATCTTCC-1                       1.0000
# AAACCAAAGCGGGGAT-1                       0.4472
# AAACCAAAGCTATAAC-1                       1.0000
# AAACCAAAGGGAAGCC-1                       1.0000
# AAACCAAAGGTCGCCA-1                       1.0000
# ...                                         ...
# GTTGTGCAGGGGTTTC-1                       1.0000
# GTTGTGGGTACCTTTG-1                       1.0000
# GTTGTGGGTAGCTTGG-1                       1.0000
# GTTGTGGGTCCTGCGC-1                       1.0000
# GTTGTGGGTCGGTGTA-1                       1.0000
#
#                     Class_correlation_coefficient  ...  \
# cell_id                                            ...
# AAACCAAAGATCTTCC-1                         0.7002  ...
# AAACCAAAGCGGGGAT-1                         0.4575  ...
# AAACCAAAGCTATAAC-1                         0.7507  ...
# AAACCAAAGGGAAGCC-1                         0.8431  ...
# AAACCAAAGGTCGCCA-1                         0.8290  ...
# ...                                           ...  ...
# GTTGTGCAGGGGTTTC-1                         0.9212  ...
# GTTGTGGGTACCTTTG-1                         0.7658  ...
# GTTGTGGGTAGCTTGG-1                         0.7528  ...
# GTTGTGGGTCCTGCGC-1                         0.7381  ...
# GTTGTGGGTCGGTGTA-1                         0.6659  ...
#
#                                       Group_name  \
# cell_id
# AAACCAAAGATCTTCC-1                   STRv D1 MSN
# AAACCAAAGCGGGGAT-1  SN-VTR-HTH GATA3-TCF7L2 GABA
# AAACCAAAGCTATAAC-1            STRd D2 Matrix MSN
# AAACCAAAGGGAAGCC-1            STRd D1 Matrix MSN
# AAACCAAAGGTCGCCA-1            STRd D1 Matrix MSN
# ...                                          ...
# GTTGTGCAGGGGTTTC-1                 Oligo PLEKHG1
# GTTGTGGGTACCTTTG-1         STRd D2 Striosome MSN
# GTTGTGGGTAGCTTGG-1                   STRv D2 MSN
# GTTGTGGGTCCTGCGC-1         STRd D1 Striosome MSN
# GTTGTGGGTCGGTGTA-1                     Astrocyte
#
#                    Group_bootstrapping_probability  \
# cell_id
# AAACCAAAGATCTTCC-1                            0.95
# AAACCAAAGCGGGGAT-1                            1.00
# AAACCAAAGCTATAAC-1                            1.00
# AAACCAAAGGGAAGCC-1                            0.99
# AAACCAAAGGTCGCCA-1                            1.00
# ...                                            ...
# GTTGTGCAGGGGTTTC-1                            1.00
# GTTGTGGGTACCTTTG-1                            1.00
# GTTGTGGGTAGCTTGG-1                            1.00
# GTTGTGGGTCCTGCGC-1                            0.67
# GTTGTGGGTCGGTGTA-1                            0.99
#
#                     Group_aggregate_probability  \
# cell_id
# AAACCAAAGATCTTCC-1                       0.9500
# AAACCAAAGCGGGGAT-1                       0.1744
# AAACCAAAGCTATAAC-1                       1.0000
# AAACCAAAGGGAAGCC-1                       0.9900
# AAACCAAAGGTCGCCA-1                       1.0000
# ...                                         ...
# GTTGTGCAGGGGTTTC-1                       1.0000
# GTTGTGGGTACCTTTG-1                       1.0000
# GTTGTGGGTAGCTTGG-1                       1.0000
# GTTGTGGGTCCTGCGC-1                       0.4422
# GTTGTGGGTCGGTGTA-1                       0.9900
#
#                     Group_correlation_coefficient          Cluster_label  \
# cell_id
# AAACCAAAGATCTTCC-1                         0.4558  CS20250428_CLUST_0529
# AAACCAAAGCGGGGAT-1                         0.5068  CS20250428_CLUST_0359
# AAACCAAAGCTATAAC-1                         0.6510  CS20250428_CLUST_0468
# AAACCAAAGGGAAGCC-1                         0.6250  CS20250428_CLUST_0435
# AAACCAAAGGTCGCCA-1                         0.6551  CS20250428_CLUST_0443
# ...                                           ...                    ...
# GTTGTGCAGGGGTTTC-1                         0.7096  CS20250428_CLUST_0231
# GTTGTGGGTACCTTTG-1                         0.6065  CS20250428_CLUST_0492
# GTTGTGGGTAGCTTGG-1                         0.6080  CS20250428_CLUST_0552
# GTTGTGGGTCCTGCGC-1                         0.5372  CS20250428_CLUST_0444
# GTTGTGGGTCGGTGTA-1                         0.3366  CS20250428_CLUST_0255
#
#                    Cluster_name Cluster_alias  \
# cell_id
# AAACCAAAGATCTTCC-1    Human-166     Human-166
# AAACCAAAGCGGGGAT-1    Human-524     Human-524
# AAACCAAAGCTATAAC-1    Human-433     Human-433
# AAACCAAAGGGAAGCC-1     Human-26      Human-26
# AAACCAAAGGTCGCCA-1    Human-512     Human-512
# ...                         ...           ...
# GTTGTGCAGGGGTTTC-1     Human-15      Human-15
# GTTGTGGGTACCTTTG-1    Human-477     Human-477
# GTTGTGGGTAGCTTGG-1    Human-339     Human-339
# GTTGTGGGTCCTGCGC-1     Human-23      Human-23
# GTTGTGGGTCGGTGTA-1    Human-232     Human-232
#
#                     Cluster_bootstrapping_probability  \
# cell_id
# AAACCAAAGATCTTCC-1                               0.26
# AAACCAAAGCGGGGAT-1                               0.56
# AAACCAAAGCTATAAC-1                               0.59
# AAACCAAAGGGAAGCC-1                               0.95
# AAACCAAAGGTCGCCA-1                               0.87
# ...                                               ...
# GTTGTGCAGGGGTTTC-1                               1.00
# GTTGTGGGTACCTTTG-1                               0.95
# GTTGTGGGTAGCTTGG-1                               0.94
# GTTGTGGGTCCTGCGC-1                               1.00
# GTTGTGGGTCGGTGTA-1                               0.90
#
#                     Cluster_aggregate_probability  \
# cell_id
# AAACCAAAGATCTTCC-1                         0.2470
# AAACCAAAGCGGGGAT-1                         0.0977
# AAACCAAAGCTATAAC-1                         0.5900
# AAACCAAAGGGAAGCC-1                         0.9405
# AAACCAAAGGTCGCCA-1                         0.8700
# ...                                           ...
# GTTGTGCAGGGGTTTC-1                         1.0000
# GTTGTGGGTACCTTTG-1                         0.9500
# GTTGTGGGTAGCTTGG-1                         0.9400
# GTTGTGGGTCCTGCGC-1                         0.4422
# GTTGTGGGTCGGTGTA-1                         0.8910
#
#                     Cluster_correlation_coefficient
# cell_id
# AAACCAAAGATCTTCC-1                           0.3708
# AAACCAAAGCGGGGAT-1                           0.2665
# AAACCAAAGCTATAAC-1                           0.4392
# AAACCAAAGGGAAGCC-1                           0.4722
# AAACCAAAGGTCGCCA-1                           0.4888
# ...                                             ...
# GTTGTGCAGGGGTTTC-1                           0.7994
# GTTGTGGGTACCTTTG-1                           0.4132
# GTTGTGGGTAGCTTGG-1                           0.5810
# GTTGTGGGTCCTGCGC-1                           0.5222
# GTTGTGGGTCGGTGTA-1                           0.4343
#
# [11488 rows x 26 columns]

# %% [markdown]
# # Add Metadata to adata and Save

# %%
# Read adata
query_adata = sc.read_h5ad(QUERY_PATH)

# Merge metadata
query_adata.obs = query_adata.obs.join(mapping_csv, how="left")
display(query_adata.obs)

# save 
query_adata.write(adata_labelled_path)
print(f"Saved labelled adata to {adata_labelled_path}")

n_cells_original = len(query_adata.obs)
n_cells_mapped = mapping_csv.index.nunique()
print(f"Original cells: {n_cells_original}")
print(f"Mapped cells: {n_cells_mapped}")
assert n_cells_original == n_cells_mapped, "Mapping incomplete!"
# Out:
#                                x             y  pct_intronic  \
# AAACCAAAGATCTTCC-1  36423.540181   1737.824118      0.579186
# AAACCAAAGCGGGGAT-1  32213.904742    724.472621      0.709032
# AAACCAAAGCTATAAC-1  14327.696644  -7050.372339      0.704688
# AAACCAAAGGGAAGCC-1  50536.774687   1133.246302      0.699606
# AAACCAAAGGTCGCCA-1  52681.258688   2680.789502      0.768053
# ...                          ...           ...           ...
# GTTGTGCAGGGGTTTC-1  52688.986346  10504.087756      0.572950
# GTTGTGGGTACCTTTG-1  49002.528022   7073.173803      0.743793
# GTTGTGGGTAGCTTGG-1  35984.176748  -3792.366933      0.611910
# GTTGTGGGTCCTGCGC-1  42675.815207    462.513644      0.612490
# GTTGTGGGTCGGTGTA-1  60232.487629   6336.162686      0.611297
#
#                     frac_contamination  dbscan_clusters  dbscan_score  \
# AAACCAAAGATCTTCC-1            0.005441                1      0.989659
# AAACCAAAGCGGGGAT-1            0.162640                1      0.967157
# AAACCAAAGCTATAAC-1            0.028627                1      0.924382
# AAACCAAAGGGAAGCC-1            0.000932                3      0.535463
# AAACCAAAGGTCGCCA-1            0.002405                1      0.951235
# ...                                ...              ...           ...
# GTTGTGCAGGGGTTTC-1            0.031225                1      0.934203
# GTTGTGGGTACCTTTG-1            0.042181                1      0.966727
# GTTGTGGGTAGCTTGG-1            0.005486                1      0.708145
# GTTGTGGGTCCTGCGC-1            0.010583                1      0.922969
# GTTGTGGGTCGGTGTA-1            0.441838                1      0.939984
#
#                        sample  has_spatial     Neighborhood_label  \
# AAACCAAAGATCTTCC-1  sample_03         True  CS20250428_NEIGH_0002
# AAACCAAAGCGGGGAT-1  sample_03         True  CS20250428_NEIGH_0002
# AAACCAAAGCTATAAC-1  sample_03         True  CS20250428_NEIGH_0002
# AAACCAAAGGGAAGCC-1  sample_03        False  CS20250428_NEIGH_0002
# AAACCAAAGGTCGCCA-1  sample_03         True  CS20250428_NEIGH_0002
# ...                       ...          ...                    ...
# GTTGTGCAGGGGTTTC-1  sample_03         True  CS20250428_NEIGH_0001
# GTTGTGGGTACCTTTG-1  sample_03         True  CS20250428_NEIGH_0002
# GTTGTGGGTAGCTTGG-1  sample_03         True  CS20250428_NEIGH_0002
# GTTGTGGGTCCTGCGC-1  sample_03         True  CS20250428_NEIGH_0002
# GTTGTGGGTCGGTGTA-1  sample_03         True  CS20250428_NEIGH_0001
#
#                    Neighborhood_name  ...                    Group_name  \
# AAACCAAAGATCTTCC-1   Subpallium GABA  ...                   STRv D1 MSN
# AAACCAAAGCGGGGAT-1   Subpallium GABA  ...  SN-VTR-HTH GATA3-TCF7L2 GABA
# AAACCAAAGCTATAAC-1   Subpallium GABA  ...            STRd D2 Matrix MSN
# AAACCAAAGGGAAGCC-1   Subpallium GABA  ...            STRd D1 Matrix MSN
# AAACCAAAGGTCGCCA-1   Subpallium GABA  ...            STRd D1 Matrix MSN
# ...                              ...  ...                           ...
# GTTGTGCAGGGGTTTC-1         Nonneuron  ...                 Oligo PLEKHG1
# GTTGTGGGTACCTTTG-1   Subpallium GABA  ...         STRd D2 Striosome MSN
# GTTGTGGGTAGCTTGG-1   Subpallium GABA  ...                   STRv D2 MSN
# GTTGTGGGTCCTGCGC-1   Subpallium GABA  ...         STRd D1 Striosome MSN
# GTTGTGGGTCGGTGTA-1         Nonneuron  ...                     Astrocyte
#
#                     Group_bootstrapping_probability  \
# AAACCAAAGATCTTCC-1                             0.95
# AAACCAAAGCGGGGAT-1                             1.00
# AAACCAAAGCTATAAC-1                             1.00
# AAACCAAAGGGAAGCC-1                             0.99
# AAACCAAAGGTCGCCA-1                             1.00
# ...                                             ...
# GTTGTGCAGGGGTTTC-1                             1.00
# GTTGTGGGTACCTTTG-1                             1.00
# GTTGTGGGTAGCTTGG-1                             1.00
# GTTGTGGGTCCTGCGC-1                             0.67
# GTTGTGGGTCGGTGTA-1                             0.99
#
#                     Group_aggregate_probability Group_correlation_coefficient  \
# AAACCAAAGATCTTCC-1                       0.9500                        0.4558
# AAACCAAAGCGGGGAT-1                       0.1744                        0.5068
# AAACCAAAGCTATAAC-1                       1.0000                        0.6510
# AAACCAAAGGGAAGCC-1                       0.9900                        0.6250
# AAACCAAAGGTCGCCA-1                       1.0000                        0.6551
# ...                                         ...                           ...
# GTTGTGCAGGGGTTTC-1                       1.0000                        0.7096
# GTTGTGGGTACCTTTG-1                       1.0000                        0.6065
# GTTGTGGGTAGCTTGG-1                       1.0000                        0.6080
# GTTGTGGGTCCTGCGC-1                       0.4422                        0.5372
# GTTGTGGGTCGGTGTA-1                       0.9900                        0.3366
#
#                             Cluster_label  Cluster_name  Cluster_alias  \
# AAACCAAAGATCTTCC-1  CS20250428_CLUST_0529     Human-166      Human-166
# AAACCAAAGCGGGGAT-1  CS20250428_CLUST_0359     Human-524      Human-524
# AAACCAAAGCTATAAC-1  CS20250428_CLUST_0468     Human-433      Human-433
# AAACCAAAGGGAAGCC-1  CS20250428_CLUST_0435      Human-26       Human-26
# AAACCAAAGGTCGCCA-1  CS20250428_CLUST_0443     Human-512      Human-512
# ...                                   ...           ...            ...
# GTTGTGCAGGGGTTTC-1  CS20250428_CLUST_0231      Human-15       Human-15
# GTTGTGGGTACCTTTG-1  CS20250428_CLUST_0492     Human-477      Human-477
# GTTGTGGGTAGCTTGG-1  CS20250428_CLUST_0552     Human-339      Human-339
# GTTGTGGGTCCTGCGC-1  CS20250428_CLUST_0444      Human-23       Human-23
# GTTGTGGGTCGGTGTA-1  CS20250428_CLUST_0255     Human-232      Human-232
#
#                     Cluster_bootstrapping_probability  \
# AAACCAAAGATCTTCC-1                               0.26
# AAACCAAAGCGGGGAT-1                               0.56
# AAACCAAAGCTATAAC-1                               0.59
# AAACCAAAGGGAAGCC-1                               0.95
# AAACCAAAGGTCGCCA-1                               0.87
# ...                                               ...
# GTTGTGCAGGGGTTTC-1                               1.00
# GTTGTGGGTACCTTTG-1                               0.95
# GTTGTGGGTAGCTTGG-1                               0.94
# GTTGTGGGTCCTGCGC-1                               1.00
# GTTGTGGGTCGGTGTA-1                               0.90
#
#                    Cluster_aggregate_probability  \
# AAACCAAAGATCTTCC-1                        0.2470
# AAACCAAAGCGGGGAT-1                        0.0977
# AAACCAAAGCTATAAC-1                        0.5900
# AAACCAAAGGGAAGCC-1                        0.9405
# AAACCAAAGGTCGCCA-1                        0.8700
# ...                                          ...
# GTTGTGCAGGGGTTTC-1                        1.0000
# GTTGTGGGTACCTTTG-1                        0.9500
# GTTGTGGGTAGCTTGG-1                        0.9400
# GTTGTGGGTCCTGCGC-1                        0.4422
# GTTGTGGGTCGGTGTA-1                        0.8910
#
#                    Cluster_correlation_coefficient
# AAACCAAAGATCTTCC-1                          0.3708
# AAACCAAAGCGGGGAT-1                          0.2665
# AAACCAAAGCTATAAC-1                          0.4392
# AAACCAAAGGGAAGCC-1                          0.4722
# AAACCAAAGGTCGCCA-1                          0.4888
# ...                                            ...
# GTTGTGCAGGGGTTTC-1                          0.7994
# GTTGTGGGTACCTTTG-1                          0.4132
# GTTGTGGGTAGCTTGG-1                          0.5810
# GTTGTGGGTCCTGCGC-1                          0.5222
# GTTGTGGGTCGGTGTA-1                          0.4343
#
# [11488 rows x 34 columns]
# Saved labelled adata to /home/gdallagl/myworkdir/data/XDP/SlideTags_single_libraries/sample_03/260313_SL-EXA_0758_B23GHNHLT4/SI-TT-C5/adata/labelled_adata.h5ad
# Original cells: 11488
# Mapped cells: 11488

# %%
sc.pl.embedding(query_adata, basis="spatial",  color="Group_name", 
                groups=["STRd D1 Matrix MSN", "STRd D1 Striosome MSN", "STRd D2 Matrix MSN", "STRd D2 Striosome MSN", "STRd D2 StrioMat Hybrid MSN", "STRv D1 MSN", "STRv D2 MSN", "STRv D1 NUDAP MSN", "STR D1D2 Hybrid MSN"],
                size=10, palette = ["#E63946", "#F4A261", "#2DC653", "#FF006E", "#FFBE0B", "#8338EC", "#3A86FF", "#06D6A0", "#FB5607"]
)
# Out:
# WARNING: Length of palette colors is smaller than the number of categories (palette length: 9, categories length: 48. Some categories will have the same color.

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Optional: JSON output file
#
# The JSON output contains everything in the CSV file, along with helpful metadata about your mapping run as [documented here](https://github.com/AllenInstitute/cell_type_mapper/blob/main/docs/output.md#json-output-file).

# %%
# with open(json_dst_path, 'rb') as src:
#     mapping_json = json.load(src)

# %% [markdown]
# For instance, to see the configuration parameters corresponding to your mapping run, you can look at

# %%
# print(json.dumps(mapping_json['config'], indent=2))

# %% [markdown]
# The actual cell type assignments are stored as a list under `'results'` as in

# %%
# print(json.dumps(mapping_json['results'][0], indent=2))

# %% [markdown]
# One complication is that the cell type assignments are only referred to by their unique machine-readable labels in this file. Fortunately, the cell type taxonomy, along with the mapping between machine- and human-readable cell type labels is also provided in this file. The `TaxonomyTree` class provides a helpful interface with that data.

# %%
# from cell_type_mapper.taxonomy.taxonomy_tree import TaxonomyTree

# %%
# taxonomy = TaxonomyTree(data=mapping_json['taxonomy_tree'])

# %%
# taxonomy.label_to_name(level='CCN20250428_LEVEL_3', label='CS20250428_GROUP_0025')
