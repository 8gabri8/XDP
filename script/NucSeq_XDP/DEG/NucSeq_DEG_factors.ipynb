# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
from scipy import sparse
import scanpy as sc
import matplotlib.pyplot as plt
import os
import glob
import rpy2.robjects as ro
import shutil
import seaborn as sns  

from dotenv import load_dotenv; load_dotenv()

from utils import preprocessing
from utils import nebula_with_factors as nebula_utils

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# ATTENTION: need for perpty of running jupternotbook
# %matplotlib inline

PARALLEL_NEBULA_SCRIPT_PATH = os.getenv("PARALLEL_NEBULA_SCRIPT")

TISSUE = "Striatum" # Striatum, DFC,SN
TYPE_DEG = "gradient_score_nebula" #PCA_nebula, baseline_nebula, cNMF_nebula, gradient_score_nebula




if TISSUE == "Striatum":
    ADATA_PATH = f"/home/gdallagl/myworkdir/XDP/data/XDP/NucSec/adatas/{TISSUE}/{TISSUE}_combined_QC_mmc_ct-cured_zoned.h5ad"
elif (TISSUE == "DFC") | (TISSUE == "SN"):
    # no zones
    ADATA_PATH = f"/home/gdallagl/myworkdir/XDP/data/XDP/NucSec/adatas/{TISSUE}/{TISSUE}_combined_QC_mmc_ct-cured.h5ad"

# name of cell tyoe vauble annotaton to use in this analsys
CT_FOR_DEG_VARIABLE = "ct_for_deg" #"Group_name",  "spn_type"
# name of Sample varibale
SAMPLE_VARIABLE = "donor_id"
# variable to test if differtially epxresseda
CONTRAST_VARIABLE = "condition"
# Level of contrat varibale to use as baseline
CONTRAST_BASELINE = "Control"
# Level of contrat varibale to use as stimulated
CONTRAST_STIM = "XDP"

# Covariates to use for stat test
COVARIATES_FOR_DEG = ["age_of_death", "sex", "pct_counts_mt", "frac_intronic", "cohort",
                     #f"age_of_death:{CONTRAST_VARIABLE}"
                      ]
# libraru size col for  enbula
LIBRARY_SIZE_COL = "total_counts"

# # mitluple etst correction pvalue thr
# ALPHA_MULTIPLE_TEST = 0.05
# LOGFC_THR=0.1
# PVAL_THR=0.05

# Save folder
DEG_FOLDER =F"/home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/{TISSUE}/{TYPE_DEG}" # "/home/gdallagl/myworkdir/XDP/data/_old/nucseq_deg_pca_age" #F"/home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/{TISSUE}/{TYPE_DEG}"
os.makedirs(DEG_FOLDER, exist_ok=True)
DEG_FOLDER
# Out:
# '/home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula'

# %%
ct_forcNMF = {
    "Striatum": ["Matrix", "Patch", "Matrix_D1", "Matrix_D2", "Patch_D1", "Patch_D2", "eMSN_D1D2", "eMSN_StrioMat", "eMSN_NUDAP","Oligodendrocyte", "Astrocyte", "Microglia"],
    "DFC": ["Oligodendrocyte", "Astrocyte", "Microglia"],
    "SN": ["Oligodendrocyte", "Astrocyte", "Microglia"],
}

"""
1) request access to UGER macosko folder
2) ssh in UGER
	$ssh gdallagl@login02.broadinstitute.org
3) lunch tmudx
	$tmux
4) type
	$use UGER
5) request interactive node
	$/broad/software/scripts/ish -l h_vmem=10g -pe smp 4 -binding linear:4 -l h_rt=12:00:00 -l os='RedHat7'
6) cd your working folder
	$ cd /broad/macosko/gdallagl/cNMF
7) type
	$use UGER
8) run scirpt to open jupyer on website
	$./start_jupyter_cNMF.sh 
	*) paste link into browser


first run once the cell n order to egenrate the hlahy datset --> then upload on uger


to copy adata to google bucket (on VM terminal)

    TISSUE="DFC"
    for cell_type in "Matrix_D1" "Matrix_D2" "Patch_D1" "Patch_D2" "eMSN_D1D2" "eMSN_StrioMat" "eMSN_NUDAP" "Oligodendrocyte" "Astrocyte" "Microglia"; do
        echo "Copying $cell_type..."
        gsutil cp /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/$TISSUE/cNMF_nebula/$cell_type/healthy_cNMF.h5ad \
            gs://macosko_data/gdallagl/NucSeq/healthy_adata_for_cNMF/$TISSUE/$cell_type/healthy_cNMF.h5ad
    done

to copy form google bucket to auger (on UGER terminal)

    use UGER
    ish #alias to reaeust small ndoe
    use Google-Cloud-SDK

    TISSUE="DFC"
    for cell_type in "Matrix_D1" "Matrix_D2" "Patch_D1" "Patch_D2" "eMSN_D1D2" "eMSN_StrioMat" "eMSN_NUDAP" "Oligodendrocyte" "Astrocyte" "Microglia"; do
        echo "Copying $cell_type..."
        mkdir -p /broad/macosko/gdallagl/cNMF/NucSeq/$TISSUE/$cell_type/input
        gsutil cp gs://macosko_data/gdallagl/NucSeq/healthy_adata_for_cNMF/$TISSUE/$cell_type/healthy_cNMF.h5ad \
            /broad/macosko/gdallagl/cNMF/NucSeq/$TISSUE/$cell_type/input/
    done

Run facotrization on UGER

to copy from UGER to google bucket (on UGER terminal)

    use Google-Cloud-SDK
    TISSUE="DFC"
    for cell_type in Matrix_D1 Matrix_D2 Patch_D1 Patch_D2 eMSN_D1D2 eMSN_StrioMat eMSN_NUDAP Oligodendrocyte Astrocyte Microglia; do
        echo "Copying $cell_type..."
        gsutil -m cp -r \
            /broad/macosko/gdallagl/cNMF/NucSeq/$TISSUE/$cell_type/output/final_results/* \
            gs://macosko_data/gdallagl/NucSeq/healthy_adata_for_cNMF/$TISSUE/$cell_type/cNMF_run_healthy/
    done
    

to copy from google bucket to local (on VM terminal)

    TISSUE="DFC"
    for cell_type in "Matrix_D1" "Matrix_D2" "Patch_D1" "Patch_D2" "eMSN_D1D2" "eMSN_StrioMat" "eMSN_NUDAP" "Oligodendrocyte" "Astrocyte" "Microglia"; do
        echo "Copying $cell_type..."
        mkdir -p /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/$TISSUE/cNMF_nebula/$cell_type/cNMF_run_healthy
        gsutil cp -r gs://macosko_data/gdallagl/NucSeq/healthy_adata_for_cNMF/$TISSUE/$cell_type/cNMF_run_healthy/* \
            /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/$TISSUE/cNMF_nebula/$cell_type/cNMF_run_healthy/
    done

"""
# Out:
# '\n1) request access to UGER macosko folder\n2) ssh in UGER\n\t$ssh gdallagl@login02.broadinstitute.org\n3) lunch tmudx\n\t$tmux\n4) type\n\t$use UGER\n5) request interactive node\n\t$/broad/software/scripts/ish -l h_vmem=10g -pe smp 4 -binding linear:4 -l h_rt=12:00:00 -l os=\'RedHat7\'\n6) cd your working folder\n\t$ cd /broad/macosko/gdallagl/cNMF\n7) type\n\t$use UGER\n8) run scirpt to open jupyer on website\n\t$./start_jupyter_cNMF.sh \n\t*) paste link into browser\n\n\nfirst run once the cell n order to egenrate the hlahy datset --> then upload on uger\n\n\nto copy adata to google bucket (on VM terminal)\n\n    TISSUE="DFC"\n    for cell_type in "Matrix_D1" "Matrix_D2" "Patch_D1" "Patch_D2" "eMSN_D1D2" "eMSN_StrioMat" "eMSN_NUDAP" "Oligodendrocyte" "Astrocyte" "Microglia"; do\n        echo "Copying $cell_type..."\n        gsutil cp /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/$TISSUE/cNMF_nebula/$cell_type/healthy_cNMF.h5ad             gs://macosko_data/gdallagl/NucSeq/healthy_adata_for_cNMF/$TISSUE/$cell_type/healthy_cNMF.h5ad\n    done\n\nto copy form google bucket to auger (on UGER terminal)\n\n    use UGER\n    ish #alias to reaeust small ndoe\n    use Google-Cloud-SDK\n\n    TISSUE="DFC"\n    for cell_type in "Matrix_D1" "Matrix_D2" "Patch_D1" "Patch_D2" "eMSN_D1D2" "eMSN_StrioMat" "eMSN_NUDAP" "Oligodendrocyte" "Astrocyte" "Microglia"; do\n        echo "Copying $cell_type..."\n        mkdir -p /broad/macosko/gdallagl/cNMF/NucSeq/$TISSUE/$cell_type/input\n        gsutil cp gs://macosko_data/gdallagl/NucSeq/healthy_adata_for_cNMF/$TISSUE/$cell_type/healthy_cNMF.h5ad             /broad/macosko/gdallagl/cNMF/NucSeq/$TISSUE/$cell_type/input/\n    done\n\nRun facotrization on UGER\n\nto copy from UGER to google bucket (on UGER terminal)\n\n    use Google-Cloud-SDK\n    TISSUE="DFC"\n    for cell_type in Matrix_D1 Matrix_D2 Patch_D1 Patch_D2 eMSN_D1D2 eMSN_StrioMat eMSN_NUDAP Oligodendrocyte Astrocyte Microglia; do\n        echo "Copying $cell_type..."\n        gsutil -m cp -r             /broad/macosko/gdallagl/cNMF/NucSeq/$TISSUE/$cell_type/output/final_results/*             gs://macosko_data/gdallagl/NucSeq/healthy_adata_for_cNMF/$TISSUE/$cell_type/cNMF_run_healthy/\n    done\n\n\nto copy from google bucket to local (on VM terminal)\n\n    TISSUE="DFC"\n    for cell_type in "Matrix_D1" "Matrix_D2" "Patch_D1" "Patch_D2" "eMSN_D1D2" "eMSN_StrioMat" "eMSN_NUDAP" "Oligodendrocyte" "Astrocyte" "Microglia"; do\n        echo "Copying $cell_type..."\n        mkdir -p /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/$TISSUE/cNMF_nebula/$cell_type/cNMF_run_healthy\n        gsutil cp -r gs://macosko_data/gdallagl/NucSeq/healthy_adata_for_cNMF/$TISSUE/$cell_type/cNMF_run_healthy/*             /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/$TISSUE/cNMF_nebula/$cell_type/cNMF_run_healthy/\n    done\n\n'

# %% [markdown]
# # Read adata

# %%
print("Loading adata... \ntissue:", TISSUE, "\ntype of DEG:", TYPE_DEG)
adata = sc.read_h5ad(ADATA_PATH)#, backed="r")
print(adata.obs.columns)

###########################
#ATTENTION: use genenames for DEG
adata.var.index = adata.var["gene_symbol"]
###########################

###########################
#ATTENTION: remove "bad cell" ypes
adata = adata[~adata.obs["ct_for_deg"].str.startswith("-"), :].copy()
###########################

###########################
#ATTENTION: be sure cell types have no space
adata.obs[CT_FOR_DEG_VARIABLE] = adata.obs[CT_FOR_DEG_VARIABLE].str.replace(" ", "_")
###########################

###########################
#ATTENTION: remove bad quality samples
adata = adata[~adata.obs[CONTRAST_VARIABLE].isna()].copy()
###########################
# Out:
# Loading adata...
# tissue: Striatum
# type of DEG: gradient_score_nebula
# Index(['background_fraction', 'cell_probability', 'cell_size',
#        'droplet_efficiency', 'barcode', 'bcl', 'rna_index', 'library',
#        'library__barcode', 'frac_mito', 'mol_info_nUMI', 'mol_info_nRead',
#        'frac_intronic', 'donor_id', 'vireo_prob_max', 'vireo_prob_doublet',
#        'vireo_n_vars', 'vireo_best_singlet', 'vireo_best_doublet',
#        'vireo_doublet_logLikRatio', 'dropsift_frac_contamination',
#        'dropsift_training_label_is_cell', 'dropsift_empty_gene_module_score',
#        'dropsift_is_cell', 'dropsift_is_cell_prob', 'cell_class', 'leiden_0.1',
#        'leiden_0.2', 'leiden_0.3', 'leiden_0.4', 'leiden_0.5', 'tissue',
#        'broad_original_cell_type', 'n_genes_by_counts',
#        'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts',
#        'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes',
#        'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes',
#        'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt',
#        'brain_bank', 'cohort', 'condition', 'sex', 'age_of_onset',
#        'age_of_death', 'repeat_length', 'year_collected', 'disease_duration',
#        'rqs', 'dv200', 'ph', 'mqs_numerical', 'mqs',
#        'immediate.cause.of.death', 'infection_related_death',
#        'Neighborhood_label', 'Neighborhood_name',
#        'Neighborhood_bootstrapping_probability',
#        'Neighborhood_aggregate_probability',
#        'Neighborhood_correlation_coefficient', 'Class_label', 'Class_name',
#        'Class_bootstrapping_probability', 'Class_aggregate_probability',
#        'Class_correlation_coefficient', 'Subclass_label', 'Subclass_name',
#        'Subclass_bootstrapping_probability', 'Subclass_aggregate_probability',
#        'Subclass_correlation_coefficient', 'Group_label', 'Group_name',
#        'Group_bootstrapping_probability', 'Group_aggregate_probability',
#        'Group_correlation_coefficient', 'Cluster_label', 'Cluster_name',
#        'Cluster_alias', 'Cluster_bootstrapping_probability',
#        'Cluster_aggregate_probability', 'Cluster_correlation_coefficient',
#        'leiden_0.1_all_cells', 'leiden_0.5_all_cells', 'leiden_0.07_all_cells',
#        'ct_for_deg', 'is_neuron', 'mapping_coupling_for_zoning', 'zone',
#        'zone_probability', 'mapping_coupling_for_zoning_4_zones', 'zone_4',
#        'zone_4_probability'],
#       dtype='object')

# %%
# just same age gap
min_age = adata[adata.obs[CONTRAST_VARIABLE] == CONTRAST_STIM].obs["age_of_death"].min()
max_age = adata[adata.obs[CONTRAST_VARIABLE] == CONTRAST_STIM].obs["age_of_death"].max()
adata[adata.obs["age_of_death"].between(min_age-5, max_age+5)]
# Out:
# View of AnnData object with n_obs × n_vars = 194330 × 38601
#     obs: 'background_fraction', 'cell_probability', 'cell_size', 'droplet_efficiency', 'barcode', 'bcl', 'rna_index', 'library', 'library__barcode', 'frac_mito', 'mol_info_nUMI', 'mol_info_nRead', 'frac_intronic', 'donor_id', 'vireo_prob_max', 'vireo_prob_doublet', 'vireo_n_vars', 'vireo_best_singlet', 'vireo_best_doublet', 'vireo_doublet_logLikRatio', 'dropsift_frac_contamination', 'dropsift_training_label_is_cell', 'dropsift_empty_gene_module_score', 'dropsift_is_cell', 'dropsift_is_cell_prob', 'cell_class', 'leiden_0.1', 'leiden_0.2', 'leiden_0.3', 'leiden_0.4', 'leiden_0.5', 'tissue', 'broad_original_cell_type', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'brain_bank', 'cohort', 'condition', 'sex', 'age_of_onset', 'age_of_death', 'repeat_length', 'year_collected', 'disease_duration', 'rqs', 'dv200', 'ph', 'mqs_numerical', 'mqs', 'immediate.cause.of.death', 'infection_related_death', 'Neighborhood_label', 'Neighborhood_name', 'Neighborhood_bootstrapping_probability', 'Neighborhood_aggregate_probability', 'Neighborhood_correlation_coefficient', 'Class_label', 'Class_name', 'Class_bootstrapping_probability', 'Class_aggregate_probability', 'Class_correlation_coefficient', 'Subclass_label', 'Subclass_name', 'Subclass_bootstrapping_probability', 'Subclass_aggregate_probability', 'Subclass_correlation_coefficient', 'Group_label', 'Group_name', 'Group_bootstrapping_probability', 'Group_aggregate_probability', 'Group_correlation_coefficient', 'Cluster_label', 'Cluster_name', 'Cluster_alias', 'Cluster_bootstrapping_probability', 'Cluster_aggregate_probability', 'Cluster_correlation_coefficient', 'leiden_0.1_all_cells', 'leiden_0.5_all_cells', 'leiden_0.07_all_cells', 'ct_for_deg', 'is_neuron', 'mapping_coupling_for_zoning', 'zone', 'zone_probability', 'mapping_coupling_for_zoning_4_zones', 'zone_4', 'zone_4_probability'
#     var: 'gene_symbol', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'ensamble_id', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'Group_name_colors', 'Subclass_name_colors', 'brain_bank_colors', 'cohort_colors', 'condition_colors', 'ct_for_deg_colors', 'donor_id_colors', 'hvg', 'is_neuron_colors', 'leiden_0.07_all_cells', 'leiden_0.1_all_cells', 'leiden_0.1_all_cells_colors', 'leiden_0.5_all_cells', 'library_colors', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'umap'
#     varm: 'PCs'
#     layers: 'counts', 'log1p_norm'
#     obsp: 'connectivities', 'distances'

# %%
# ATTENTION: just one mix d1 and d2 and run anasys
adata =  adata[adata.obs[CT_FOR_DEG_VARIABLE].isin(["Matrix_D1", "Matrix_D2", "Patch_D1", "Patch_D2", "eMSN_D1D2"])].copy()
# merge for power
adata.obs[CT_FOR_DEG_VARIABLE].replace({"Matrix_D1": "Matrix", "Matrix_D2": "Matrix", "Patch_D1": "Patch", "Patch_D2": "Patch"}, inplace=True)

########à

# # just males
# adata = adata[adata.obs.sex == "M"].copy()
# COVARIATES_FOR_DEG = COVARIATES_FOR_DEG = [cov for cov in COVARIATES_FOR_DEG if cov != "sex"]

# # just same age gap
# min_age = adata[adata.obs[CONTRAST_VARIABLE] == CONTRAST_STIM].obs["age_of_death"].min()
# max_age = adata[adata.obs[CONTRAST_VARIABLE] == CONTRAST_STIM].obs["age_of_death"].max()
# adata = adata[adata.obs["age_of_death"].between(min_age-5, max_age+5)].copy()

# display(adata.obs[CT_FOR_DEG_VARIABLE].value_counts())
# display(adata.obs[CONTRAST_VARIABLE].value_counts())
# sns.lmplot(data=adata.obs.drop_duplicates(SAMPLE_VARIABLE), x="age_of_death", y="total_counts", hue=CONTRAST_VARIABLE)
# adata
# Out:
# /tmp/ipykernel_26969/988220494.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adata.obs[CT_FOR_DEG_VARIABLE].replace({"Matrix_D1": "Matrix", "Matrix_D2": "Matrix", "Patch_D1": "Patch", "Patch_D2": "Patch"}, inplace=True)

# %%
# RUN_ON_ZONES = False # if False, will run on ct

# if RUN_ON_ZONES:

#     ZONE_CT = "Astrocyte" #Astrocyte, Matrix_D1

#     # Each cell type has a better zonation level
#     if ZONE_CT in ["Matrix_D1", "Matrix_D2"]:
#         ZONE_VARIABLE = "zone_6" 
#     if ZONE_CT in ["Patch_D1", "Patch_D2", "eMSN_D1D2", "Astrocyte"]:
#         ZONE_VARIABLE = "zone_4"

#     adata = adata[
#         (adata.obs["ct_for_deg"] == ZONE_CT) & # only QC cells tat are matrix
#         (adata.obs[ZONE_VARIABLE].notna()) # only cells with zone annotation
#     ].to_memory().copy()
    
#     # chnage zone to be treated as ct
#     CT_FOR_DEG_VARIABLE = ZONE_VARIABLE

#     print(adata)
#     print(adata.obs.groupby([ZONE_VARIABLE, CONTRAST_VARIABLE]).size())

# %% [markdown]
# # Define gradient genes

# %%
# GRAD_THR=0.1

# df_grad = pd.read_csv("/home/gdallagl/myworkdir/XDP/utils/dorsal_ventral_gradient/exp_by_spline_combined.csv")

# grad_genes = df_grad[
#     (np.abs(df_grad.mean_spearman)>= GRAD_THR) & 
#     (df_grad.combined_p <= 0.05) &
#     (df_grad.mean_spearman.notna()) 
#     ]["gene"].tolist()
# print(len(grad_genes))

# df_grad["is_gradient_gene"] = df_grad["gene"].isin(grad_genes)
# print(df_grad["is_gradient_gene"].sum())
# df_grad = df_grad.set_index("gene")[["mean_spearman", "is_gradient_gene"]]
# df_grad
# Out:
# 1241
# 1241
#                  mean_spearman  is_gradient_gene
# gene
# A1BG                 -0.002360             False
# A1BG-AS1             -0.007881             False
# A1CF                  0.007398             False
# A2M                  -0.002144             False
# A2M-AS1              -0.000389             False
# ...                        ...               ...
# ENSG00000277836            NaN             False
# ENSG00000278633            NaN             False
# ENSG00000276017      -0.008289             False
# ENSG00000278817      -0.027789             False
# ENSG00000277196       0.004669             False
#
# [51543 rows x 2 columns]

# %% [markdown]
# # Calcualte DV score from splines

# %%
# Genes whose Matrix/Patch spatial gradient (health vs XDP, from the BICAN spatial-spline
# analysis) is strong AND agrees in sign in BOTH conditions - i.e. disease-invariant spatial
# markers. Deliberately NOT genes whose gradient differs between health/XDP: those are
# candidate DEG hits themselves, and scoring cells with the genes being tested would regress
# a gene's DE signal out against itself.

CORR_DIR = "/home/gdallagl/myworkdir/XDP/data/BICAN/bican_spatial_zonated/genes_correlation"
STABLE_GRAD_THR           = 0.2   # minimum |rho| in EACH condition to count as "has gradient"
STABLE_GRAD_PADJ_THR      = 0.05
STABLE_GRAD_MIN_PCT_EXPR  = 0.20
STABLE_GRAD_MIN_MEAN_EXPR = 0.10

df_corr_health = pd.read_csv(f"{CORR_DIR}/df_corr.csv", index_col=0)
df_corr_xdp    = pd.read_csv(f"{CORR_DIR}/df_corr_xdp.csv", index_col=0)
common_genes   = df_corr_health.index.intersection(df_corr_xdp.index)

stable_grad_weight = {}   # ct -> Series(gene -> weight), weight = mean(rho_health, rho_XDP)
for ct in ["Matrix", "Patch", "eMSN"]:
    dfh, dfx = df_corr_health.loc[common_genes], df_corr_xdp.loc[common_genes]
    rho_h, rho_x = dfh[f"rho_{ct}"], dfx[f"rho_{ct}"]

    reliable_h = (dfh[f"padj_{ct}"] < STABLE_GRAD_PADJ_THR) & (dfh[f"pct_expr_{ct}"] >= STABLE_GRAD_MIN_PCT_EXPR) & (dfh[f"mean_expr_{ct}"] >= STABLE_GRAD_MIN_MEAN_EXPR)
    reliable_x = (dfx[f"padj_{ct}"] < STABLE_GRAD_PADJ_THR) & (dfx[f"pct_expr_{ct}"] >= STABLE_GRAD_MIN_PCT_EXPR) & (dfx[f"mean_expr_{ct}"] >= STABLE_GRAD_MIN_MEAN_EXPR)

    stable = (
        (rho_h.abs() >= STABLE_GRAD_THR) & (rho_x.abs() >= STABLE_GRAD_THR) &
        (np.sign(rho_h) == np.sign(rho_x)) &
        reliable_h & reliable_x
    ).fillna(False)

    genes_ct = common_genes[stable]
    stable_grad_weight[ct] = pd.concat([rho_h[genes_ct], rho_x[genes_ct]], axis=1).mean(axis=1)
    print(f"{ct}: {len(genes_ct)} stable gradient genes (agree in sign, health & XDP)")

stable_grad_weight
# Out:
# Matrix: 339 stable gradient genes (agree in sign, health & XDP)
# Patch: 163 stable gradient genes (agree in sign, health & XDP)
# eMSN: 231 stable gradient genes (agree in sign, health & XDP)
# {'Matrix': ABHD12B    0.292252
#  ABI3BP    -0.314378
#  ABLIM1    -0.445626
#  ACTG1     -0.258578
#  ADAM12     0.395667
#               ...
#  YWHAZ     -0.222178
#  ZBTB20    -0.357788
#  ZMAT4      0.262138
#  ZNF385B    0.615598
#  ZNF706    -0.222404
#  Length: 339, dtype: float64,
#  'Patch': ABI3BP    -0.239441
#  ABLIM1    -0.373840
#  ADCY5      0.304601
#  ADRB1     -0.254576
#  AFF3       0.308055
#               ...
#  WSB1      -0.207514
#  ZBTB20    -0.342757
#  ZDHHC23   -0.271289
#  ZNF385B    0.425977
#  ZNF706    -0.218994
#  Length: 163, dtype: float64,
#  'eMSN': ADARB2       0.274372
#  ADGRB3-DT   -0.333795
#  AFF3         0.247025
#  AK5         -0.324430
#  ANKRD29      0.256143
#                 ...
#  TTLL11       0.384468
#  UNC5C       -0.416131
#  WLS          0.414881
#  ZBTB20      -0.230607
#  ZNF385B      0.500982
#  Length: 231, dtype: float64}

# %%
def calc_gradient_score(adata, gene_weights, ct_col="ct_for_deg", score_col="gradient_score"):
    """Score every cell by its predicted position along the Matrix/Patch dorsal-ventral
    spatial gradient, using per-cell-type gene weights (dict: ct -> Series[gene -> weight],
    weight = mean spatial rho in health & XDP - see "Define gradient genes" above).

    ATTENTION: adata.X must be raw counts.
    ATTENTION: cells whose ct_col value isn't a key of `gene_weights` get NaN (e.g. glia).

    Each gene is z-scored across cells of its own cell type before being weighted by rho, so
    a highly-expressed-but-weakly-correlated gene can't dominate a lowly-expressed-but-
    strongly-correlated one purely by scale - only how informative the gene actually is about
    position (its rho) determines its contribution to the score.
    """
    sc.pp.normalize_total(adata, target_sum=1e4)
    sc.pp.log1p(adata)

    adata.obs[score_col] = np.nan

    for ct, weight in gene_weights.items():
        cell_mask = (adata.obs[ct_col] == ct).values
        if cell_mask.sum() == 0:
            continue

        genes_here = [g for g in weight.index if g in adata.var_names]
        print(f"{ct}: scoring {cell_mask.sum()} cells with {len(genes_here)}/{len(weight)} gradient genes found in adata")

        X = adata[cell_mask, genes_here].X
        X = X.toarray() if sparse.issparse(X) else np.asarray(X)
        X = (X - X.mean(axis=0)) / (X.std(axis=0) + 1e-9)   # z-score per gene, within this cell type

        adata.obs.loc[cell_mask, score_col] = X @ weight.loc[genes_here].values

    return adata

# %%
save_csv_path = f"{os.path.dirname(ADATA_PATH)}/gradient_scores.csv"

if not os.path.exists(save_csv_path):
    adata.X = adata.layers["counts"].copy()  # use raw counts for score calculation
    adata = calc_gradient_score(adata, stable_grad_weight, ct_col=CT_FOR_DEG_VARIABLE)
    adata.obs[["gradient_score"]].to_csv(save_csv_path)
else:
    df_scores = pd.read_csv(save_csv_path, index_col=0)
    adata.obs = adata.obs.merge(df_scores, how="left", left_index=True, right_index=True, validate="one_to_one")

# only Matrix/Patch cells are expected to have a score - other cell types are outside the
# scope of stable_grad_weight (glia etc. were never spatially gradient-tested) and stay NaN
assert not adata.obs.loc[adata.obs[CT_FOR_DEG_VARIABLE].isin(stable_grad_weight.keys()), "gradient_score"].isna().any(), \
    "Some Matrix/Patch cells have no gradient score!"
# Out:
# WARNING: adata.X seems to be already log-transformed.
# Matrix: scoring 22782 cells with 339/339 gradient genes found in adata
# Patch: scoring 7269 cells with 163/163 gradient genes found in adata

# %%
adata.obs["gradient_score"]

for ct in ["Matrix", "Patch", "eMSN_D1D2"]:
    sns.histplot(data=adata.obs[adata.obs[CT_FOR_DEG_VARIABLE] == ct], x="gradient_score", hue=CONTRAST_VARIABLE, bins=50, stat="density", common_norm=False); plt.title(ct); plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 4
#       1 adata.obs["gradient_score"]
#       3 for ct in ["Matrix", "Patch", "eMSN_D1D2"]:
# ----> 4     sns.histplot(data=adata.obs[adata.obs[CT_FOR_DEG_VARIABLE] == ct], x="gradient_score", hue=CONTRAST_VARIABLE, bins=50, stat="density", common_norm=False); plt.title(ct); plt.show()
#
# File ~/myworkdir/XDP/.venv/lib/python3.11/site-packages/seaborn/distributions.py:1416, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1405 estimate_kws = dict(
#    1406     stat=stat,
#    1407     bins=bins,
#    (...)   1411     cumulative=cumulative,
#    1412 )
#    1414 if p.univariate:
# -> 1416     p.plot_univariate_histogram(
#    1417         multiple=multiple,
#    1418         element=element,
#    1419         fill=fill,
#    1420         shrink=shrink,
#    1421         common_norm=common_norm,
#    1422         common_bins=common_bins,
#    1423         kde=kde,
#    1424         kde_kws=kde_kws,
#    1425         color=color,
#    1426         legend=legend,
#    1427         estimate_kws=estimate_kws,
#    1428         line_kws=line_kws,
#    1429         **kwargs,
#    1430     )
#    1432 else:
#    1434     p.plot_bivariate_histogram(
#    1435         common_bins=common_bins,
#    1436         common_norm=common_norm,
#    (...)   1446         **kwargs,
#    1447     )
#
# File ~/myworkdir/XDP/.venv/lib/python3.11/site-packages/seaborn/distributions.py:665, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     658             line.sticky_edges.y[:] = sticky_y
#     660 if element == "bars" and "linewidth" not in plot_kws:
#     661
#     662     # Now we handle linewidth, which depends on the scaling of the plot
#     663
#     664     # We will base everything on the minimum bin width
# --> 665     hist_metadata = pd.concat([
#     666         # Use .items for generality over dict or df
#     667         h.index.to_frame() for _, h in histograms.items()
#     668     ]).reset_index(drop=True)
#     669     thin_bar_idx = hist_metadata["widths"].idxmin()
#     670     binwidth = hist_metadata.loc[thin_bar_idx, "widths"]
#
# File ~/myworkdir/XDP/.venv/lib/python3.11/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File ~/myworkdir/XDP/.venv/lib/python3.11/site-packages/pandas/core/reshape/concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File ~/myworkdir/XDP/.venv/lib/python3.11/site-packages/pandas/core/reshape/concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %% [markdown]
# # DV score, Matrix Vs D1D2

# %%
# ============================================================
# DEG: Matrix vs eMSN_D1D2, with DV (gradient) score as covariate
# ============================================================
# ATTENTION: eMSN_D1D2 was dropped from `adata` earlier (the "just one mix d1 and d2" cell
# restricts to Matrix_D1/D2 + Patch_D1/D2 only) -> reload a fresh subset here instead of
# reusing the module-level `adata`.

CT_BASELINE = "Matrix"
CT_STIM = "eMSN_D1D2"

# Restrict to one disease condition before comparing cell types, or None to pool both
# conditions and add `condition` itself as a covariate instead.
#   "Control" -> only healthy donors
#   "XDP"     -> only XDP donors
#   None      -> keep both, condition becomes a covariate
CONDITION_FILTER = "XDP"  # "Control", "XDP", or None

adata_full = sc.read_h5ad(ADATA_PATH)
adata_full.var.index = adata_full.var["gene_symbol"]
adata_full = adata_full[~adata_full.obs["ct_for_deg"].str.startswith("-"), :].copy()
adata_full.obs[CT_FOR_DEG_VARIABLE] = adata_full.obs[CT_FOR_DEG_VARIABLE].str.replace(" ", "_")
adata_full = adata_full[~adata_full.obs[CONTRAST_VARIABLE].isna()].copy()

# ATTENTION: merge Matrix_D1/Matrix_D2 -> "Matrix" (mirrors the "just one mix d1 and d2" cell
# above) so CT_BASELINE="Matrix" actually matches something; eMSN_D1D2 has no D1/D2 split to merge.
adata_full = adata_full[adata_full.obs[CT_FOR_DEG_VARIABLE].isin(["Matrix_D1", "Matrix_D2", CT_STIM])].copy()
adata_full.obs[CT_FOR_DEG_VARIABLE] = adata_full.obs[CT_FOR_DEG_VARIABLE].replace({"Matrix_D1": "Matrix", "Matrix_D2": "Matrix"})

adata_ctc = adata_full[adata_full.obs[CT_FOR_DEG_VARIABLE].isin([CT_BASELINE, CT_STIM])].to_memory().copy()
del adata_full

if CONDITION_FILTER is not None:
    adata_ctc = adata_ctc[adata_ctc.obs[CONTRAST_VARIABLE] == CONDITION_FILTER].copy()

print(adata_ctc.obs.groupby([CT_FOR_DEG_VARIABLE, CONTRAST_VARIABLE]).size())

# --- gradient/DV score, extended to cover eMSN_D1D2 ---
# df_corr_health / df_corr_xdp (loaded above, "Define gradient genes" section) already carry
# rho_eMSN / padj_eMSN / pct_expr_eMSN / mean_expr_eMSN columns for the eMSN_D1D2 compartment
# (see gradients_in_STR/find_spatial_grad_gene_MSN_types_refactored.ipynb) - column suffix is
# "eMSN", not "eMSN_D1D2", hence the col_suffix map below.
col_suffix = {CT_BASELINE: "Matrix", CT_STIM: "eMSN"}

stable_grad_weight_ctc = {}
for ct in [CT_BASELINE, CT_STIM]:
    suf = col_suffix[ct]
    dfh, dfx = df_corr_health.loc[common_genes], df_corr_xdp.loc[common_genes]
    rho_h, rho_x = dfh[f"rho_{suf}"], dfx[f"rho_{suf}"]

    reliable_h = (dfh[f"padj_{suf}"] < STABLE_GRAD_PADJ_THR) & (dfh[f"pct_expr_{suf}"] >= STABLE_GRAD_MIN_PCT_EXPR) & (dfh[f"mean_expr_{suf}"] >= STABLE_GRAD_MIN_MEAN_EXPR)
    reliable_x = (dfx[f"padj_{suf}"] < STABLE_GRAD_PADJ_THR) & (dfx[f"pct_expr_{suf}"] >= STABLE_GRAD_MIN_PCT_EXPR) & (dfx[f"mean_expr_{suf}"] >= STABLE_GRAD_MIN_MEAN_EXPR)

    stable = (
        (rho_h.abs() >= STABLE_GRAD_THR) & (rho_x.abs() >= STABLE_GRAD_THR) &
        (np.sign(rho_h) == np.sign(rho_x)) &
        reliable_h & reliable_x
    ).fillna(False)

    genes_ct = common_genes[stable]
    stable_grad_weight_ctc[ct] = pd.concat([rho_h[genes_ct], rho_x[genes_ct]], axis=1).mean(axis=1)
    print(f"{ct}: {len(genes_ct)} stable gradient genes (agree in sign, health & XDP)")

adata_ctc.X = adata_ctc.layers["counts"].copy()  # calc_gradient_score requires raw counts
adata_ctc = calc_gradient_score(adata_ctc, stable_grad_weight_ctc, ct_col=CT_FOR_DEG_VARIABLE, score_col="gradient_score")
assert not adata_ctc.obs["gradient_score"].isna().any(), "Some cells have no gradient score!"
adata_ctc.X = adata_ctc.layers["counts"].copy()  # calc_gradient_score log-normalized X in place -> reset to raw counts for nebula

# --- covariates: gradient_score always in; condition only if we didn't already filter on it ---
covariates_ctc = list(COVARIATES_FOR_DEG) + ["gradient_score"]
if CONDITION_FILTER is None:
    covariates_ctc.append(CONTRAST_VARIABLE)

# --- run nebula with cell type as the contrast ---
subfolder = f"{CT_BASELINE}_vs_{CT_STIM}" + (f"_{CONDITION_FILTER}" if CONDITION_FILTER else "_allConditions")
ADATA_PATH_QS = f"{DEG_FOLDER}/{subfolder}/tmp_{os.path.splitext(os.path.basename(ADATA_PATH))[0]}_{subfolder}_for_nebula.qs"
SAVE_HEALTHY_PCA_RESULT = os.path.dirname(ADATA_PATH_QS)
os.makedirs(SAVE_HEALTHY_PCA_RESULT, exist_ok=True)
print(ADATA_PATH_QS)

_nebula_dir = f"{os.path.splitext(ADATA_PATH_QS)[0]}__nebula_ln"
if os.path.exists(_nebula_dir):
    shutil.rmtree(_nebula_dir)

nebula_utils.run_nebula_with_factors(
    adata_ctc,
    ADATA_PATH_QS, SAVE_HEALTHY_PCA_RESULT, PARALLEL_NEBULA_SCRIPT_PATH,
    CT_FOR_DEG_VARIABLE, CT_BASELINE, CT_STIM,
    SAMPLE_VARIABLE, LIBRARY_SIZE_COL, covariates_ctc,
    N_PCS_TO_USE=None, variance_threshold=None, delete_tmp_files=True, TYPE_DEG=TYPE_DEG,
    MIN_SAMPLES_PER_CONDITION=4, MIN_NUMBER_GENES_PER_ANALYSIS=3000,
    CNMF_SPECTRA_PATH=None,
)
# Out:
# /tmp/ipykernel_26969/2662834106.py:35: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(adata_ctc.obs.groupby([CT_FOR_DEG_VARIABLE, CONTRAST_VARIABLE]).size())
# ct_for_deg  condition
# Matrix      XDP          8102
# eMSN_D1D2   XDP          1746
# dtype: int64
# Matrix: 339 stable gradient genes (agree in sign, health & XDP)
# eMSN_D1D2: 231 stable gradient genes (agree in sign, health & XDP)
# WARNING: adata.X seems to be already log-transformed.
# Matrix: scoring 8102 cells with 339/339 gradient genes found in adata
# eMSN_D1D2: scoring 1746 cells with 230/231 gradient genes found in adata
# /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula.qs
# True
# ATTENTION: .X must be raw!
# Retained donors : 30
# Filtered genes  : 38601 -> 18781 (min_cells=300, min_counts=50)
# Running Factor calculation on Healthy...
# Running Factor calculation on Diseased...
# Saving h5ad file...
# adata intact: 9848 cells, 18781 genes
# ATTENTION: Dropping 0 cells with NaN covariates: []
# ... storing 'ct_for_deg' as categorical
# ~ ct_for_deg + age_of_death + sex + pct_counts_mt + frac_intronic + cohort + gradient_score + gradient_score + total_counts
# 2026-07-22 18:59:30 | [WARNING] R callback write-console: ct_for_deg: factor | example: Matrix
#
# 2026-07-22 18:59:30 | [WARNING] R callback write-console: donor_id: character | example: SCF-18-004
#
# 2026-07-22 18:59:30 | [WARNING] R callback write-console: age_of_death: numeric | example: 56
#
# 2026-07-22 18:59:30 | [WARNING] R callback write-console: sex: character | example: M
#
# 2026-07-22 18:59:30 | [WARNING] R callback write-console: pct_counts_mt: numeric | example: 0.0388265746333046
#
# 2026-07-22 18:59:30 | [WARNING] R callback write-console: frac_intronic: numeric | example: 0.762041613978618
#
# 2026-07-22 18:59:30 | [WARNING] R callback write-console: cohort: character | example: Cohort_1
#
# 2026-07-22 18:59:30 | [WARNING] R callback write-console: gradient_score: numeric | example: -15.0579455980426
#
# 2026-07-22 18:59:30 | [WARNING] R callback write-console: gradient_score.1: numeric | example: -15.0579455980426
#                   variable         VIF
# 0                Intercept  469.100728
# 4       cohort[T.Cohort_3]    2.434967
# 9             total_counts    2.376146
# 3       cohort[T.Cohort_2]    2.060041
# 6            pct_counts_mt    1.666433
# 7            frac_intronic    1.498679
# 8           gradient_score    1.232066
# 1  ct_for_deg[T.eMSN_D1D2]    1.227504
# 5             age_of_death    1.111655
# 2                 sex[T.M]    1.094086
#
# binary identifiability test. False
# 2026-07-22 18:59:30 | [WARNING] R callback write-console:
# Fitting: gradient_score ~ ct_for_deg + age_of_death + sex + pct_counts_mt + frac_intronic + cohort + gradient_score + (1|donor_id)
#
# 2026-07-22 18:59:30 | [WARNING] R callback write-console: In addition:
# 2026-07-22 18:59:30 | [WARNING] R callback write-console: Warning messages:
#
# 2026-07-22 18:59:30 | [WARNING] R callback write-console: 1:
# 2026-07-22 18:59:30 | [WARNING] R callback write-console: In model.matrix.default(fixedform, fr, contrasts) :
# 2026-07-22 18:59:30 | [WARNING] R callback write-console:
#
# 2026-07-22 18:59:30 | [WARNING] R callback write-console:  the response appeared on the right-hand side and was dropped
#
# 2026-07-22 18:59:30 | [WARNING] R callback write-console: 2:
# 2026-07-22 18:59:30 | [WARNING] R callback write-console: In model.matrix.default(fixedform, fr, contrasts) :
# 2026-07-22 18:59:30 | [WARNING] R callback write-console:
#
# 2026-07-22 18:59:30 | [WARNING] R callback write-console:  problem with term 7 in model.matrix: no columns are assigned
#
# 2026-07-22 18:59:30 | [WARNING] R callback write-console: 3:
# 2026-07-22 18:59:30 | [WARNING] R callback write-console: In model.matrix.default(fixedform, fr, contrasts) :
# 2026-07-22 18:59:30 | [WARNING] R callback write-console:
#
# 2026-07-22 18:59:30 | [WARNING] R callback write-console:  the response appeared on the right-hand side and was dropped
#
# 2026-07-22 18:59:30 | [WARNING] R callback write-console: 4:
# 2026-07-22 18:59:30 | [WARNING] R callback write-console: In model.matrix.default(fixedform, fr, contrasts) :
# 2026-07-22 18:59:30 | [WARNING] R callback write-console:
#
# 2026-07-22 18:59:30 | [WARNING] R callback write-console:  problem with term 7 in model.matrix: no columns are assigned
#         factor      beta      se  p_value      fdr
# gradient_score -1.295711 0.78663 0.099556 0.099556
# Saving qs file...
# 	Saving files for R coversion...
# 	Building R obj...
#
# Setting ct_for_deg reference level to: Matrix
# Levels: Matrix eMSN_D1D2
# [1] "Creating Seurat object..."
# 2026-07-22 19:00:05 | [WARNING] R callback write-console: Warning:
# 2026-07-22 19:00:05 | [WARNING] R callback write-console:  Data is of class dgTMatrix. Coercing to dgCMatrix.
# [1] "Saving Seurat object as .qs..."
# Running Nebula...
# cmd list: ['bash', '/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/run-nebula-parallel.sh', '--path', '/home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula.qs', '--id-col', 'donor_id', '--offset-col', 'total_counts', '--n-folds', '40', '--n-cores', '40', '--save-tmp', '0']
# Running command: bash /home/gdallagl/myworkdir/XDP/utils/nebula_scripts/run-nebula-parallel.sh --path /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula.qs --id-col donor_id --offset-col total_counts --n-folds 40 --n-cores 40 --save-tmp 0
# Running command: bash /home/gdallagl/myworkdir/XDP/utils/nebula_scripts/run-nebula-parallel.sh --path /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula.qs --id-col donor_id --offset-col total_counts --n-folds 40 --n-cores 40 --save-tmp 0 --covs ct_for_deg,age_of_death,sex,pct_counts_mt,frac_intronic,cohort,gradient_score,gradient_score
# ================================================================================
# [INFO] Input: /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula.qs
# [INFO] Script dir: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [INFO] Base name: tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula.qs
# [INFO] Geneset dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP
# [INFO] Geneset: Matrix_vs_eMSN_D1D2_XDP
# [INFO] Split dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula
# [INFO] Split: gradient_score_nebula
# [INFO] n-folds: 40
# [INFO] parallel jobs: 40
# [INFO] id-col: donor_id
# [INFO] covs:
#        - ct_for_deg
#        - age_of_death
#        - sex
#        - pct_counts_mt
#        - frac_intronic
#        - cohort
#        - gradient_score
#        - gradient_score
# [INFO] offset-col: total_counts  -> will create meta 'nUMI_nebula'
# [INFO] Tmp dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln
# [INFO] Chunks dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks
# [INFO] Tmp de_dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results/
# [INFO] final_dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/de_results/nebula_ln
# [INFO] nebula_out_basename: tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln_combined.qs
# [INFO] Final combined results: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/de_results/nebula_ln/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln_combined.qs
#
# ***** LOADING sobj: /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula.qs
# Splitting 18781 genes into 40 chunks
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_001_of_040.qs (genes 1 --> 470; nGenes=470)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_002_of_040.qs (genes 471 --> 940; nGenes=470)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_003_of_040.qs (genes 941 --> 1410; nGenes=470)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_004_of_040.qs (genes 1411 --> 1880; nGenes=470)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_005_of_040.qs (genes 1881 --> 2350; nGenes=470)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_006_of_040.qs (genes 2351 --> 2820; nGenes=470)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_007_of_040.qs (genes 2821 --> 3290; nGenes=470)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_008_of_040.qs (genes 3291 --> 3760; nGenes=470)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_009_of_040.qs (genes 3761 --> 4230; nGenes=470)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_010_of_040.qs (genes 4231 --> 4700; nGenes=470)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_011_of_040.qs (genes 4701 --> 5170; nGenes=470)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_012_of_040.qs (genes 5171 --> 5640; nGenes=470)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_013_of_040.qs (genes 5641 --> 6110; nGenes=470)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_014_of_040.qs (genes 6111 --> 6580; nGenes=470)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_015_of_040.qs (genes 6581 --> 7050; nGenes=470)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_016_of_040.qs (genes 7051 --> 7520; nGenes=470)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_017_of_040.qs (genes 7521 --> 7990; nGenes=470)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_018_of_040.qs (genes 7991 --> 8460; nGenes=470)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_019_of_040.qs (genes 8461 --> 8930; nGenes=470)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_020_of_040.qs (genes 8931 --> 9400; nGenes=470)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_021_of_040.qs (genes 9401 --> 9870; nGenes=470)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_022_of_040.qs (genes 9871 --> 10339; nGenes=469)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_023_of_040.qs (genes 10340 --> 10808; nGenes=469)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_024_of_040.qs (genes 10809 --> 11277; nGenes=469)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_025_of_040.qs (genes 11278 --> 11746; nGenes=469)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_026_of_040.qs (genes 11747 --> 12215; nGenes=469)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_027_of_040.qs (genes 12216 --> 12684; nGenes=469)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_028_of_040.qs (genes 12685 --> 13153; nGenes=469)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_029_of_040.qs (genes 13154 --> 13622; nGenes=469)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_030_of_040.qs (genes 13623 --> 14091; nGenes=469)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_031_of_040.qs (genes 14092 --> 14560; nGenes=469)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_032_of_040.qs (genes 14561 --> 15029; nGenes=469)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_033_of_040.qs (genes 15030 --> 15498; nGenes=469)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_034_of_040.qs (genes 15499 --> 15967; nGenes=469)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_035_of_040.qs (genes 15968 --> 16436; nGenes=469)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_036_of_040.qs (genes 16437 --> 16905; nGenes=469)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_037_of_040.qs (genes 16906 --> 17374; nGenes=469)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_038_of_040.qs (genes 17375 --> 17843; nGenes=469)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_039_of_040.qs (genes 17844 --> 18312; nGenes=469)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_040_of_040.qs (genes 18313 --> 18781; nGenes=469)
# ***** SPLITTING DONE.
#
# [INFO] Launching chunk jobs with GNU parallel...
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_028_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_028_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_006_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_006_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_021_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_021_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_026_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_026_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_004_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_004_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_017_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_017_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_024_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_024_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_008_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_008_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "Extracted 469 genes and 9848 cells"
# [1] "Formula: ~ct_for_deg+age_of_death+sex+pct_counts_mt+frac_intronic+cohort+gradient_score+gradient_score"
# [1] "Covariate types:"
#       ct_for_deg     age_of_death              sex    pct_counts_mt
#         "factor"        "numeric"      "character"        "numeric"
#    frac_intronic           cohort   gradient_score gradient_score.1
#        "numeric"      "character"        "numeric"        "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"         "ct_for_degeMSN_D1D2" "age_of_death"
# [4] "sexM"                "pct_counts_mt"       "frac_intronic"
# [7] "cohortCohort_2"      "cohortCohort_3"      "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "Extracted 470 genes and 9848 cells"
# [1] "Formula: ~ct_for_deg+age_of_death+sex+pct_counts_mt+frac_intronic+cohort+gradient_score+gradient_score"
# [1] "Covariate types:"
#       ct_for_deg     age_of_death              sex    pct_counts_mt
#         "factor"        "numeric"      "character"        "numeric"
#    frac_intronic           cohort   gradient_score gradient_score.1
#        "numeric"      "character"        "numeric"        "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"         "ct_for_degeMSN_D1D2" "age_of_death"
# [4] "sexM"                "pct_counts_mt"       "frac_intronic"
# [7] "cohortCohort_2"      "cohortCohort_3"      "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "Extracted 470 genes and 9848 cells"
# [1] "Formula: ~ct_for_deg+age_of_death+sex+pct_counts_mt+frac_intronic+cohort+gradient_score+gradient_score"
# [1] "Covariate types:"
#       ct_for_deg     age_of_death              sex    pct_counts_mt
#         "factor"        "numeric"      "character"        "numeric"
#    frac_intronic           cohort   gradient_score gradient_score.1
#        "numeric"      "character"        "numeric"        "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"         "ct_for_degeMSN_D1D2" "age_of_death"
# [4] "sexM"                "pct_counts_mt"       "frac_intronic"
# [7] "cohortCohort_2"      "cohortCohort_3"      "gradient_score"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "Extracted 469 genes and 9848 cells"
# [1] "Formula: ~ct_for_deg+age_of_death+sex+pct_counts_mt+frac_intronic+cohort+gradient_score+gradient_score"
# [1] "Covariate types:"
#       ct_for_deg     age_of_death              sex    pct_counts_mt
#         "factor"        "numeric"      "character"        "numeric"
#    frac_intronic           cohort   gradient_score gradient_score.1
#        "numeric"      "character"        "numeric"        "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"         "ct_for_degeMSN_D1D2" "age_of_death"
# [4] "sexM"                "pct_counts_mt"       "frac_intronic"
# [7] "cohortCohort_2"      "cohortCohort_3"      "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "Extracted 470 genes and 9848 cells"
# [1] "Formula: ~ct_for_deg+age_of_death+sex+pct_counts_mt+frac_intronic+cohort+gradient_score+gradient_score"
# [1] "Covariate types:"
#       ct_for_deg     age_of_death              sex    pct_counts_mt
#         "factor"        "numeric"      "character"        "numeric"
#    frac_intronic           cohort   gradient_score gradient_score.1
#        "numeric"      "character"        "numeric"        "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"         "ct_for_degeMSN_D1D2" "age_of_death"
# [4] "sexM"                "pct_counts_mt"       "frac_intronic"
# [7] "cohortCohort_2"      "cohortCohort_3"      "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "Extracted 469 genes and 9848 cells"
# [1] "Formula: ~ct_for_deg+age_of_death+sex+pct_counts_mt+frac_intronic+cohort+gradient_score+gradient_score"
# [1] "Covariate types:"
#       ct_for_deg     age_of_death              sex    pct_counts_mt
#         "factor"        "numeric"      "character"        "numeric"
#    frac_intronic           cohort   gradient_score gradient_score.1
#        "numeric"      "character"        "numeric"        "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"         "ct_for_degeMSN_D1D2" "age_of_death"
# [4] "sexM"                "pct_counts_mt"       "frac_intronic"
# [7] "cohortCohort_2"      "cohortCohort_3"      "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "Extracted 470 genes and 9848 cells"
# [1] "Formula: ~ct_for_deg+age_of_death+sex+pct_counts_mt+frac_intronic+cohort+gradient_score+gradient_score"
# [1] "Covariate types:"
#       ct_for_deg     age_of_death              sex    pct_counts_mt
#         "factor"        "numeric"      "character"        "numeric"
#    frac_intronic           cohort   gradient_score gradient_score.1
#        "numeric"      "character"        "numeric"        "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"         "ct_for_degeMSN_D1D2" "age_of_death"
# [4] "sexM"                "pct_counts_mt"       "frac_intronic"
# [7] "cohortCohort_2"      "cohortCohort_3"      "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  469  genes with  30  subjects and  9848  cells.
# Remove  0  genes having low expression.
# Analyzing  470  genes with  30  subjects and  9848  cells.
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# Remove  0  genes having low expression.
# Analyzing  470  genes with  30  subjects and  9848  cells.
# [1] "Extracted 470 genes and 9848 cells"
# [1] "Formula: ~ct_for_deg+age_of_death+sex+pct_counts_mt+frac_intronic+cohort+gradient_score+gradient_score"
# [1] "Covariate types:"
#       ct_for_deg     age_of_death              sex    pct_counts_mt
#         "factor"        "numeric"      "character"        "numeric"
#    frac_intronic           cohort   gradient_score gradient_score.1
#        "numeric"      "character"        "numeric"        "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"         "ct_for_degeMSN_D1D2" "age_of_death"
# [4] "sexM"                "pct_counts_mt"       "frac_intronic"
# [7] "cohortCohort_2"      "cohortCohort_3"      "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  469  genes with  30  subjects and  9848  cells.
# Remove  0  genes having low expression.
# Analyzing  470  genes with  30  subjects and  9848  cells.
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# Remove  0  genes having low expression.
# Analyzing  469  genes with  30  subjects and  9848  cells.
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# Remove  0  genes having low expression.
# Analyzing  470  genes with  30  subjects and  9848  cells.
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# Remove  0  genes having low expression.
# Analyzing  470  genes with  30  subjects and  9848  cells.
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_018_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_018_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_014_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_014_of_040.qs ****************
# [1] "Extracted 470 genes and 9848 cells"
# [1] "Formula: ~ct_for_deg+age_of_death+sex+pct_counts_mt+frac_intronic+cohort+gradient_score+gradient_score"
# [1] "Covariate types:"
#       ct_for_deg     age_of_death              sex    pct_counts_mt
#         "factor"        "numeric"      "character"        "numeric"
#    frac_intronic           cohort   gradient_score gradient_score.1
#        "numeric"      "character"        "numeric"        "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"         "ct_for_degeMSN_D1D2" "age_of_death"
# [4] "sexM"                "pct_counts_mt"       "frac_intronic"
# [7] "cohortCohort_2"      "cohortCohort_3"      "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_039_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_039_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_010_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_010_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# Remove  0  genes having low expression.
# Analyzing  470  genes with  30  subjects and  9848  cells.
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_027_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_027_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_019_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_019_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_031_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_031_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_013_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_013_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_015_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_015_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_025_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_025_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_038_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_038_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_022_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/chunks/chunk_022_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# ...
# Analyzing  469  genes with  30  subjects and  9848  cells.
# Remove  0  genes having low expression.
# Analyzing  469  genes with  30  subjects and  9848  cells.
# Remove  0  genes having low expression.
# Analyzing  470  genes with  30  subjects and  9848  cells.
# Remove  0  genes having low expression.
# Analyzing  470  genes with  30  subjects and  9848  cells.
# Remove  0  genes having low expression.
# Analyzing  469  genes with  30  subjects and  9848  cells.
# Remove  0  genes having low expression.
# Analyzing  470  genes with  30  subjects and  9848  cells.
# Remove  0  genes having low expression.
# Analyzing  469  genes with  30  subjects and  9848  cells.
# Remove  0  genes having low expression.
# Analyzing  470  genes with  30  subjects and  9848  cells.
# Remove  0  genes having low expression.
# Analyzing  470  genes with  30  subjects and  9848  cells.
# Remove  0  genes having low expression.
# Analyzing  469  genes with  30  subjects and  9848  cells.
# Remove  0  genes having low expression.
# Analyzing  470  genes with  30  subjects and  9848  cells.
# Remove  0  genes having low expression.
# Analyzing  469  genes with  30  subjects and  9848  cells.
# Remove  0  genes having low expression.
# Analyzing  470  genes with  30  subjects and  9848  cells.
# Remove  0  genes having low expression.
# Analyzing  469  genes with  30  subjects and  9848  cells.
# Remove  0  genes having low expression.
# Analyzing  470  genes with  30  subjects and  9848  cells.
# Remove  0  genes having low expression.
# Analyzing  470  genes with  30  subjects and  9848  cells.
# Remove  0  genes having low expression.
# Analyzing  469  genes with  30  subjects and  9848  cells.
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_026_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_004_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_028_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_001_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_021_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_039_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_014_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_024_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_018_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_030_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_008_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_036_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_006_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_031_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_035_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_038_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_016_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_029_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_017_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_003_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_022_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_025_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_002_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_020_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_037_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_027_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_032_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_033_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_019_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_010_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_023_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_007_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_034_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_013_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_012_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_015_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_005_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_009_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_011_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln/de_results//chunk_040_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# [INFO] All chunk jobs completed.
#
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# ***** Combined NEBULA results written to: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/de_results/nebula_ln/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln_combined.qs
# [INFO] Final combined results: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/de_results/nebula_ln/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln_combined.qs
# [INFO] Removing tmp dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix_vs_eMSN_D1D2_XDP/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_vs_eMSN_D1D2_XDP_for_nebula__nebula_ln
# [ALL DONE]
# ================================================================================

# %% [markdown]
# # Calculate gradient score

# %%
# def calc_gradient_score(adata, df_grad, csv_save_path, col_corr="mean_spearman"):

#     print("ATTENTION: adata.X must be raw.")
#     print("ATTENTION: df_grad must have ONLY gradient genes and gene names as index.")

#     # Normalise
#     sc.pp.normalize_total(adata, target_sum=1e4)
#     sc.pp.log1p(adata)

#     # Calculate collim genes
#     common_genes = adata.var_names.intersection(df_grad.index)

#     # Subset to common genes
#     import scipy.sparse as sp
#     df_grad = df_grad.loc[common_genes]
#     X_grad_genes = adata[:, common_genes].X  # (n_cells × n_genes)
#     X_grad_genes = X_grad_genes.toarray() if sp.issparse(X_grad_genes) else np.asarray(X_grad_genes)


#     # calculate score
#     # more dorsal genes --> higher score
#     adata.obs["gradient_score"] = - X_grad_genes @ df_grad[col_corr].values

#     assert not adata.obs['gradient_score'].isna().any(), "Some cells have no gradient scores!"

#     # save df
#     df_scores = adata.obs[["gradient_score"]]
#     df_scores.to_csv(csv_save_path)

# %%
# # define genes for grad

# save_csv_path = f"{os.path.dirname(ADATA_PATH)}/gradient_scores.csv"

# if not os.path.exists(save_csv_path):

#     adata.X = adata.layers["counts"].copy()  # use raw counts for score calculation
#     df_grad_significant = df_grad[df_grad["is_gradient_gene"]]
#     calc_gradient_score(adata, df_grad_significant, save_csv_path)

# else:
#     df_scores = pd.read_csv(save_csv_path, index_col=0)
#     adata.obs = adata.obs.merge(df_scores, how="left", left_index=True, right_index=True, validate="one_to_one")
#     # Check that all cells have scores
#     assert not adata.obs['gradient_score'].isna().any(), "Some cells have no gradient scores!"

# %%
# sns.histplot(data=adata.obs, x="gradient_score", hue=CONTRAST_VARIABLE, bins=50); plt.show()
# # sns.histplot(data=adata.obs[adata.obs["broad_original_cell_type"] == "Striatum_Neuron"], x="gradient_score", hue=CONTRAST_VARIABLE, bins=50); plt.show()
# # sns.histplot(data= adata.obs[adata.obs["ct_for_deg"] == "Matrix"], x="gradient_score", hue=CONTRAST_VARIABLE, bins=50); plt.show()
# # sns.histplot(data= adata.obs[(adata.obs["Group_name"].isin(["STRd D1 Matrix MSN", "STRv D1 MSN"])) & (adata.obs["ct_for_deg"] == "Matrix")], x="gradient_score", hue=CONTRAST_VARIABLE, bins=50); plt.show()

# %%
# # Compare mean gradient score per donor
# if RUN_ON_ZONES:

#     sns.histplot(data=adata.obs, x="gradient_score", hue=CONTRAST_VARIABLE, bins=50); plt.show()

#     donor_zone_mean = (
#         adata.obs.groupby([SAMPLE_VARIABLE, CONTRAST_VARIABLE, "zone"])["gradient_score"]
#         .mean()
#         .reset_index()
#     )

#     sns.boxplot(data=donor_zone_mean, x="zone", y="gradient_score", hue=CONTRAST_VARIABLE)

# %% [markdown]
# # Define functions

# %% [markdown]
# ## Nebula Gene Filtering & PCA Stopping Criteria
#
# ### Gene Filtering
# 1. Drop donors with < `min_cells_per_sample` cells.
# 2. Keep genes expressed in ≥ `n_donors × min_cells_per_sample` cells.
# 3. Keep genes with ≥ `min_counts` total counts.
# 4. Skip analysis if:
#    - Any condition has < `MIN_SAMPLES_PER_CONDITION` donors.
#    - Remaining genes ≤ `MIN_NUMBER_GENES_PER_ANALYSIS`.

# %% [markdown]
# # Run for all ct

# %%
# sc.pl.umap(adata_ct, color=[CONTRAST_VARIABLE, "Group_name", "vireo_prob_doublet"], palette="tab20")
# pcs = [c for c in adata_ct.obs.columns if c.startswith("PC_")]
# DEG.check_corr_cov_in_design(adata_ct, vars_in_formula=[CONTRAST_VARIABLE, *pcs, *COVARIATES_FOR_DEG], corr_thr=0.7, split=" + ")

sorted(adata.obs[CT_FOR_DEG_VARIABLE].unique().tolist())[:]
# Out:
# ['Matrix', 'Patch']

# %%
for ct in sorted(adata.obs[CT_FOR_DEG_VARIABLE].unique().tolist())[:]:

    #ct="Matrix_D1"
    if ct.startswith("-"):
        continue

    if (TYPE_DEG == "cNMF_nebula") and (ct not in ct_forcNMF[TISSUE]):
        print(f"Skipping {ct} because it's not in the list of cell types to run cNMF on.")
        continue

    print("\n\n######################\n",ct, "\n######################\n")

    # Select single ct
    adata_ct = adata[adata.obs[CT_FOR_DEG_VARIABLE] == ct].to_memory().copy()
    adata_ct.X = adata_ct.layers["counts"].copy() 
    print(np.array_equal(adata_ct.X.data, adata_ct.X.data.astype(int)) if hasattr(adata_ct.X, 'data') else np.array_equal(adata_ct.X, adata_ct.X.astype(int)))

    # adata_ct = adata_ct[adata_ct.obs["zone"].isin(["4"])].copy() # only keep control and XDP for this analsys
    # print(adata_ct)

    # Define saving apthjs
    ADATA_PATH_QS = f"{DEG_FOLDER}/{ct}/tmp_{os.path.splitext(os.path.basename(ADATA_PATH))[0]}_{ct}_for_nebula.qs"
    SAVE_HEALTHY_PCA_RESULT = os.path.dirname(ADATA_PATH_QS)
    os.makedirs(SAVE_HEALTHY_PCA_RESULT, exist_ok=True)
    print(ADATA_PATH_QS)

    #break

    if TYPE_DEG == "cNMF_nebula":
        # For cNMF, we need to provide the spectra file path (with gene names as index)
            # RAW SPECTRA
        matches = glob.glob(f"/home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/{TISSUE}/cNMF_nebula/{ct}/cNMF_run_healthy/*.spectra.*.consensus.txt")
        if len(matches) == 0:
            # First time for this tissue/ct: no spectra yet.
            # run_nebula_with_factors will save healthy_cNMF.h5ad and return None.
            print(f"No spectra found for {ct} — will save healthy h5ad for cNMF training on UGER.")
            CNMF_SPECTRA_PATH = None
        elif len(matches) > 1:
            raise ValueError(f"Expected 1 spectra file for {ct}, found {len(matches)}: {matches}")
        else:
            CNMF_SPECTRA_PATH = matches[0]
    else:
        CNMF_SPECTRA_PATH = None

    # Delete stale nebula chunks so chunk-sobj-by-genes.R doesn't reuse files
    # from a previous failed run (which had different covariate columns)
    _nebula_dir = f"{os.path.splitext(ADATA_PATH_QS)[0]}__nebula_ln"
    if os.path.exists(_nebula_dir):
        shutil.rmtree(_nebula_dir)

    # Run enire pipeline for this ct
    nebula_utils.run_nebula_with_factors(
        adata_ct, 
        ADATA_PATH_QS, SAVE_HEALTHY_PCA_RESULT, PARALLEL_NEBULA_SCRIPT_PATH,
        CONTRAST_VARIABLE,CONTRAST_BASELINE, CONTRAST_STIM,
        SAMPLE_VARIABLE,LIBRARY_SIZE_COL,COVARIATES_FOR_DEG,
        N_PCS_TO_USE=None, # default knee method
        variance_threshold=None,delete_tmp_files=True, TYPE_DEG=TYPE_DEG,
        MIN_SAMPLES_PER_CONDITION=4, MIN_NUMBER_GENES_PER_ANALYSIS=3000,
        
        # Attention: spectra file expected to be in fixed place
            #/home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/{TISSUE}/cNMF_nebula/{ct}/cNMF_run_healthy/cNMF_spectra.txt
        CNMF_SPECTRA_PATH=CNMF_SPECTRA_PATH
    )

    #break
# Out:
# ######################
#  Matrix
# ######################
#
# True
# /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula.qs
# True
# ATTENTION: .X must be raw!
# Retained donors : 37
# Filtered genes  : 38601 -> 19821 (min_cells=370, min_counts=50)
# Running Factor calculation on Healthy...
# /home/gdallagl/myworkdir/XDP/utils/nebula_with_factors.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   import os
# Running Factor calculation on Diseased...
# Saving h5ad file...
# adata intact: 14838 cells, 19821 genes
# ATTENTION: Dropping 0 cells with NaN covariates: []
# ... storing 'ct_for_deg' as categorical
# ~ condition + age_of_death + pct_counts_mt + frac_intronic + cohort + gradient_score + total_counts
#              variable         VIF
# 0           Intercept  390.139385
# 2  cohort[T.Cohort_2]    2.631948
# 8        total_counts    2.430493
# 3  cohort[T.Cohort_3]    2.356513
# 1    condition[T.XDP]    1.723119
# 4        age_of_death    1.614737
# 7      gradient_score    1.446763
# 6       frac_intronic    1.350655
# 5       pct_counts_mt    1.186816
#
# binary identifiability test. False
# 2026-07-10 19:07:04 | [WARNING] R callback write-console: condition: factor | example: XDP
#
# 2026-07-10 19:07:04 | [WARNING] R callback write-console: donor_id: character | example: SCF-18-004
#
# 2026-07-10 19:07:04 | [WARNING] R callback write-console: age_of_death: numeric | example: 56
#
# 2026-07-10 19:07:04 | [WARNING] R callback write-console: pct_counts_mt: numeric | example: 0.0388265746333046
#
# 2026-07-10 19:07:04 | [WARNING] R callback write-console: frac_intronic: numeric | example: 0.762041613978618
#
# 2026-07-10 19:07:04 | [WARNING] R callback write-console: cohort: character | example: Cohort_1
#
# 2026-07-10 19:07:04 | [WARNING] R callback write-console: gradient_score: numeric | example: 20.9359330740633
#
# 2026-07-10 19:07:04 | [WARNING] R callback write-console:
# Fitting: gradient_score ~ condition + age_of_death + pct_counts_mt + frac_intronic + cohort + (1|donor_id)
#         factor       beta       se  p_value      fdr
# gradient_score -18.461917 3.611297 0.000016 0.000016
# Saving qs file...
# 	Saving files for R coversion...
# 	Building R obj...
#
# Setting condition reference level to: Control
# Levels: Control XDP
# [1] "Creating Seurat object..."
# 2026-07-10 19:08:02 | [WARNING] R callback write-console: Warning:
# 2026-07-10 19:08:02 | [WARNING] R callback write-console:  Data is of class dgTMatrix. Coercing to dgCMatrix.
# [1] "Saving Seurat object as .qs..."
# Running Nebula...
# cmd list: ['bash', '/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/run-nebula-parallel.sh', '--path', '/home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula.qs', '--id-col', 'donor_id', '--offset-col', 'total_counts', '--n-folds', '40', '--n-cores', '40', '--save-tmp', '0']
# Running command: bash /home/gdallagl/myworkdir/XDP/utils/nebula_scripts/run-nebula-parallel.sh --path /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula.qs --id-col donor_id --offset-col total_counts --n-folds 40 --n-cores 40 --save-tmp 0
# Running command: bash /home/gdallagl/myworkdir/XDP/utils/nebula_scripts/run-nebula-parallel.sh --path /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula.qs --id-col donor_id --offset-col total_counts --n-folds 40 --n-cores 40 --save-tmp 0 --covs condition,age_of_death,pct_counts_mt,frac_intronic,cohort,gradient_score
# ================================================================================
# [INFO] Input: /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula.qs
# [INFO] Script dir: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [INFO] Base name: tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula.qs
# [INFO] Geneset dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix
# [INFO] Geneset: Matrix
# [INFO] Split dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula
# [INFO] Split: gradient_score_nebula
# [INFO] n-folds: 40
# [INFO] parallel jobs: 40
# [INFO] id-col: donor_id
# [INFO] covs:
#        - condition
#        - age_of_death
#        - pct_counts_mt
#        - frac_intronic
#        - cohort
#        - gradient_score
# [INFO] offset-col: total_counts  -> will create meta 'nUMI_nebula'
# [INFO] Tmp dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln
# [INFO] Chunks dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks
# [INFO] Tmp de_dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results/
# [INFO] final_dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/de_results/nebula_ln
# [INFO] nebula_out_basename: tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln_combined.qs
# [INFO] Final combined results: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/de_results/nebula_ln/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln_combined.qs
#
# ***** LOADING sobj: /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula.qs
# Splitting 19821 genes into 40 chunks
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_001_of_040.qs (genes 1 --> 496; nGenes=496)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_002_of_040.qs (genes 497 --> 992; nGenes=496)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_003_of_040.qs (genes 993 --> 1488; nGenes=496)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_004_of_040.qs (genes 1489 --> 1984; nGenes=496)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_005_of_040.qs (genes 1985 --> 2480; nGenes=496)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_006_of_040.qs (genes 2481 --> 2976; nGenes=496)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_007_of_040.qs (genes 2977 --> 3472; nGenes=496)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_008_of_040.qs (genes 3473 --> 3968; nGenes=496)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_009_of_040.qs (genes 3969 --> 4464; nGenes=496)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_010_of_040.qs (genes 4465 --> 4960; nGenes=496)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_011_of_040.qs (genes 4961 --> 5456; nGenes=496)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_012_of_040.qs (genes 5457 --> 5952; nGenes=496)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_013_of_040.qs (genes 5953 --> 6448; nGenes=496)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_014_of_040.qs (genes 6449 --> 6944; nGenes=496)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_015_of_040.qs (genes 6945 --> 7440; nGenes=496)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_016_of_040.qs (genes 7441 --> 7936; nGenes=496)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_017_of_040.qs (genes 7937 --> 8432; nGenes=496)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_018_of_040.qs (genes 8433 --> 8928; nGenes=496)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_019_of_040.qs (genes 8929 --> 9424; nGenes=496)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_020_of_040.qs (genes 9425 --> 9920; nGenes=496)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_021_of_040.qs (genes 9921 --> 10416; nGenes=496)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_022_of_040.qs (genes 10417 --> 10911; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_023_of_040.qs (genes 10912 --> 11406; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_024_of_040.qs (genes 11407 --> 11901; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_025_of_040.qs (genes 11902 --> 12396; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_026_of_040.qs (genes 12397 --> 12891; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_027_of_040.qs (genes 12892 --> 13386; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_028_of_040.qs (genes 13387 --> 13881; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_029_of_040.qs (genes 13882 --> 14376; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_030_of_040.qs (genes 14377 --> 14871; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_031_of_040.qs (genes 14872 --> 15366; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_032_of_040.qs (genes 15367 --> 15861; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_033_of_040.qs (genes 15862 --> 16356; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_034_of_040.qs (genes 16357 --> 16851; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_035_of_040.qs (genes 16852 --> 17346; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_036_of_040.qs (genes 17347 --> 17841; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_037_of_040.qs (genes 17842 --> 18336; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_038_of_040.qs (genes 18337 --> 18831; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_039_of_040.qs (genes 18832 --> 19326; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_040_of_040.qs (genes 19327 --> 19821; nGenes=495)
# ***** SPLITTING DONE.
#
# [INFO] Launching chunk jobs with GNU parallel...
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_020_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_020_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_006_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_006_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_034_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_034_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_003_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_003_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_015_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_015_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_008_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_008_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_026_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_026_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "Extracted 496 genes and 14838 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+gradient_score"
# [1] "Covariate types:"
#      condition   age_of_death  pct_counts_mt  frac_intronic         cohort
#       "factor"      "numeric"      "numeric"      "numeric"    "character"
# gradient_score
#      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
# [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "Extracted 496 genes and 14838 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+gradient_score"
# [1] "Covariate types:"
#      condition   age_of_death  pct_counts_mt  frac_intronic         cohort
#       "factor"      "numeric"      "numeric"      "numeric"    "character"
# gradient_score
#      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
# [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "Extracted 495 genes and 14838 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+gradient_score"
# [1] "Covariate types:"
#      condition   age_of_death  pct_counts_mt  frac_intronic         cohort
#       "factor"      "numeric"      "numeric"      "numeric"    "character"
# gradient_score
#      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
# [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "gradient_score"
# [1] "Extracted 496 genes and 14838 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+gradient_score"
# [1] "Covariate types:"
#      condition   age_of_death  pct_counts_mt  frac_intronic         cohort
#       "factor"      "numeric"      "numeric"      "numeric"    "character"
# gradient_score
#      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
# [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "Extracted 496 genes and 14838 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+gradient_score"
# [1] "Covariate types:"
#      condition   age_of_death  pct_counts_mt  frac_intronic         cohort
#       "factor"      "numeric"      "numeric"      "numeric"    "character"
# gradient_score
#      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
# [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "gradient_score"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "Extracted 496 genes and 14838 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+gradient_score"
# [1] "Covariate types:"
#      condition   age_of_death  pct_counts_mt  frac_intronic         cohort
#       "factor"      "numeric"      "numeric"      "numeric"    "character"
# gradient_score
#      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
# [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  496  genes with  37  subjects and  14838  cells.
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_007_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_007_of_040.qs ****************
# Remove  0  genes having low expression.
# Analyzing  496  genes with  37  subjects and  14838  cells.
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "Extracted 495 genes and 14838 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+gradient_score"
# [1] "Covariate types:"
#      condition   age_of_death  pct_counts_mt  frac_intronic         cohort
#       "factor"      "numeric"      "numeric"      "numeric"    "character"
# gradient_score
#      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
# [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# Remove  0  genes having low expression.
# Analyzing  495  genes with  37  subjects and  14838  cells.
# Remove  0  genes having low expression.
# Analyzing  496  genes with  37  subjects and  14838  cells.
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# Remove  0  genes having low expression.
# Analyzing  496  genes with  37  subjects and  14838  cells.
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_023_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_023_of_040.qs ****************
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# Remove  0  genes having low expression.
# Analyzing  496  genes with  37  subjects and  14838  cells.
# Remove  0  genes having low expression.
# Analyzing  495  genes with  37  subjects and  14838  cells.
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "Extracted 496 genes and 14838 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+gradient_score"
# [1] "Covariate types:"
#      condition   age_of_death  pct_counts_mt  frac_intronic         cohort
#       "factor"      "numeric"      "numeric"      "numeric"    "character"
# gradient_score
#      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
# [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "Extracted 495 genes and 14838 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+gradient_score"
# [1] "Covariate types:"
#      condition   age_of_death  pct_counts_mt  frac_intronic         cohort
#       "factor"      "numeric"      "numeric"      "numeric"    "character"
# gradient_score
#      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
# [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  496  genes with  37  subjects and  14838  cells.
# Remove  0  genes having low expression.
# Analyzing  495  genes with  37  subjects and  14838  cells.
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_019_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_019_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_016_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_016_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_018_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_018_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_012_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_012_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_022_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_022_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_004_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_004_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_029_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_029_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_024_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_024_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_036_of_040__nebula_ln.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_033_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_033_of_040.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_036_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_027_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_027_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_031_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_031_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_032_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_032_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_040_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_040_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_002_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_002_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_011_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_011_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_017_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_017_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_038_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_038_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_009_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_009_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_037_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_037_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_035_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_035_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_021_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_021_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_001_of_040__nebula_ln.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_025_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_001_of_040.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_025_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_030_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_030_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_028_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_028_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_013_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_013_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_014_of_040__nebula_ln.qs ****************
# ...
# [1] "Extracted 400 genes and 5058 cells"
# Remove  0  genes having low expression.
# Analyzing  400  genes with  36  subjects and  5058  cells.
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+gradient_score"
# [1] "Covariate types:"
#      condition   age_of_death  pct_counts_mt  frac_intronic         cohort
#       "factor"      "numeric"      "numeric"      "numeric"    "character"
# gradient_score
#      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
# [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  400  genes with  36  subjects and  5058  cells.
# [1] "Extracted 400 genes and 5058 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+gradient_score"
# [1] "Covariate types:"
#      condition   age_of_death  pct_counts_mt  frac_intronic         cohort
#       "factor"      "numeric"      "numeric"      "numeric"    "character"
# gradient_score
#      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
# [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "Extracted 401 genes and 5058 cells"
# [1] "Extracted 400 genes and 5058 cells"
# Remove  0  genes having low expression.
# Analyzing  400  genes with  36  subjects and  5058  cells.
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+gradient_score"
# [1] "Covariate types:"
#      condition   age_of_death  pct_counts_mt  frac_intronic         cohort
#       "factor"      "numeric"      "numeric"      "numeric"    "character"
# gradient_score
#      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
# [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "gradient_score"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+gradient_score"
# [1] "Covariate types:"
#      condition   age_of_death  pct_counts_mt  frac_intronic         cohort
#       "factor"      "numeric"      "numeric"      "numeric"    "character"
# gradient_score
#      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
# [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "gradient_score"
# Remove  0  genes having low expression.
# Analyzing  400  genes with  36  subjects and  5058  cells.
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  400  genes with  36  subjects and  5058  cells.
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  400  genes with  36  subjects and  5058  cells.
# Remove  0  genes having low expression.
# Analyzing  400  genes with  36  subjects and  5058  cells.
# Remove  0  genes having low expression.
# Analyzing  401  genes with  36  subjects and  5058  cells.
# Remove  0  genes having low expression.
# Analyzing  400  genes with  36  subjects and  5058  cells.
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_001_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_035_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_033_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_039_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_017_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_030_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_020_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_007_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_021_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_002_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_003_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_036_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_015_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_032_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_005_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_037_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_040_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_038_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_019_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_031_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_023_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_034_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_027_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_016_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_025_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_028_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_014_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_013_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_018_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_009_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_026_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_010_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_008_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_004_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_024_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_022_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_029_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_006_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_011_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_012_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# [INFO] All chunk jobs completed.
#
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# ***** Combined NEBULA results written to: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/de_results/nebula_ln/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln_combined.qs
# [INFO] Final combined results: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/de_results/nebula_ln/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln_combined.qs
# [INFO] Removing tmp dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/gradient_score_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln
# [ALL DONE]
# ================================================================================

# %%
# for ct in sorted(adata.obs[CT_FOR_DEG_VARIABLE].unique().tolist())[:]:

#     #ct="Matrix_D1"
#     if ct.startswith("-"):
#         continue

#     if (TYPE_DEG == "cNMF_nebula") and (ct not in ct_forcNMF[TISSUE]):
#         print(f"Skipping {ct} because it's not in the list of cell types to run cNMF on.")
#         continue

#     print("\n\n######################\n",ct, "\n######################\n")

#     # Select single ct
#     adata_ct = adata[adata.obs[CT_FOR_DEG_VARIABLE] == ct].to_memory().copy()
#     adata_ct.X = adata_ct.layers["counts"].copy() 
#     print(np.array_equal(adata_ct.X.data, adata_ct.X.data.astype(int)) if hasattr(adata_ct.X, 'data') else np.array_equal(adata_ct.X, adata_ct.X.astype(int)))

#     # adata_ct = adata_ct[adata_ct.obs["zone"].isin(["4"])].copy() # only keep control and XDP for this analsys
#     # print(adata_ct)

#     # Define saving apthjs
#     ADATA_PATH_QS = f"{DEG_FOLDER}/{ct}/tmp_{os.path.splitext(os.path.basename(ADATA_PATH))[0]}_{ct}_for_nebula.qs"
#     SAVE_HEALTHY_PCA_RESULT = os.path.dirname(ADATA_PATH_QS)
#     os.makedirs(SAVE_HEALTHY_PCA_RESULT, exist_ok=True)
#     print(ADATA_PATH_QS)

#     #break

#     if TYPE_DEG == "cNMF_nebula":
#         # For cNMF, we need to provide the spectra file path (with gene names as index)
#             # RAW SPECTRA
#         matches = glob.glob(f"/home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/{TISSUE}/cNMF_nebula/{ct}/cNMF_run_healthy/*.spectra.*.consensus.txt")
#         if len(matches) == 0:
#             # First time for this tissue/ct: no spectra yet.
#             # run_nebula_with_factors will save healthy_cNMF.h5ad and return None.
#             print(f"No spectra found for {ct} — will save healthy h5ad for cNMF training on UGER.")
#             CNMF_SPECTRA_PATH = None
#         elif len(matches) > 1:
#             raise ValueError(f"Expected 1 spectra file for {ct}, found {len(matches)}: {matches}")
#         else:
#             CNMF_SPECTRA_PATH = matches[0]
#     else:
#         CNMF_SPECTRA_PATH = None


#     # Run enire pipeline for this ct
#     nebula_utils.run_nebula_with_factors(
#         adata_ct, 
#         ADATA_PATH_QS, SAVE_HEALTHY_PCA_RESULT, PARALLEL_NEBULA_SCRIPT_PATH,
#         CONTRAST_VARIABLE,CONTRAST_BASELINE, CONTRAST_STIM,
#         SAMPLE_VARIABLE,LIBRARY_SIZE_COL,COVARIATES_FOR_DEG,
#         N_PCS_TO_USE=None, # default knee method
#         variance_threshold=None,delete_tmp_files=True, TYPE_DEG=TYPE_DEG,
#         MIN_SAMPLES_PER_CONDITION=4, MIN_NUMBER_GENES_PER_ANALYSIS=3000,
        
#         # Attention: spectra file expected to be in fixed place
#             #/home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/{TISSUE}/cNMF_nebula/{ct}/cNMF_run_healthy/cNMF_spectra.txt
#         CNMF_SPECTRA_PATH=CNMF_SPECTRA_PATH
#     )

#     #break
# Out:
# ######################
#  Matrix
# ######################
#
# True
# /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula.qs
# True
# ATTENTION: .X must be raw!
# Retained donors : 37
# Filtered genes  : 38601 -> 19821 (min_cells=370, min_counts=50)
# Running Factor calculation on Healthy...
# /home/gdallagl/myworkdir/XDP/utils/nebula_with_factors.py:464: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(CONTRAST_VARIABLE)[SAMPLE_VARIABLE]
# Normalising
# WARNING: adata.X seems to be already log-transformed.
# HVG
# Scaling
# PCA on Healthy
# Auto-selected 8 PCs via elbow (13.4% variance explained using 50)
# Done.
# Running Factor calculation on Diseased...
# Normalising
# WARNING: adata.X seems to be already log-transformed.
# Scaling
# PCA on Diseased
# Done.
# Saving h5ad file...
# adata intact: 14838 cells, 19821 genes
# ATTENTION: Dropping 0 cells with NaN covariates: []
# ... storing 'ct_for_deg' as categorical
# ~ condition + age_of_death + pct_counts_mt + frac_intronic + cohort + PC_1 + PC_2 + PC_3 + PC_4 + PC_5 + PC_6 + PC_7 + PC_8 + total_counts
#               variable          VIF
# 0            Intercept  1117.397963
# 2   cohort[T.Cohort_2]     3.799023
# 6        frac_intronic     3.585293
# 3   cohort[T.Cohort_3]     2.928843
# 9                 PC_3     2.754957
# 15        total_counts     2.622195
# 7                 PC_1     2.382421
# 1     condition[T.XDP]     1.811795
# 4         age_of_death     1.771971
# 5        pct_counts_mt     1.703380
# 10                PC_4     1.480768
# 8                 PC_2     1.476418
# 12                PC_6     1.390807
# 13                PC_7     1.234740
# 14                PC_8     1.227015
# 11                PC_5     1.106538
#
# binary identifiability test. False
# 2026-06-09 13:08:05 | [WARNING] R callback write-console: condition: factor | example: XDP
#
# 2026-06-09 13:08:05 | [WARNING] R callback write-console: donor_id: character | example: SCF-18-004
#
# 2026-06-09 13:08:05 | [WARNING] R callback write-console: age_of_death: numeric | example: 56
#
# 2026-06-09 13:08:05 | [WARNING] R callback write-console: pct_counts_mt: numeric | example: 0.0388265746333046
#
# 2026-06-09 13:08:05 | [WARNING] R callback write-console: frac_intronic: numeric | example: 0.762041613978618
#
# 2026-06-09 13:08:05 | [WARNING] R callback write-console: cohort: character | example: Cohort_1
#
# 2026-06-09 13:08:05 | [WARNING] R callback write-console: PC_1: numeric | example: 2.44017196081234
#
# 2026-06-09 13:08:05 | [WARNING] R callback write-console: PC_2: numeric | example: -9.95924134668503
#
# 2026-06-09 13:08:05 | [WARNING] R callback write-console: PC_3: numeric | example: -0.585685256314882
#
# 2026-06-09 13:08:05 | [WARNING] R callback write-console: PC_4: numeric | example: -4.50289582288154
#
# 2026-06-09 13:08:05 | [WARNING] R callback write-console: PC_5: numeric | example: -2.29697319326103
#
# 2026-06-09 13:08:05 | [WARNING] R callback write-console: PC_6: numeric | example: 4.96850360090312
#
# 2026-06-09 13:08:05 | [WARNING] R callback write-console: PC_7: numeric | example: -10.8640742985496
#
# 2026-06-09 13:08:05 | [WARNING] R callback write-console: PC_8: numeric | example: 5.83493243630161
#
# 2026-06-09 13:08:05 | [WARNING] R callback write-console:
# Fitting: PC_1 ~ condition + age_of_death + pct_counts_mt + frac_intronic + cohort + (1|donor_id)
#
# 2026-06-09 13:08:05 | [WARNING] R callback write-console:
# Fitting: PC_2 ~ condition + age_of_death + pct_counts_mt + frac_intronic + cohort + (1|donor_id)
#
# 2026-06-09 13:08:05 | [WARNING] R callback write-console:
# Fitting: PC_3 ~ condition + age_of_death + pct_counts_mt + frac_intronic + cohort + (1|donor_id)
#
# 2026-06-09 13:08:06 | [WARNING] R callback write-console:
# Fitting: PC_4 ~ condition + age_of_death + pct_counts_mt + frac_intronic + cohort + (1|donor_id)
#
# 2026-06-09 13:08:06 | [WARNING] R callback write-console:
# Fitting: PC_5 ~ condition + age_of_death + pct_counts_mt + frac_intronic + cohort + (1|donor_id)
#
# 2026-06-09 13:08:06 | [WARNING] R callback write-console:
# Fitting: PC_6 ~ condition + age_of_death + pct_counts_mt + frac_intronic + cohort + (1|donor_id)
#
# 2026-06-09 13:08:07 | [WARNING] R callback write-console:
# Fitting: PC_7 ~ condition + age_of_death + pct_counts_mt + frac_intronic + cohort + (1|donor_id)
#
# 2026-06-09 13:08:07 | [WARNING] R callback write-console:
# Fitting: PC_8 ~ condition + age_of_death + pct_counts_mt + frac_intronic + cohort + (1|donor_id)
# factor      beta       se  p_value      fdr
#   PC_2 -8.158563 1.672842 0.000030 0.000244
#   PC_5  1.545288 0.536842 0.007539 0.030157
#   PC_8  0.917336 0.829288 0.277647 0.529669
#   PC_1 -2.083330 2.045476 0.316097 0.529669
#   PC_7 -0.735386 0.744791 0.331043 0.529669
#   PC_6  0.623711 1.307891 0.636692 0.788319
#   PC_3 -0.395571 1.428427 0.783615 0.788319
#   PC_4  0.289678 1.069904 0.788319 0.788319
# Saving qs file...
# 	Saving files for R coversion...
# 2026-06-09 13:08:13 | [WARNING] R callback write-console: Loading required package: SeuratObject
#
# 2026-06-09 13:08:13 | [WARNING] R callback write-console: Loading required package: sp
# 	Building R obj...
# 2026-06-09 13:08:14 | [WARNING] R callback write-console:
# Attaching package: ‘SeuratObject’
#
#
# 2026-06-09 13:08:14 | [WARNING] R callback write-console: The following objects are masked from ‘package:base’:
#
#     %||%, intersect, t
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# 2026-06-09 13:08:15 | [WARNING] R callback write-console:
# Attaching package: ‘Seurat’
#
#
# 2026-06-09 13:08:15 | [WARNING] R callback write-console: The following object is masked from ‘package:base’:
#
#     %||%
#
#
# 2026-06-09 13:08:15 | [WARNING] R callback write-console: qs 0.27.3. Announcement: https://github.com/qsbase/qs/issues/103
# Setting condition reference level to: Control
# Levels: Control XDP
# [1] "Creating Seurat object..."
# 2026-06-09 13:09:09 | [WARNING] R callback write-console: Warning:
# 2026-06-09 13:09:09 | [WARNING] R callback write-console:  Data is of class dgTMatrix. Coercing to dgCMatrix.
# [1] "Saving Seurat object as .qs..."
# Running Nebula...
# cmd list: ['bash', '/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/run-nebula-parallel.sh', '--path', '/home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula.qs', '--id-col', 'donor_id', '--offset-col', 'total_counts', '--n-folds', '40', '--n-cores', '40', '--save-tmp', '0']
# Running command: bash /home/gdallagl/myworkdir/XDP/utils/nebula_scripts/run-nebula-parallel.sh --path /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula.qs --id-col donor_id --offset-col total_counts --n-folds 40 --n-cores 40 --save-tmp 0
# Running command: bash /home/gdallagl/myworkdir/XDP/utils/nebula_scripts/run-nebula-parallel.sh --path /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula.qs --id-col donor_id --offset-col total_counts --n-folds 40 --n-cores 40 --save-tmp 0 --covs condition,age_of_death,pct_counts_mt,frac_intronic,cohort,PC_1,PC_2,PC_3,PC_4,PC_5,PC_6,PC_7,PC_8
# ================================================================================
# [INFO] Input: /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula.qs
# [INFO] Script dir: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [INFO] Base name: tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula.qs
# [INFO] Geneset dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix
# [INFO] Geneset: Matrix
# [INFO] Split dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula
# [INFO] Split: PCA_nebula
# [INFO] n-folds: 40
# [INFO] parallel jobs: 40
# [INFO] id-col: donor_id
# [INFO] covs:
#        - condition
#        - age_of_death
#        - pct_counts_mt
#        - frac_intronic
#        - cohort
#        - PC_1
#        - PC_2
#        - PC_3
#        - PC_4
#        - PC_5
#        - PC_6
#        - PC_7
#        - PC_8
# [INFO] offset-col: total_counts  -> will create meta 'nUMI_nebula'
# [INFO] Tmp dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln
# [INFO] Chunks dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks
# [INFO] Tmp de_dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results/
# [INFO] final_dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/de_results/nebula_ln
# [INFO] nebula_out_basename: tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln_combined.qs
# [INFO] Final combined results: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/de_results/nebula_ln/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln_combined.qs
#
# ***** LOADING sobj: /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula.qs
# Splitting 19821 genes into 40 chunks
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_001_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_002_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_003_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_004_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_005_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_006_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_007_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_008_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_009_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_010_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_011_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_012_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_013_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_014_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_015_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_016_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_017_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_018_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_019_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_020_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_021_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_022_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_023_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_024_of_040.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_025_of_040.qs (already exists)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_026_of_040.qs (genes 12397 --> 12891; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_027_of_040.qs (genes 12892 --> 13386; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_028_of_040.qs (genes 13387 --> 13881; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_029_of_040.qs (genes 13882 --> 14376; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_030_of_040.qs (genes 14377 --> 14871; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_031_of_040.qs (genes 14872 --> 15366; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_032_of_040.qs (genes 15367 --> 15861; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_033_of_040.qs (genes 15862 --> 16356; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_034_of_040.qs (genes 16357 --> 16851; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_035_of_040.qs (genes 16852 --> 17346; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_036_of_040.qs (genes 17347 --> 17841; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_037_of_040.qs (genes 17842 --> 18336; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_038_of_040.qs (genes 18337 --> 18831; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_039_of_040.qs (genes 18832 --> 19326; nGenes=495)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_040_of_040.qs (genes 19327 --> 19821; nGenes=495)
# ***** SPLITTING DONE.
#
# [INFO] Launching chunk jobs with GNU parallel...
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_006_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_006_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_019_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_019_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_032_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_032_of_040.qs ****************
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_016_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_016_of_040.qs ****************
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_023_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_023_of_040.qs ****************
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "Extracted 496 genes and 14838 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+PC_1+PC_2+PC_3+PC_4+PC_5+PC_6+PC_7+PC_8"
# [1] "Covariate types:"
#     condition  age_of_death pct_counts_mt frac_intronic        cohort
#      "factor"     "numeric"     "numeric"     "numeric"   "character"
#          PC_1          PC_2          PC_3          PC_4          PC_5
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          PC_6          PC_7          PC_8
#     "numeric"     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
#  [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "PC_1"
#  [9] "PC_2"           "PC_3"           "PC_4"           "PC_5"
# [13] "PC_6"           "PC_7"           "PC_8"
# [1] "Extracted 496 genes and 14838 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+PC_1+PC_2+PC_3+PC_4+PC_5+PC_6+PC_7+PC_8"
# [1] "Covariate types:"
#     condition  age_of_death pct_counts_mt frac_intronic        cohort
#      "factor"     "numeric"     "numeric"     "numeric"   "character"
#          PC_1          PC_2          PC_3          PC_4          PC_5
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          PC_6          PC_7          PC_8
#     "numeric"     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
#  [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "PC_1"
#  [9] "PC_2"           "PC_3"           "PC_4"           "PC_5"
# [13] "PC_6"           "PC_7"           "PC_8"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "Extracted 495 genes and 14838 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+PC_1+PC_2+PC_3+PC_4+PC_5+PC_6+PC_7+PC_8"
# [1] "Covariate types:"
#     condition  age_of_death pct_counts_mt frac_intronic        cohort
#      "factor"     "numeric"     "numeric"     "numeric"   "character"
#          PC_1          PC_2          PC_3          PC_4          PC_5
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          PC_6          PC_7          PC_8
#     "numeric"     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
#  [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "PC_1"
#  [9] "PC_2"           "PC_3"           "PC_4"           "PC_5"
# [13] "PC_6"           "PC_7"           "PC_8"
# [1] "**************** RUNNING NEBULA LN ****************"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_007_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_007_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# Remove  0  genes having low expression.
# Analyzing  496  genes with  37  subjects and  14838  cells.
# Remove  0  genes having low expression.
# Analyzing  496  genes with  37  subjects and  14838  cells.
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_010_of_040__nebula_ln.qs ****************
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_010_of_040.qs ****************
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_003_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_003_of_040.qs ****************
# Remove  0  genes having low expression.
# Analyzing  495  genes with  37  subjects and  14838  cells.
# [1] "Extracted 495 genes and 14838 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+PC_1+PC_2+PC_3+PC_4+PC_5+PC_6+PC_7+PC_8"
# [1] "Covariate types:"
#     condition  age_of_death pct_counts_mt frac_intronic        cohort
#      "factor"     "numeric"     "numeric"     "numeric"   "character"
#          PC_1          PC_2          PC_3          PC_4          PC_5
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          PC_6          PC_7          PC_8
#     "numeric"     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
#  [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "PC_1"
#  [9] "PC_2"           "PC_3"           "PC_4"           "PC_5"
# [13] "PC_6"           "PC_7"           "PC_8"
# [1] "Extracted 496 genes and 14838 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+PC_1+PC_2+PC_3+PC_4+PC_5+PC_6+PC_7+PC_8"
# [1] "Covariate types:"
#     condition  age_of_death pct_counts_mt frac_intronic        cohort
#      "factor"     "numeric"     "numeric"     "numeric"   "character"
#          PC_1          PC_2          PC_3          PC_4          PC_5
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          PC_6          PC_7          PC_8
#     "numeric"     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
#  [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "PC_1"
#  [9] "PC_2"           "PC_3"           "PC_4"           "PC_5"
# [13] "PC_6"           "PC_7"           "PC_8"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** RUNNING NEBULA LN ****************"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_034_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_034_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_001_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_001_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_012_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_012_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_026_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_026_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_027_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_027_of_040.qs ****************
# Remove  0  genes having low expression.
# Analyzing  495  genes with  37  subjects and  14838  cells.
# [1] "Extracted 496 genes and 14838 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+PC_1+PC_2+PC_3+PC_4+PC_5+PC_6+PC_7+PC_8"
# [1] "Covariate types:"
#     condition  age_of_death pct_counts_mt frac_intronic        cohort
#      "factor"     "numeric"     "numeric"     "numeric"   "character"
#          PC_1          PC_2          PC_3          PC_4          PC_5
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          PC_6          PC_7          PC_8
#     "numeric"     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
#  [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "PC_1"
#  [9] "PC_2"           "PC_3"           "PC_4"           "PC_5"
# [13] "PC_6"           "PC_7"           "PC_8"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_033_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_033_of_040.qs ****************
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  496  genes with  37  subjects and  14838  cells.
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "Extracted 496 genes and 14838 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+PC_1+PC_2+PC_3+PC_4+PC_5+PC_6+PC_7+PC_8"
# [1] "Covariate types:"
#     condition  age_of_death pct_counts_mt frac_intronic        cohort
#      "factor"     "numeric"     "numeric"     "numeric"   "character"
#          PC_1          PC_2          PC_3          PC_4          PC_5
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          PC_6          PC_7          PC_8
#     "numeric"     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
#  [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "PC_1"
#  [9] "PC_2"           "PC_3"           "PC_4"           "PC_5"
# [13] "PC_6"           "PC_7"           "PC_8"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "Extracted 496 genes and 14838 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+PC_1+PC_2+PC_3+PC_4+PC_5+PC_6+PC_7+PC_8"
# [1] "Covariate types:"
#     condition  age_of_death pct_counts_mt frac_intronic        cohort
#      "factor"     "numeric"     "numeric"     "numeric"   "character"
#          PC_1          PC_2          PC_3          PC_4          PC_5
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          PC_6          PC_7          PC_8
#     "numeric"     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
#  [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "PC_1"
#  [9] "PC_2"           "PC_3"           "PC_4"           "PC_5"
# [13] "PC_6"           "PC_7"           "PC_8"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_030_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_030_of_040.qs ****************
# [1] "Extracted 496 genes and 14838 cells"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_038_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_038_of_040.qs ****************
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+PC_1+PC_2+PC_3+PC_4+PC_5+PC_6+PC_7+PC_8"
# [1] "Covariate types:"
#     condition  age_of_death pct_counts_mt frac_intronic        cohort
#      "factor"     "numeric"     "numeric"     "numeric"   "character"
#          PC_1          PC_2          PC_3          PC_4          PC_5
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          PC_6          PC_7          PC_8
#     "numeric"     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
#  [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "PC_1"
#  [9] "PC_2"           "PC_3"           "PC_4"           "PC_5"
# [13] "PC_6"           "PC_7"           "PC_8"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "Extracted 496 genes and 14838 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+PC_1+PC_2+PC_3+PC_4+PC_5+PC_6+PC_7+PC_8"
# [1] "Covariate types:"
#     condition  age_of_death pct_counts_mt frac_intronic        cohort
#      "factor"     "numeric"     "numeric"     "numeric"   "character"
#          PC_1          PC_2          PC_3          PC_4          PC_5
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          PC_6          PC_7          PC_8
#     "numeric"     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
#  [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "PC_1"
#  [9] "PC_2"           "PC_3"           "PC_4"           "PC_5"
# [13] "PC_6"           "PC_7"           "PC_8"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  496  genes with  37  subjects and  14838  cells.
# [1] "Extracted 495 genes and 14838 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+PC_1+PC_2+PC_3+PC_4+PC_5+PC_6+PC_7+PC_8"
# [1] "Covariate types:"
#     condition  age_of_death pct_counts_mt frac_intronic        cohort
#      "factor"     "numeric"     "numeric"     "numeric"   "character"
#          PC_1          PC_2          PC_3          PC_4          PC_5
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          PC_6          PC_7          PC_8
#     "numeric"     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
#  [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "PC_1"
#  [9] "PC_2"           "PC_3"           "PC_4"           "PC_5"
# [13] "PC_6"           "PC_7"           "PC_8"
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  496  genes with  37  subjects and  14838  cells.
# Remove  0  genes having low expression.
# Analyzing  496  genes with  37  subjects and  14838  cells.
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/de_results//chunk_020_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Matrix/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Matrix_for_nebula__nebula_ln/chunks/chunk_020_of_040.qs ****************
# [1] "Extracted 495 genes and 14838 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+PC_1+PC_2+PC_3+PC_4+PC_5+PC_6+PC_7+PC_8"
# [1] "Covariate types:"
#     condition  age_of_death pct_counts_mt frac_intronic        cohort
#      "factor"     "numeric"     "numeric"     "numeric"   "character"
#          PC_1          PC_2          PC_3          PC_4          PC_5
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          PC_6          PC_7          PC_8
#     "numeric"     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
#  [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "PC_1"
#  [9] "PC_2"           "PC_3"           "PC_4"           "PC_5"
# [13] "PC_6"           "PC_7"           "PC_8"
# Remove  0  genes having low expression.
# Analyzing  496  genes with  37  subjects and  14838  cells.
# [1] "Extracted 495 genes and 14838 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+PC_1+PC_2+PC_3+PC_4+PC_5+PC_6+PC_7+PC_8"
# [1] "Covariate types:"
#     condition  age_of_death pct_counts_mt frac_intronic        cohort
#      "factor"     "numeric"     "numeric"     "numeric"   "character"
#          PC_1          PC_2          PC_3          PC_4          PC_5
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          PC_6          PC_7          PC_8
#     "numeric"     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
# ...
# [1] "Covariate types:"
#     condition  age_of_death pct_counts_mt frac_intronic        cohort
#      "factor"     "numeric"     "numeric"     "numeric"   "character"
#          PC_1          PC_2          PC_3          PC_4          PC_5
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          PC_6          PC_7          PC_8          PC_9
#     "numeric"     "numeric"     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
#  [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "PC_1"
#  [9] "PC_2"           "PC_3"           "PC_4"           "PC_5"
# [13] "PC_6"           "PC_7"           "PC_8"           "PC_9"
# Remove  0  genes having low expression.
# Analyzing  401  genes with  36  subjects and  5058  cells.
# Remove  0  genes having low expression.
# Analyzing  400  genes with  36  subjects and  5058  cells.
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "Extracted 400 genes and 5058 cells"
# [1] "Extracted 400 genes and 5058 cells"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+PC_1+PC_2+PC_3+PC_4+PC_5+PC_6+PC_7+PC_8+PC_9"
# [1] "Covariate types:"
#     condition  age_of_death pct_counts_mt frac_intronic        cohort
#      "factor"     "numeric"     "numeric"     "numeric"   "character"
#          PC_1          PC_2          PC_3          PC_4          PC_5
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          PC_6          PC_7          PC_8          PC_9
#     "numeric"     "numeric"     "numeric"     "numeric"
# [1] "Formula: ~condition+age_of_death+pct_counts_mt+frac_intronic+cohort+PC_1+PC_2+PC_3+PC_4+PC_5+PC_6+PC_7+PC_8+PC_9"
# [1] "Covariate types:"
#     condition  age_of_death pct_counts_mt frac_intronic        cohort
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
#  [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "PC_1"
#  [9] "PC_2"           "PC_3"           "PC_4"           "PC_5"
# [13] "PC_6"           "PC_7"           "PC_8"           "PC_9"
# Remove  0  genes having low expression.
# Analyzing  400  genes with  36  subjects and  5058  cells.
#      "factor"     "numeric"     "numeric"     "numeric"   "character"
#          PC_1          PC_2          PC_3          PC_4          PC_5
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          PC_6          PC_7          PC_8          PC_9
#     "numeric"     "numeric"     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "pct_counts_mt"
#  [5] "frac_intronic"  "cohortCohort_2" "cohortCohort_3" "PC_1"
#  [9] "PC_2"           "PC_3"           "PC_4"           "PC_5"
# [13] "PC_6"           "PC_7"           "PC_8"           "PC_9"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  400  genes with  36  subjects and  5058  cells.
# Remove  0  genes having low expression.
# Analyzing  400  genes with  36  subjects and  5058  cells.
# Remove  0  genes having low expression.
# Analyzing  400  genes with  36  subjects and  5058  cells.
# Remove  0  genes having low expression.
# Analyzing  400  genes with  36  subjects and  5058  cells.
# Remove  0  genes having low expression.
# Analyzing  400  genes with  36  subjects and  5058  cells.
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_024_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_002_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_004_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_021_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_009_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_008_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_038_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_036_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_039_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_033_of_040__nebula_ln.qs ****************
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_006_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_029_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_031_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_012_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_030_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_035_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_027_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_001_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_032_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_037_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_007_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_013_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_018_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_023_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_003_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_014_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_016_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_020_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_034_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_017_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_005_of_040__nebula_ln.qs ****************
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_028_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_019_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_025_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_040_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_026_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_022_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_010_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_011_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln/de_results//chunk_015_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# [INFO] All chunk jobs completed.
#
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# ***** Combined NEBULA results written to: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/de_results/nebula_ln/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln_combined.qs
# [INFO] Final combined results: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/de_results/nebula_ln/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln_combined.qs
# [INFO] Removing tmp dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/PCA_nebula/Patch/tmp_Striatum_combined_QC_mmc_ct-cured_zoned_Patch_for_nebula__nebula_ln
# [ALL DONE]
# ================================================================================

# %%
adata.obs[adata.obs[CONTRAST_VARIABLE].isna()][SAMPLE_VARIABLE].unique()
# Out:
# [], Categories (41, object): ['PCMC-16-011', 'PCMC-16-012', 'SCF-18-003', 'SCF-18-004', ..., 'SCF_23_072CF', 'SCF_23_074CF', 'SCF_23_075CM', 'SCF_23_079CF']

# %% [markdown]
# # Run for all Zones
# ### ONLY STR  --> omly tissue with zones
# ### cNMF in zone uses the data/files of the cell type used for mapping

# %%
if TISSUE != "Striatum":
    exit()

# %%
# Map: cell types that have zone analysis → their zone variable
# each cell type has  a better zonation level
ZONE_CT_MAP = {
    "Matrix_D1": "zone", # just zone for zone_6
    "Matrix_D2": "zone",

    "Patch_D1":  "zone_4",
    "Patch_D2":  "zone_4",
    "eMSN_D1D2": "zone_4",
    "Astrocyte": "zone_4",
}
# adata stays untouched here — no more global mutation

# %%
DEG_FOLDER
# Out:
# '/home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/SN/cNMF_nebula'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
ZONE_CT_MAP.items()
# Out:
# dict_items([('Matrix_D1', 'zone'), ('Matrix_D2', 'zone'), ('Patch_D1', 'zone_4'), ('Patch_D2', 'zone_4'), ('eMSN_D1D2', 'zone_4'), ('Astrocyte', 'zone_4')])

# %%
for zone_ct, zone_variable in ZONE_CT_MAP.items():

    # if zone_ct != "Astrocyte":
    #     continue
    
    if zone_ct not in adata.obs["ct_for_deg"].values:
        print(f"WARNING: {zone_ct} not in adata, skipping")
        continue

    # cNMF of celltype_X_zone are not recualted (ie re-facotrize for each zone)
    #  we just use the same cNMF spectra as for the whole cell type, but run Nebula separately for each zone (with the zone as a covariate in the model)
        # Reuse the spectra from the full cell-type cNMF run (already computed)
    if TYPE_DEG == "cNMF_nebula":
        matches = glob.glob(f"{DEG_FOLDER}/{zone_ct}/cNMF_run_healthy/*.spectra.*.consensus.txt")
        if len(matches) != 1:
            print(f"WARNING: Expected 1 spectra file for {zone_ct}, found {len(matches)}: {matches}. Skipping.")
            continue
        CNMF_SPECTRA_PATH = matches[0]
        print(f"Using spectra: {CNMF_SPECTRA_PATH}")
    else:
        CNMF_SPECTRA_PATH = None

    adata_zone = adata[
        (adata.obs["ct_for_deg"] == zone_ct) & # filter to QC labels
        (adata.obs[zone_variable].notna()) # only cells with zone annotation
    ].to_memory().copy()

    for zone in sorted(adata_zone.obs[zone_variable].unique()):
        print(f"\n\n######################\n{zone_ct} / {zone_variable}={zone} / {TYPE_DEG}\n######################\n")

        adata_ct = adata_zone[adata_zone.obs[zone_variable] == zone].to_memory().copy()
        adata_ct.X = adata_ct.layers["counts"].copy()

        subfolder = f"{zone_ct}_by_{zone_variable}/{zone}"
        ADATA_PATH_QS = f"{DEG_FOLDER}/{subfolder}/{os.path.splitext(os.path.basename(ADATA_PATH))[0]}.qs"
        SAVE_HEALTHY_PCA_RESULT = os.path.dirname(ADATA_PATH_QS)
        os.makedirs(SAVE_HEALTHY_PCA_RESULT, exist_ok=True)
        print(SAVE_HEALTHY_PCA_RESULT)

        nebula_utils.run_nebula_with_factors(
            adata_ct,
            ADATA_PATH_QS, SAVE_HEALTHY_PCA_RESULT, PARALLEL_NEBULA_SCRIPT_PATH,
            CONTRAST_VARIABLE, CONTRAST_BASELINE, CONTRAST_STIM,
            SAMPLE_VARIABLE, LIBRARY_SIZE_COL, COVARIATES_FOR_DEG,
            N_PCS_TO_USE=None, variance_threshold=None, delete_tmp_files=True, TYPE_DEG=TYPE_DEG,
            MIN_SAMPLES_PER_CONDITION=4, MIN_NUMBER_GENES_PER_ANALYSIS=3000,
            CNMF_SPECTRA_PATH=CNMF_SPECTRA_PATH
        )


    #break
# Out:
# Using spectra: /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte/cNMF_run_healthy/healthy_cNMF.spectra.k_12.dt_0_05.consensus.txt
#
#
# ######################
# Astrocyte / zone_4=1 / cNMF_nebula
# ######################
#
# /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1
# True
# ATTENTION: .X must be raw!
# Retained donors : 47
# Filtered genes  : 38601 -> 12878 (min_cells=470, min_counts=50)
# Running Factor calculation on Healthy...
# /home/gdallagl/myworkdir/XDP/utils/nebula_with_factors.py:461: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(CONTRAST_VARIABLE)[SAMPLE_VARIABLE]
# Found existing cNMF spectra at /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte/cNMF_run_healthy/healthy_cNMF.spectra.k_12.dt_0_05.consensus.txt, skipping cNMF training and proceeding to projection step.
# WARNING: 304/2000 spectra genes not in adata (filtered). Using 1696 genes.
# Saved healthy GEP projections: 1977 cells, 11 GEPs
# Running Factor calculation on Diseased...
# Saved diseased GEP projections: 6112 cells, 11 GEPs
# Saving h5ad file...
# adata intact: 8089 cells, 12878 genes
# ATTENTION: Dropping 0 cells with NaN covariates: []
# ... storing 'ct_for_deg' as categorical
# ~ condition + age_of_death + sex + pct_counts_mt + frac_intronic + cohort + GEP_1 + GEP_2 + GEP_3 + GEP_4 + GEP_5 + GEP_6 + GEP_7 + GEP_8 + GEP_9 + GEP_10 + GEP_11 + total_counts
#               variable         VIF
# 0            Intercept  464.954367
# 13               GEP_6    3.433664
# 8                GEP_1    2.827076
# 10               GEP_3    2.700274
# 17              GEP_10    2.477679
# 3   cohort[T.Cohort_2]    2.473131
# 9                GEP_2    2.462106
# 7        frac_intronic    2.357145
# 18              GEP_11    2.343027
# 1     condition[T.XDP]    2.185774
# 4   cohort[T.Cohort_3]    2.144866
# 16               GEP_9    2.097945
# 2             sex[T.M]    2.090622
# 15               GEP_8    1.930366
# 19        total_counts    1.824973
# 5         age_of_death    1.787284
# 12               GEP_5    1.569213
# 11               GEP_4    1.568697
# 14               GEP_7    1.485424
# 6        pct_counts_mt    1.064202
#
# binary identifiability test. False
# ATTENTION: using lmerTest (Gaussian LMM) --> not totally statistically correct (but still robust)
# 		 ZIBR coudl be better
# 2026-04-21 19:28:04 | [WARNING] R callback write-console: condition: factor | example: XDP
#
# 2026-04-21 19:28:04 | [WARNING] R callback write-console: donor_id: character | example: SCF-20-025
#
# 2026-04-21 19:28:04 | [WARNING] R callback write-console: age_of_death: numeric | example: 54
#
# 2026-04-21 19:28:04 | [WARNING] R callback write-console: sex: character | example: M
#
# 2026-04-21 19:28:04 | [WARNING] R callback write-console: pct_counts_mt: numeric | example: 0.162876852324987
#
# 2026-04-21 19:28:04 | [WARNING] R callback write-console: frac_intronic: numeric | example: 0.679666889164362
#
# 2026-04-21 19:28:04 | [WARNING] R callback write-console: cohort: character | example: Cohort_1
#
# 2026-04-21 19:28:04 | [WARNING] R callback write-console: GEP_1: numeric | example: 0.224756625405671
#
# 2026-04-21 19:28:04 | [WARNING] R callback write-console: GEP_2: numeric | example: 0.0392135865215256
#
# 2026-04-21 19:28:04 | [WARNING] R callback write-console: GEP_3: numeric | example: 0
#
# 2026-04-21 19:28:04 | [WARNING] R callback write-console: GEP_4: numeric | example: 0.0991038885941173
#
# 2026-04-21 19:28:04 | [WARNING] R callback write-console: GEP_5: numeric | example: 0.00933880941916101
#
# 2026-04-21 19:28:04 | [WARNING] R callback write-console: GEP_6: numeric | example: 0
#
# 2026-04-21 19:28:04 | [WARNING] R callback write-console: GEP_7: numeric | example: 0
#
# 2026-04-21 19:28:04 | [WARNING] R callback write-console: GEP_8: numeric | example: 0
#
# 2026-04-21 19:28:04 | [WARNING] R callback write-console: GEP_9: numeric | example: 0.064843258453548
#
# 2026-04-21 19:28:04 | [WARNING] R callback write-console: GEP_10: numeric | example: 0
#
# 2026-04-21 19:28:04 | [WARNING] R callback write-console: GEP_11: numeric | example: 0.418678546491884
#
# 2026-04-21 19:28:04 | [WARNING] R callback write-console:
# Fitting: GEP_1 ~ condition + age_of_death + sex + pct_counts_mt + frac_intronic + cohort + GEP_2 + GEP_3 + GEP_4 + GEP_5 + GEP_6 + GEP_7 + GEP_8 + GEP_9 + GEP_10 + GEP_11 + (1|donor_id)
#
# 2026-04-21 19:28:05 | [WARNING] R callback write-console:
# Fitting: GEP_2 ~ condition + age_of_death + sex + pct_counts_mt + frac_intronic + cohort + GEP_1 + GEP_3 + GEP_4 + GEP_5 + GEP_6 + GEP_7 + GEP_8 + GEP_9 + GEP_10 + GEP_11 + (1|donor_id)
#
# 2026-04-21 19:28:05 | [WARNING] R callback write-console:
# Fitting: GEP_3 ~ condition + age_of_death + sex + pct_counts_mt + frac_intronic + cohort + GEP_1 + GEP_2 + GEP_4 + GEP_5 + GEP_6 + GEP_7 + GEP_8 + GEP_9 + GEP_10 + GEP_11 + (1|donor_id)
#
# 2026-04-21 19:28:06 | [WARNING] R callback write-console:
# Fitting: GEP_4 ~ condition + age_of_death + sex + pct_counts_mt + frac_intronic + cohort + GEP_1 + GEP_2 + GEP_3 + GEP_5 + GEP_6 + GEP_7 + GEP_8 + GEP_9 + GEP_10 + GEP_11 + (1|donor_id)
#
# 2026-04-21 19:28:06 | [WARNING] R callback write-console:
# Fitting: GEP_5 ~ condition + age_of_death + sex + pct_counts_mt + frac_intronic + cohort + GEP_1 + GEP_2 + GEP_3 + GEP_4 + GEP_6 + GEP_7 + GEP_8 + GEP_9 + GEP_10 + GEP_11 + (1|donor_id)
#
# 2026-04-21 19:28:07 | [WARNING] R callback write-console:
# Fitting: GEP_6 ~ condition + age_of_death + sex + pct_counts_mt + frac_intronic + cohort + GEP_1 + GEP_2 + GEP_3 + GEP_4 + GEP_5 + GEP_7 + GEP_8 + GEP_9 + GEP_10 + GEP_11 + (1|donor_id)
#
# 2026-04-21 19:28:07 | [WARNING] R callback write-console:
# Fitting: GEP_7 ~ condition + age_of_death + sex + pct_counts_mt + frac_intronic + cohort + GEP_1 + GEP_2 + GEP_3 + GEP_4 + GEP_5 + GEP_6 + GEP_8 + GEP_9 + GEP_10 + GEP_11 + (1|donor_id)
#
# 2026-04-21 19:28:07 | [WARNING] R callback write-console:
# Fitting: GEP_8 ~ condition + age_of_death + sex + pct_counts_mt + frac_intronic + cohort + GEP_1 + GEP_2 + GEP_3 + GEP_4 + GEP_5 + GEP_6 + GEP_7 + GEP_9 + GEP_10 + GEP_11 + (1|donor_id)
#
# 2026-04-21 19:28:07 | [WARNING] R callback write-console:
# Fitting: GEP_9 ~ condition + age_of_death + sex + pct_counts_mt + frac_intronic + cohort + GEP_1 + GEP_2 + GEP_3 + GEP_4 + GEP_5 + GEP_6 + GEP_7 + GEP_8 + GEP_10 + GEP_11 + (1|donor_id)
#
# 2026-04-21 19:28:08 | [WARNING] R callback write-console:
# Fitting: GEP_10 ~ condition + age_of_death + sex + pct_counts_mt + frac_intronic + cohort + GEP_1 + GEP_2 + GEP_3 + GEP_4 + GEP_5 + GEP_6 + GEP_7 + GEP_8 + GEP_9 + GEP_11 + (1|donor_id)
#
# 2026-04-21 19:28:08 | [WARNING] R callback write-console:
# Fitting: GEP_11 ~ condition + age_of_death + sex + pct_counts_mt + frac_intronic + cohort + GEP_1 + GEP_2 + GEP_3 + GEP_4 + GEP_5 + GEP_6 + GEP_7 + GEP_8 + GEP_9 + GEP_10 + (1|donor_id)
# factor     beta       se  p_value      fdr
# GEP_10 0.098146 0.020377 0.000021 0.000235
#  GEP_8 0.060228 0.015796 0.000461 0.002537
#  GEP_9 0.065488 0.020323 0.002500 0.008667
#  GEP_5 0.033998 0.010854 0.003152 0.008667
#  GEP_4 0.022152 0.009326 0.022320 0.048171
#  GEP_6 0.041417 0.017977 0.026275 0.048171
#  GEP_3 0.046538 0.022976 0.049308 0.077484
# GEP_11 0.046749 0.026235 0.082133 0.112933
#  GEP_2 0.032440 0.022621 0.159204 0.194582
#  GEP_7 0.009721 0.013555 0.477263 0.524990
#  GEP_1 0.006494 0.015899 0.685022 0.685022
# Significant GEPs (FDR<0.05): ['GEP_10', 'GEP_8', 'GEP_9', 'GEP_5', 'GEP_4', 'GEP_6']
# Saving qs file...
# 	Saving files for R coversion...
# 2026-04-21 19:28:10 | [WARNING] R callback write-console: Loading required package: SeuratObject
#
# 2026-04-21 19:28:10 | [WARNING] R callback write-console: Loading required package: sp
# 	Building R obj...
# 2026-04-21 19:28:11 | [WARNING] R callback write-console:
# Attaching package: ‘SeuratObject’
#
#
# 2026-04-21 19:28:11 | [WARNING] R callback write-console: The following objects are masked from ‘package:base’:
#
#     %||%, intersect, t
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# 2026-04-21 19:28:13 | [WARNING] R callback write-console:
# Attaching package: ‘Seurat’
#
#
# 2026-04-21 19:28:13 | [WARNING] R callback write-console: The following object is masked from ‘package:base’:
#
#     %||%
#
#
# 2026-04-21 19:28:13 | [WARNING] R callback write-console: qs 0.27.3. Announcement: https://github.com/qsbase/qs/issues/103
# Setting condition reference level to: Control
# Levels: Control XDP
# [1] "Creating Seurat object..."
# 2026-04-21 19:28:29 | [WARNING] R callback write-console: Warning:
# 2026-04-21 19:28:29 | [WARNING] R callback write-console:  Data is of class dgTMatrix. Coercing to dgCMatrix.
# [1] "Saving Seurat object as .qs..."
# Running Nebula...
# cmd list: ['bash', '/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/run-nebula-parallel.sh', '--path', '/home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned.qs', '--id-col', 'donor_id', '--offset-col', 'total_counts', '--n-folds', '40', '--n-cores', '40', '--save-tmp', '0']
# Running command: bash /home/gdallagl/myworkdir/XDP/utils/nebula_scripts/run-nebula-parallel.sh --path /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned.qs --id-col donor_id --offset-col total_counts --n-folds 40 --n-cores 40 --save-tmp 0
# Running command: bash /home/gdallagl/myworkdir/XDP/utils/nebula_scripts/run-nebula-parallel.sh --path /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned.qs --id-col donor_id --offset-col total_counts --n-folds 40 --n-cores 40 --save-tmp 0 --covs condition,age_of_death,sex,pct_counts_mt,frac_intronic,cohort,GEP_10,GEP_8,GEP_9,GEP_5,GEP_4,GEP_6
# ================================================================================
# [INFO] Input: /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned.qs
# [INFO] Script dir: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [INFO] Base name: Striatum_combined_QC_mmc_ct-cured_zoned.qs
# [INFO] Geneset dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1
# [INFO] Geneset: 1
# [INFO] Split dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4
# [INFO] Split: Astrocyte_by_zone_4
# [INFO] n-folds: 40
# [INFO] parallel jobs: 40
# [INFO] id-col: donor_id
# [INFO] covs:
#        - condition
#        - age_of_death
#        - sex
#        - pct_counts_mt
#        - frac_intronic
#        - cohort
#        - GEP_10
#        - GEP_8
#        - GEP_9
#        - GEP_5
#        - GEP_4
#        - GEP_6
# [INFO] offset-col: total_counts  -> will create meta 'nUMI_nebula'
# [INFO] Tmp dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln
# [INFO] Chunks dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks
# [INFO] Tmp de_dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results/
# [INFO] final_dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/de_results/nebula_ln
# [INFO] nebula_out_basename: Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln_combined.qs
# [INFO] Final combined results: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/de_results/nebula_ln/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln_combined.qs
#
# ***** LOADING sobj: /home/gdallagl/myworkdir/XDP/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned.qs
# Splitting 12878 genes into 40 chunks
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_001_of_040.qs (genes 1 --> 322; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_002_of_040.qs (genes 323 --> 644; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_003_of_040.qs (genes 645 --> 966; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_004_of_040.qs (genes 967 --> 1288; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_005_of_040.qs (genes 1289 --> 1610; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_006_of_040.qs (genes 1611 --> 1932; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_007_of_040.qs (genes 1933 --> 2254; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_008_of_040.qs (genes 2255 --> 2576; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_009_of_040.qs (genes 2577 --> 2898; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_010_of_040.qs (genes 2899 --> 3220; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_011_of_040.qs (genes 3221 --> 3542; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_012_of_040.qs (genes 3543 --> 3864; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_013_of_040.qs (genes 3865 --> 4186; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_014_of_040.qs (genes 4187 --> 4508; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_015_of_040.qs (genes 4509 --> 4830; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_016_of_040.qs (genes 4831 --> 5152; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_017_of_040.qs (genes 5153 --> 5474; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_018_of_040.qs (genes 5475 --> 5796; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_019_of_040.qs (genes 5797 --> 6118; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_020_of_040.qs (genes 6119 --> 6440; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_021_of_040.qs (genes 6441 --> 6762; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_022_of_040.qs (genes 6763 --> 7084; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_023_of_040.qs (genes 7085 --> 7406; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_024_of_040.qs (genes 7407 --> 7728; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_025_of_040.qs (genes 7729 --> 8050; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_026_of_040.qs (genes 8051 --> 8372; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_027_of_040.qs (genes 8373 --> 8694; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_028_of_040.qs (genes 8695 --> 9016; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_029_of_040.qs (genes 9017 --> 9338; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_030_of_040.qs (genes 9339 --> 9660; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_031_of_040.qs (genes 9661 --> 9982; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_032_of_040.qs (genes 9983 --> 10304; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_033_of_040.qs (genes 10305 --> 10626; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_034_of_040.qs (genes 10627 --> 10948; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_035_of_040.qs (genes 10949 --> 11270; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_036_of_040.qs (genes 11271 --> 11592; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_037_of_040.qs (genes 11593 --> 11914; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_038_of_040.qs (genes 11915 --> 12236; nGenes=322)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_039_of_040.qs (genes 12237 --> 12557; nGenes=321)
# Wrote /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_040_of_040.qs (genes 12558 --> 12878; nGenes=321)
# ***** SPLITTING DONE.
#
# [INFO] Launching chunk jobs with GNU parallel...
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_033_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_033_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_005_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_005_of_040.qs ****************
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "Extracted 322 genes and 8089 cells"
# [1] "Formula: ~condition+age_of_death+sex+pct_counts_mt+frac_intronic+cohort+GEP_10+GEP_8+GEP_9+GEP_5+GEP_4+GEP_6"
# [1] "Covariate types:"
#     condition  age_of_death           sex pct_counts_mt frac_intronic
#      "factor"     "numeric"   "character"     "numeric"     "numeric"
#        cohort        GEP_10         GEP_8         GEP_9         GEP_5
#   "character"     "numeric"     "numeric"     "numeric"     "numeric"
#         GEP_4         GEP_6
#     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "sexM"
#  [5] "pct_counts_mt"  "frac_intronic"  "cohortCohort_2" "cohortCohort_3"
#  [9] "GEP_10"         "GEP_8"          "GEP_9"          "GEP_5"
# [13] "GEP_4"          "GEP_6"
# [1] "**************** RUNNING NEBULA LN ****************"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_028_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_028_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_013_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_013_of_040.qs ****************
# Remove  0  genes having low expression.
# Analyzing  322  genes with  47  subjects and  8089  cells.
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_040_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_040_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "Extracted 322 genes and 8089 cells"
# [1] "Formula: ~condition+age_of_death+sex+pct_counts_mt+frac_intronic+cohort+GEP_10+GEP_8+GEP_9+GEP_5+GEP_4+GEP_6"
# [1] "Covariate types:"
#     condition  age_of_death           sex pct_counts_mt frac_intronic
#      "factor"     "numeric"   "character"     "numeric"     "numeric"
#        cohort        GEP_10         GEP_8         GEP_9         GEP_5
#   "character"     "numeric"     "numeric"     "numeric"     "numeric"
#         GEP_4         GEP_6
#     "numeric"     "numeric"
# [1] "Design matrix columns:"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "sexM"
#  [5] "pct_counts_mt"  "frac_intronic"  "cohortCohort_2" "cohortCohort_3"
#  [9] "GEP_10"         "GEP_8"          "GEP_9"          "GEP_5"
# [13] "GEP_4"          "GEP_6"
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  322  genes with  47  subjects and  8089  cells.
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "Extracted 322 genes and 8089 cells"
# [1] "Formula: ~condition+age_of_death+sex+pct_counts_mt+frac_intronic+cohort+GEP_10+GEP_8+GEP_9+GEP_5+GEP_4+GEP_6"
# [1] "Covariate types:"
#     condition  age_of_death           sex pct_counts_mt frac_intronic
#      "factor"     "numeric"   "character"     "numeric"     "numeric"
#        cohort        GEP_10         GEP_8         GEP_9         GEP_5
#   "character"     "numeric"     "numeric"     "numeric"     "numeric"
#         GEP_4         GEP_6
#     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "sexM"
#  [5] "pct_counts_mt"  "frac_intronic"  "cohortCohort_2" "cohortCohort_3"
#  [9] "GEP_10"         "GEP_8"          "GEP_9"          "GEP_5"
# [13] "GEP_4"          "GEP_6"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "Extracted 322 genes and 8089 cells"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "Formula: ~condition+age_of_death+sex+pct_counts_mt+frac_intronic+cohort+GEP_10+GEP_8+GEP_9+GEP_5+GEP_4+GEP_6"
# [1] "Covariate types:"
#     condition  age_of_death           sex pct_counts_mt frac_intronic
#      "factor"     "numeric"   "character"     "numeric"     "numeric"
#        cohort        GEP_10         GEP_8         GEP_9         GEP_5
#   "character"     "numeric"     "numeric"     "numeric"     "numeric"
#         GEP_4         GEP_6
#     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "sexM"
#  [5] "pct_counts_mt"  "frac_intronic"  "cohortCohort_2" "cohortCohort_3"
#  [9] "GEP_10"         "GEP_8"          "GEP_9"          "GEP_5"
# [13] "GEP_4"          "GEP_6"
# [1] "**************** RUNNING NEBULA LN ****************"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_009_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_009_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# Remove  0  genes having low expression.
# Analyzing  322  genes with  47  subjects and  8089  cells.
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_034_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_034_of_040.qs ****************
# Remove  0  genes having low expression.
# Analyzing  322  genes with  47  subjects and  8089  cells.
# [1] "Extracted 321 genes and 8089 cells"
# [1] "Formula: ~condition+age_of_death+sex+pct_counts_mt+frac_intronic+cohort+GEP_10+GEP_8+GEP_9+GEP_5+GEP_4+GEP_6"
# [1] "Covariate types:"
#     condition  age_of_death           sex pct_counts_mt frac_intronic
#      "factor"     "numeric"   "character"     "numeric"     "numeric"
#        cohort        GEP_10         GEP_8         GEP_9         GEP_5
#   "character"     "numeric"     "numeric"     "numeric"     "numeric"
#         GEP_4         GEP_6
#     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "sexM"
#  [5] "pct_counts_mt"  "frac_intronic"  "cohortCohort_2" "cohortCohort_3"
#  [9] "GEP_10"         "GEP_8"          "GEP_9"          "GEP_5"
# [13] "GEP_4"          "GEP_6"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# Remove  0  genes having low expression.
# Analyzing  321  genes with  47  subjects and  8089  cells.
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_020_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_020_of_040.qs ****************
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_022_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_022_of_040.qs ****************
# [1] "Extracted 322 genes and 8089 cells"
# [1] "Formula: ~condition+age_of_death+sex+pct_counts_mt+frac_intronic+cohort+GEP_10+GEP_8+GEP_9+GEP_5+GEP_4+GEP_6"
# [1] "Covariate types:"
#     condition  age_of_death           sex pct_counts_mt frac_intronic
#      "factor"     "numeric"   "character"     "numeric"     "numeric"
#        cohort        GEP_10         GEP_8         GEP_9         GEP_5
#   "character"     "numeric"     "numeric"     "numeric"     "numeric"
#         GEP_4         GEP_6
#     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "sexM"
#  [5] "pct_counts_mt"  "frac_intronic"  "cohortCohort_2" "cohortCohort_3"
#  [9] "GEP_10"         "GEP_8"          "GEP_9"          "GEP_5"
# [13] "GEP_4"          "GEP_6"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# Remove  0  genes having low expression.
# Analyzing  322  genes with  47  subjects and  8089  cells.
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_012_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_012_of_040.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_024_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_024_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "Extracted 322 genes and 8089 cells"
# [1] "Formula: ~condition+age_of_death+sex+pct_counts_mt+frac_intronic+cohort+GEP_10+GEP_8+GEP_9+GEP_5+GEP_4+GEP_6"
# [1] "Covariate types:"
#     condition  age_of_death           sex pct_counts_mt frac_intronic
#      "factor"     "numeric"   "character"     "numeric"     "numeric"
#        cohort        GEP_10         GEP_8         GEP_9         GEP_5
#   "character"     "numeric"     "numeric"     "numeric"     "numeric"
#         GEP_4         GEP_6
#     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "sexM"
#  [5] "pct_counts_mt"  "frac_intronic"  "cohortCohort_2" "cohortCohort_3"
#  [9] "GEP_10"         "GEP_8"          "GEP_9"          "GEP_5"
# [13] "GEP_4"          "GEP_6"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# Remove  0  genes having low expression.
# Analyzing  322  genes with  47  subjects and  8089  cells.
# [1] "Extracted 322 genes and 8089 cells"
# [1] "Formula: ~condition+age_of_death+sex+pct_counts_mt+frac_intronic+cohort+GEP_10+GEP_8+GEP_9+GEP_5+GEP_4+GEP_6"
# [1] "Covariate types:"
#     condition  age_of_death           sex pct_counts_mt frac_intronic
#      "factor"     "numeric"   "character"     "numeric"     "numeric"
#        cohort        GEP_10         GEP_8         GEP_9         GEP_5
#   "character"     "numeric"     "numeric"     "numeric"     "numeric"
#         GEP_4         GEP_6
#     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "sexM"
#  [5] "pct_counts_mt"  "frac_intronic"  "cohortCohort_2" "cohortCohort_3"
#  [9] "GEP_10"         "GEP_8"          "GEP_9"          "GEP_5"
# [13] "GEP_4"          "GEP_6"
# [1] "**************** RUNNING NEBULA LN ****************"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_035_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_035_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_001_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_001_of_040.qs ****************
# Remove  0  genes having low expression.
# Analyzing  322  genes with  47  subjects and  8089  cells.
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_039_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_039_of_040.qs ****************
# [1] "Extracted 322 genes and 8089 cells"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "Formula: ~condition+age_of_death+sex+pct_counts_mt+frac_intronic+cohort+GEP_10+GEP_8+GEP_9+GEP_5+GEP_4+GEP_6"
# [1] "Covariate types:"
#     condition  age_of_death           sex pct_counts_mt frac_intronic
#      "factor"     "numeric"   "character"     "numeric"     "numeric"
#        cohort        GEP_10         GEP_8         GEP_9         GEP_5
#   "character"     "numeric"     "numeric"     "numeric"     "numeric"
#         GEP_4         GEP_6
#     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "sexM"
#  [5] "pct_counts_mt"  "frac_intronic"  "cohortCohort_2" "cohortCohort_3"
#  [9] "GEP_10"         "GEP_8"          "GEP_9"          "GEP_5"
# [13] "GEP_4"          "GEP_6"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** RUNNING NEBULA LN ****************"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_031_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_031_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_025_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_025_of_040.qs ****************
# Remove  0  genes having low expression.
# Analyzing  322  genes with  47  subjects and  8089  cells.
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_037_of_040__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/1/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/chunks/chunk_037_of_040.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "Extracted 322 genes and 8089 cells"
# [1] "Formula: ~condition+age_of_death+sex+pct_counts_mt+frac_intronic+cohort+GEP_10+GEP_8+GEP_9+GEP_5+GEP_4+GEP_6"
# [1] "Covariate types:"
#     condition  age_of_death           sex pct_counts_mt frac_intronic
#      "factor"     "numeric"   "character"     "numeric"     "numeric"
#        cohort        GEP_10         GEP_8         GEP_9         GEP_5
#   "character"     "numeric"     "numeric"     "numeric"     "numeric"
#         GEP_4         GEP_6
#     "numeric"     "numeric"
# [1] "Design matrix columns:"
#  [1] "(Intercept)"    "conditionXDP"   "age_of_death"   "sexM"
#  [5] "pct_counts_mt"  "frac_intronic"  "cohortCohort_2" "cohortCohort_3"
#  [9] "GEP_10"         "GEP_8"          "GEP_9"          "GEP_5"
# [13] "GEP_4"          "GEP_6"
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  322  genes with  47  subjects and  8089  cells.
# ...
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  255  genes with  47  subjects and  5592  cells.
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  255  genes with  47  subjects and  5592  cells.
# Remove  0  genes having low expression.
# Analyzing  256  genes with  47  subjects and  5592  cells.
# Remove  0  genes having low expression.
# Analyzing  255  genes with  47  subjects and  5592  cells.
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  255  genes with  47  subjects and  5592  cells.
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  255  genes with  47  subjects and  5592  cells.
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  255  genes with  47  subjects and  5592  cells.
# Remove  0  genes having low expression.
# Analyzing  255  genes with  47  subjects and  5592  cells.
# Remove  0  genes having low expression.
# Analyzing  255  genes with  47  subjects and  5592  cells.
# Remove  0  genes having low expression.
# Analyzing  255  genes with  47  subjects and  5592  cells.
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  255  genes with  47  subjects and  5592  cells.
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  255  genes with  47  subjects and  5592  cells.
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  255  genes with  47  subjects and  5592  cells.
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  256  genes with  47  subjects and  5592  cells.
# Remove  0  genes having low expression.
# Analyzing  255  genes with  47  subjects and  5592  cells.
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  255  genes with  47  subjects and  5592  cells.
# Remove  0  genes having low expression.
# Analyzing  255  genes with  47  subjects and  5592  cells.
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  256  genes with  47  subjects and  5592  cells.
# Remove  0  genes having low expression.
# Analyzing  255  genes with  47  subjects and  5592  cells.
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  0  genes having low expression.
# Analyzing  256  genes with  47  subjects and  5592  cells.
# Remove  0  genes having low expression.
# Analyzing  255  genes with  47  subjects and  5592  cells.
# Remove  0  genes having low expression.
# Analyzing  255  genes with  47  subjects and  5592  cells.
# Remove  0  genes having low expression.
# Analyzing  255  genes with  47  subjects and  5592  cells.
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_023_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_019_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_017_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_027_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_040_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_024_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_025_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_007_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_012_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_032_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_035_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_018_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_031_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_003_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_033_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_036_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_029_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_005_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_001_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_038_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_039_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_030_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_026_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_037_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_016_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_020_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_034_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_015_of_040__nebula_ln.qs ****************
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_013_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_014_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_004_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_021_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_008_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_022_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_028_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_011_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_009_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_010_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_006_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln/de_results//chunk_002_of_040__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# [INFO] All chunk jobs completed.
#
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# ***** Combined NEBULA results written to: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/de_results/nebula_ln/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln_combined.qs
# [INFO] Final combined results: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/de_results/nebula_ln/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln_combined.qs
# [INFO] Removing tmp dir: /home/gdallagl/myworkdir/data/XDP/NucSec/DEG/Striatum/cNMF_nebula/Astrocyte_by_zone_4/4/Striatum_combined_QC_mmc_ct-cured_zoned__nebula_ln
# [ALL DONE]
# ================================================================================
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# #

# %% [markdown]
# # ---
