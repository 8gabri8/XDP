# %% [markdown]
# # Hyperparameters

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
from scipy import sparse
import scanpy as sc
import matplotlib.pyplot as plt
import os
import rpy2.robjects as ro

from dotenv import load_dotenv; load_dotenv()


from utils import preprocessing
from utils import DEG

# ATTENTION: need for perpty of running jupternotbook
# %matplotlib inline

PARALLEL_NEBULA_SCRIPT_PATH = os.getenv("PARALLEL_NEBULA_SCRIPT")

GENESET="004"
DATASET_FOLDER = f"/home/gdallagl/myworkdir/XDP/data/XDP/artificial_bican/geneset_{GENESET}/depleted_versions"
TRUE_DEG_PATH = f"{DATASET_FOLDER}/../initial_perturbed/genes.csv"
QS_TMP_FOLDER = "/home/gdallagl/myworkdir/XDP/data/_old/nebula_tmp" # tmp folder where to save intemrediate results
METHOD_NAME = "gradient_score_nebula"

# name of cell tyoe vauble annotaton to use in this analsys
CT_FOR_DEG_VARIABLE = "spn_type" #"Group_name",  "spn_type"
# name of Sample varibale
SAMPLE_VARIABLE = "donor_id"
# variable to test if differtially epxressed
CONTRAST_VARIABLE = "case_control"
# Level of contrat varibale to use as baseline
CONTRAST_BASELINE = "control"
# Level of contrat varibale to use as stimulated
CONTRAST_STIM = "case"

# Covariates to use for stat test
COVARIATES_FOR_DEG = ["Age.at.Death", "Sex", "PMI", "pct_mt", "pct_intronic",
                      "gradient_score" # SPECIFIC FOR THIS ANALYSIS
                      ]
# libraru size col for  enbula
LIBRARY_SIZE_COL = "nCount_RNA"

# mitluple etst correction pvalue thr
ALPHA_MULTIPLE_TEST = 0.05
LOGFC_THR=0.1
PVAL_THR=0.05

# %% [markdown]
# # Create Covs and update .qs File
#
# Each method will add its covaritates in .qs obj (needed for Nebula).

# %%
for dataset in sorted(os.listdir(DATASET_FOLDER)):

    print(f"\n######\n Processing dataset: {dataset} \n######\n")

    results_folder = os.path.join(DATASET_FOLDER, dataset, METHOD_NAME)
    dataset_path_h5ad = os.path.join(DATASET_FOLDER, f"{dataset}.h5ad")
    dataset_path_qs = os.path.join(DATASET_FOLDER, f"{dataset}.qs")
    cov_df_csv_path = os.path.join(results_folder, "covariates_df.csv")
    os.makedirs(results_folder, exist_ok=True)

    ###################

    # Logic to calcualte specific Covs --> df with covariates (cov_df_csv_path)


    ##################

    # Update obs of .qs obj
    # add_metadata_to_qs(
    #     base_qs_path=dataset_path_qs,
    #     new_metadata_df=pd.read_csv(cov_df_csv_path),
    #     barcode_col="barcode",
    # )

    #break
# Out:
# ######
#  Processing dataset: depleted_0.00_dorsal_matrix
# ######
#
#
# ######
#  Processing dataset: depleted_0.10_dorsal_matrix
# ######
#
#
# ######
#  Processing dataset: depleted_0.20_dorsal_matrix
# ######
#
#
# ######
#  Processing dataset: depleted_0.30_dorsal_matrix
# ######
#
#
# ######
#  Processing dataset: depleted_0.40_dorsal_matrix
# ######
#
#
# ######
#  Processing dataset: depleted_0.50_dorsal_matrix
# ######
#
#
# ######
#  Processing dataset: depleted_0.60_dorsal_matrix
# ######
#
#
# ######
#  Processing dataset: depleted_0.70_dorsal_matrix
# ######
#
#
# ######
#  Processing dataset: depleted_0.80_dorsal_matrix
# ######

# %% [markdown]
# # DEG

# %%
for dataset in sorted(os.listdir(DATASET_FOLDER), reverse=True):

    #dataset="depleted_0.40_dorsal_matrix"


    print(f"\n######\n Processing dataset: {dataset} \n######\n")

    results_folder = os.path.join(DATASET_FOLDER, dataset, METHOD_NAME)
    dataset_path_qs = os.path.join(DATASET_FOLDER, dataset, f"{dataset}.qs")
    save_csv_path = os.path.join(results_folder, f"{dataset}-{METHOD_NAME}_results.csv")
    print(save_csv_path)

    if os.path.exists(save_csv_path):
        continue

    # Run Nebula
    nebula_result_path = DEG.run_nebula_parallel_script(
        path_qs = dataset_path_qs,
        path_nebula_script = PARALLEL_NEBULA_SCRIPT_PATH,
        id_col = SAMPLE_VARIABLE,
        covs = [CONTRAST_VARIABLE, *COVARIATES_FOR_DEG], # wihtout LIBRARY_SIZE_COL, with constrst vaibale too
        offset_col = LIBRARY_SIZE_COL,
        n_folds = 30, # (MORE gene chunks = LESS RAM per chunk)
        n_cores = 25, # (FEWER parallel jobs = LESS total RAM)
        save_tmp = False,
        suffix = None,
    )

    # save csv
    ro.r(f'''
        library(qs)
        obj <- qread("{nebula_result_path}")
        df <- obj$summary
        write.csv(df, "{save_csv_path}", row.names = FALSE)
    ''')

    #break
# Out:
# ######
#  Processing dataset: depleted_0.80_dorsal_matrix
# ######
#
# /home/gdallagl/myworkdir/XDP/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.80_dorsal_matrix/gradient_score_nebula/depleted_0.80_dorsal_matrix-gradient_score_nebula_results.csv
#
# ######
#  Processing dataset: depleted_0.70_dorsal_matrix
# ######
#
# /home/gdallagl/myworkdir/XDP/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.70_dorsal_matrix/gradient_score_nebula/depleted_0.70_dorsal_matrix-gradient_score_nebula_results.csv
#
# ######
#  Processing dataset: depleted_0.60_dorsal_matrix
# ######
#
# /home/gdallagl/myworkdir/XDP/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.60_dorsal_matrix/gradient_score_nebula/depleted_0.60_dorsal_matrix-gradient_score_nebula_results.csv
#
# ######
#  Processing dataset: depleted_0.50_dorsal_matrix
# ######
#
# /home/gdallagl/myworkdir/XDP/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.50_dorsal_matrix/gradient_score_nebula/depleted_0.50_dorsal_matrix-gradient_score_nebula_results.csv
#
# ######
#  Processing dataset: depleted_0.40_dorsal_matrix
# ######
#
# /home/gdallagl/myworkdir/XDP/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/gradient_score_nebula/depleted_0.40_dorsal_matrix-gradient_score_nebula_results.csv
# Running command: bash /home/gdallagl/myworkdir/XDP/utils/nebula_scripts/run-nebula-parallel.sh --path /home/gdallagl/myworkdir/XDP/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix.qs --id-col donor_id --offset-col nCount_RNA --n-folds 30 --n-cores 25 --save-tmp 0 --covs case_control,Age.at.Death,Sex,PMI,pct_mt,pct_intronic,gradient_score
# ================================================================================
# [INFO] Input: /home/gdallagl/myworkdir/XDP/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix.qs
# [INFO] Script dir: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [INFO] Base name: depleted_0.40_dorsal_matrix.qs
# [INFO] Geneset dir: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix
# [INFO] Geneset: depleted_0.40_dorsal_matrix
# [INFO] Split dir: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions
# [INFO] Split: depleted_versions
# [INFO] n-folds: 30
# [INFO] parallel jobs: 25
# [INFO] id-col: donor_id
# [INFO] covs:
#        - case_control
#        - Age.at.Death
#        - Sex
#        - PMI
#        - pct_mt
#        - pct_intronic
#        - gradient_score
# [INFO] offset-col: nCount_RNA  -> will create meta 'nUMI_nebula'
# [INFO] Tmp dir: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln
# [INFO] Chunks dir: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks
# [INFO] Tmp de_dir: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results/
# [INFO] final_dir: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/de_results/nebula_ln
# [INFO] nebula_out_basename: depleted_0.40_dorsal_matrix__nebula_ln_combined.qs
# [INFO] Final combined results: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/de_results/nebula_ln/depleted_0.40_dorsal_matrix__nebula_ln_combined.qs
# ***** LOADING sobj: /home/gdallagl/myworkdir/XDP/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix.qs
# Splitting 37905 genes into 30 chunks
# Skipping /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_001_of_030.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_002_of_030.qs (already exists)
# Skipping /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_003_of_030.qs (already exists)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_004_of_030.qs (genes 3793 --> 5056; nGenes=1264)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_005_of_030.qs (genes 5057 --> 6320; nGenes=1264)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_006_of_030.qs (genes 6321 --> 7584; nGenes=1264)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_007_of_030.qs (genes 7585 --> 8848; nGenes=1264)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_008_of_030.qs (genes 8849 --> 10112; nGenes=1264)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_009_of_030.qs (genes 10113 --> 11376; nGenes=1264)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_010_of_030.qs (genes 11377 --> 12640; nGenes=1264)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_011_of_030.qs (genes 12641 --> 13904; nGenes=1264)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_012_of_030.qs (genes 13905 --> 15168; nGenes=1264)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_013_of_030.qs (genes 15169 --> 16432; nGenes=1264)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_014_of_030.qs (genes 16433 --> 17696; nGenes=1264)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_015_of_030.qs (genes 17697 --> 18960; nGenes=1264)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_016_of_030.qs (genes 18961 --> 20223; nGenes=1263)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_017_of_030.qs (genes 20224 --> 21486; nGenes=1263)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_018_of_030.qs (genes 21487 --> 22749; nGenes=1263)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_019_of_030.qs (genes 22750 --> 24012; nGenes=1263)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_020_of_030.qs (genes 24013 --> 25275; nGenes=1263)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_021_of_030.qs (genes 25276 --> 26538; nGenes=1263)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_022_of_030.qs (genes 26539 --> 27801; nGenes=1263)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_023_of_030.qs (genes 27802 --> 29064; nGenes=1263)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_024_of_030.qs (genes 29065 --> 30327; nGenes=1263)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_025_of_030.qs (genes 30328 --> 31590; nGenes=1263)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_026_of_030.qs (genes 31591 --> 32853; nGenes=1263)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_027_of_030.qs (genes 32854 --> 34116; nGenes=1263)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_028_of_030.qs (genes 34117 --> 35379; nGenes=1263)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_029_of_030.qs (genes 35380 --> 36642; nGenes=1263)
# Wrote /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_030_of_030.qs (genes 36643 --> 37905; nGenes=1263)
# ***** SPLITTING DONE.
#
# [INFO] Launching chunk jobs with GNU parallel...
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_015_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_015_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_010_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_010_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_016_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_016_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_018_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_018_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_014_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_014_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_017_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_017_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_023_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_023_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_012_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_012_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_001_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_001_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_003_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_003_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_020_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_020_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_019_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_019_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_005_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_005_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_022_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_022_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_013_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_013_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_029_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_029_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_021_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_021_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_002_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_002_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_008_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_008_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_009_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_009_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_025_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_025_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_027_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_027_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_026_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_026_of_030.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "Extracted 1264 genes and 99188 cells"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "Extracted 1264 genes and 99188 cells"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "Extracted 1264 genes and 99188 cells"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "Extracted 1264 genes and 99188 cells"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "Extracted 1264 genes and 99188 cells"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "Extracted 1264 genes and 99188 cells"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "Extracted 1263 genes and 99188 cells"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  499  genes having low expression.
# Analyzing  765  genes with  19  subjects and  99188  cells.
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "Extracted 1263 genes and 99188 cells"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# Remove  466  genes having low expression.
# Analyzing  798  genes with  19  subjects and  99188  cells.
# [1] "Extracted 1263 genes and 99188 cells"
# Remove  527  genes having low expression.
# Analyzing  737  genes with  19  subjects and  99188  cells.
# [1] "Extracted 1263 genes and 99188 cells"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "Extracted 1264 genes and 99188 cells"
# [1] "Extracted 1264 genes and 99188 cells"
# [1] "Extracted 1263 genes and 99188 cells"
# Remove  550  genes having low expression.
# Analyzing  714  genes with  19  subjects and  99188  cells.
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "Extracted 1263 genes and 99188 cells"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "Extracted 1263 genes and 99188 cells"
# [1] "Extracted 1264 genes and 99188 cells"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "Extracted 1263 genes and 99188 cells"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "Extracted 1263 genes and 99188 cells"
# Remove  484  genes having low expression.
# Analyzing  780  genes with  19  subjects and  99188  cells.
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "Extracted 1264 genes and 99188 cells"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "Extracted 1264 genes and 99188 cells"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# Remove  447  genes having low expression.
# Analyzing  817  genes with  19  subjects and  99188  cells.
# [1] "Extracted 1263 genes and 99188 cells"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "Extracted 1263 genes and 99188 cells"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# Remove  474  genes having low expression.
# Analyzing  789  genes with  19  subjects and  99188  cells.
# [1] "Extracted 1263 genes and 99188 cells"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_011_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_011_of_030.qs ****************
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/de_results//chunk_004_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.40_dorsal_matrix/depleted_0.40_dorsal_matrix__nebula_ln/chunks/chunk_004_of_030.qs ****************
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# Remove  333  genes having low expression.
# Analyzing  931  genes with  19  subjects and  99188  cells.
# Remove  369  genes having low expression.
# Analyzing  894  genes with  19  subjects and  99188  cells.
# Remove  241  genes having low expression.
# Analyzing  1022  genes with  19  subjects and  99188  cells.
# Remove  310  genes having low expression.
# Analyzing  953  genes with  19  subjects and  99188  cells.
# Remove  227  genes having low expression.
# Analyzing  1036  genes with  19  subjects and  99188  cells.
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# Remove  250  genes having low expression.
# Analyzing  1014  genes with  19  subjects and  99188  cells.
# Remove  252  genes having low expression.
# Analyzing  1011  genes with  19  subjects and  99188  cells.
# Remove  277  genes having low expression.
# Analyzing  986  genes with  19  subjects and  99188  cells.
# Remove  137  genes having low expression.
# Analyzing  1126  genes with  19  subjects and  99188  cells.
# Remove  133  genes having low expression.
# Analyzing  1131  genes with  19  subjects and  99188  cells.
# Remove  175  genes having low expression.
# Analyzing  1089  genes with  19  subjects and  99188  cells.
# [1] "Extracted 1264 genes and 99188 cells"
# Remove  181  genes having low expression.
# Analyzing  1082  genes with  19  subjects and  99188  cells.
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# Remove  143  genes having low expression.
# Analyzing  1121  genes with  19  subjects and  99188  cells.
# Remove  142  genes having low expression.
# Analyzing  1121  genes with  19  subjects and  99188  cells.
# Remove  153  genes having low expression.
# Analyzing  1110  genes with  19  subjects and  99188  cells.
# Remove  158  genes having low expression.
# Analyzing  1105  genes with  19  subjects and  99188  cells.
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  472  genes having low expression.
# Analyzing  792  genes with  19  subjects and  99188  cells.
# [1] "Extracted 1264 genes and 99188 cells"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  166  genes having low expression.
# ...
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "Extracted 1263 genes and 121633 cells"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# Warning message:
# In asMethod(object) :
#   sparse->dense coercion: allocating vector of size 1.1 GiB
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_028_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/chunks/chunk_028_of_030.qs ****************
# [1] "**************** RUNNING NEBULA LN ****************"
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# Remove  139  genes having low expression.
# Analyzing  1124  genes with  19  subjects and  121633  cells.
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# [1] "Extracted 1263 genes and 121633 cells"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# Warning message:
# In asMethod(object) :
#   sparse->dense coercion: allocating vector of size 1.1 GiB
# [1] "**************** RUNNING NEBULA LN ****************"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_007_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/chunks/chunk_007_of_030.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# Remove  216  genes having low expression.
# Analyzing  1047  genes with  19  subjects and  121633  cells.
# [1] "Extracted 1264 genes and 121633 cells"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# Warning message:
# In asMethod(object) :
#   sparse->dense coercion: allocating vector of size 1.1 GiB
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  544  genes having low expression.
# Analyzing  720  genes with  19  subjects and  121633  cells.
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_014_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_030_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/chunks/chunk_030_of_030.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_013_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# [1] "Extracted 1263 genes and 121633 cells"
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# Warning message:
# In asMethod(object) :
#   sparse->dense coercion: allocating vector of size 1.1 GiB
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  1261  genes having low expression.
# Analyzing  2  genes with  19  subjects and  121633  cells.
# [1] "/home/gdallagl/myworkdir/XDP/utils/nebula_scripts/utils.R"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_030_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_012_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** OUTPUT FILE: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_006_of_030__nebula_ln.qs ****************
# **************** LOADING DATA FROM /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/chunks/chunk_006_of_030.qs ****************
# [1] "**************** PREPARING DATA FOR NEBULA ****************"
# [1] "Extracting count data manually (Seurat v5 compatible)"
# [1] "Extracted 1264 genes and 121633 cells"
# Warning message:
# In asMethod(object) :
#   sparse->dense coercion: allocating vector of size 1.1 GiB
# [1] "Formula: ~case_control+Age.at.Death+Sex+PMI+pct_mt+pct_intronic+gradient_score"
# [1] "Covariate types:"
#   case_control   Age.at.Death            Sex            PMI         pct_mt
#       "factor"      "integer"    "character"      "integer"      "numeric"
#   pct_intronic gradient_score
#      "numeric"      "numeric"
# [1] "Design matrix columns:"
# [1] "(Intercept)"      "case_controlcase" "Age.at.Death"     "SexMale"
# [5] "PMI"              "pct_mt"           "pct_intronic"     "gradient_score"
# [1] "**************** RUNNING NEBULA LN ****************"
# Remove  581  genes having low expression.
# Analyzing  683  genes with  19  subjects and  121633  cells.
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_008_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_019_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_018_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_005_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_022_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_015_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_017_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_016_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_020_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_003_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_027_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_007_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_006_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_025_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_004_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_002_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_026_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_001_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_021_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_023_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_029_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_028_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# **************** SAVING RESULTS to /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln/de_results//chunk_024_of_030__nebula_ln.qs ****************
# [1] "**************** ALL DONE ****************"
# [INFO] All chunk jobs completed.
#
# [1] "**************** LOADING LIBRARIES ****************"
# Script located in directory: /home/gdallagl/myworkdir/XDP/utils/nebula_scripts
# ***** Combined NEBULA results written to: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/de_results/nebula_ln/depleted_0.00_dorsal_matrix__nebula_ln_combined.qs
# [INFO] Final combined results: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/de_results/nebula_ln/depleted_0.00_dorsal_matrix__nebula_ln_combined.qs
# [INFO] Removing tmp dir: /home/gdallagl/myworkdir/data/XDP/artificial_bican/geneset_004/depleted_versions/depleted_0.00_dorsal_matrix/depleted_0.00_dorsal_matrix__nebula_ln
# [ALL DONE]
# ================================================================================

# %% [markdown]
# # Plot Results

# %%
df_true_degs = pd.read_csv(TRUE_DEG_PATH)
df_true_degs
# Out:
#              gene_id    log2fc  frac_applied  n_subjects_applied  \
# 0              RAB29  1.788889           0.7                   7
# 1             SHCBP1 -0.944444           0.7                   7
# 2             INO80C  1.155556           0.7                   7
# 3    ENSG00000234185  0.522222           0.3                   3
# 4               PPIH -1.155556           0.4                   4
# ..               ...       ...           ...                 ...
# 395          ZNF780A -0.944444           0.6                   6
# 396             NBEA -0.944444           0.8                   8
# 397      EPB41L1-AS1  0.733333           0.4                   4
# 398            TCTE1 -1.788889           1.0                  10
# 399             RBM4  0.311111           0.1                   1
#
#                                       subjects_applied
# 0    MD6927,MD9129,MS706984,MS876075,MS986638,UMBEB...
# 1    MD9129,MS30499,MS706984,MS876075,MS986638,UMBE...
# 2    MD6927,MD9129,MS30499,MS986638,UMBEB22074,UMBE...
# 3                             MD9129,MS706984,MS876075
# 4              MS706984,MS986638,UMBEB23158,UMBEB24013
# ..                                                 ...
# 395  MS30499,MS706984,UMBEB22074,UMBEB23076,UMBEB23...
# 396  MD6927,MD9129,MS30499,MS876075,MS986638,UMBEB2...
# 397            MD9129,UMBEB23076,UMBEB23158,UMBEB24013
# 398  MD6927,MD9129,MS30499,MS706984,MS876075,MS9866...
# 399                                         UMBEB23076
#
# [400 rows x 5 columns]

# %%
for dataset in sorted(os.listdir(DATASET_FOLDER)):

    print(f"\n######\n Processing dataset: {dataset} \n######\n")

    results_folder = os.path.join(DATASET_FOLDER, dataset, METHOD_NAME)
    save_csv_path = os.path.join(results_folder, f"{dataset}-{METHOD_NAME}_results.csv")

    df_nebula = pd.read_csv(save_csv_path)

    DEG.plot_nebula_results(df_nebula, 
                    df_true_degs, 
                    col_p=f"p_{CONTRAST_VARIABLE}{CONTRAST_STIM}", 
                    col_logFC=f"logFC_{CONTRAST_VARIABLE}{CONTRAST_STIM}", 
                    col_gene="gene",
                    PVAL_THR=PVAL_THR,
                    LOGFC_THR=LOGFC_THR,
                    max_FDR=10,
                    add_adj_p_col=True
                    )
    break
# Out:
# ######
#  Processing dataset: depleted_0.00_dorsal_matrix
# ######
# Precision: 0.683
# Recall:    0.242
# F1 Score:  0.358
# Accuracy:  0.987
# Clipping 24 genes with -log10(p) > 10
#                   gene  logFC_case_controlcase  p_case_controlcase  \
# 0                 A1BG               -0.113721            0.011790
# 1             A1BG-AS1               -0.025827            0.633348
# 2                 A1CF               -0.238748            0.007326
# 3                  A2M                0.271460            0.083669
# 4              A2M-AS1                0.046509            0.437802
# ...                ...                     ...                 ...
# 27475            ZZEF1               -0.022206            0.414542
# 27476             ZZZ3                0.046481            0.405155
# 27477  ENSG00000205653                0.451566            0.501272
# 27478  ENSG00000223438                0.023911            0.972119
# 27479        NOTCH2NLR                0.780382            0.258492
#
#        adj_p_case_controlcase  is_significant  is_true_DEG   -log10p category  \
# 0                    0.479980           False        False  0.318777       TN
# 1                    0.948777           False        False  0.022836       TN
# 2                    0.410365           False        False  0.386830       TN
# 3                    0.810938           False        False  0.091012       TN
# 4                    0.918970           False        False  0.036699       TN
# ...                       ...             ...          ...       ...      ...
# 27475                0.918970           False        False  0.036699       TN
# 27476                0.917626           False        False  0.037334       TN
# 27477                0.930773           False        False  0.031156       TN
# 27478                0.995559           False        False  0.001933       TN
# 27479                0.898800           False        False  0.046337       TN
#
#          sorter
# 0     -0.036252
# 1     -0.000590
# 2     -0.092355
# 3      0.024706
# 4      0.001707
# ...         ...
# 27475 -0.000815
# 27476  0.001735
# 27477  0.014069
# 27478  0.000046
# 27479  0.036161
#
# [27480 rows x 9 columns]
