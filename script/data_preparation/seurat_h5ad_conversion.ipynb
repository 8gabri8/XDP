# %%
# %load_ext autoreload
# %autoreload 2

import scanpy as sc
import os

from utils import preprocessing
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # From Seurat to h5ad

# %%
PATH_BASE  = "/home/gdallagl/myworkdir/XDP/data/_old/files_for_conversion" #same temp folder idea (created automatically)
QS_PATH    = "/home/gdallagl/myworkdir/XDP/data/STR_zonation_references_h5ad/_old/Astrocyte_4_zones.qs" # to covert
H5AD_PATH  = f"{os.path.splitext(QS_PATH)[0]}.h5ad" #here you want the output .h5ad saved

preprocessing.read_qs_save_files(QS_PATH, PATH_BASE)
adata = preprocessing.build_h5ad_from_files(PATH_BASE, H5AD_PATH)
# Out:
# Seurat version: 5.4.0
# Detected Seurat v5 assay
# /home/gdallagl/myworkdir/XDP/utils/preprocessing.py:135: DtypeWarning: Columns (52,65) have mixed types. Specify dtype option on import or set low_memory=False.
#   metadata = pd.read_csv(f"{PATH_BASE}/metadata.csv", index_col=0)

# %% [markdown]
# # From h5ad to Seurat

# %%
PATH_BASE   = "/tmp/conversion/" #a temp folder where intermediate files are saved (created automatically)
ADATA_PATH  = "/path/to/input.h5ad" # adata to cinvert
QS_PATH     = "/path/to/output.qs" # where you want the output .qs Seurat object saved

adata = sc.read_h5ad(ADATA_PATH)
preprocessing.save_files_for_R_conversion(adata, PATH_BASE)
preprocessing.build_qs_from_python_files(PATH_BASE, QS_PATH)

# %% [markdown]
# # ...
