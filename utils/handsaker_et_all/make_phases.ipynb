# %%
import pandas as pd

df = pd.read_excel("HD_phaseGenes.xlsx", sheet_name="Table S2 - Phase C,D Gene Stats", header=26)
print(df.Phase.value_counts())
df
# Out:
# Phase
# D     719
# C+    327
# C-    220
# Name: count, dtype: int64
#                  Gene Phase C p-value Phase C effect  Phase C fold-change  \
# 0                A1BG           0.506      -0.000587                0.916
# 1            A1BG-AS1           0.967       0.000017                1.002
# 2                A1CF           0.122      -0.002294                0.709
# 3                 A2M             0.0       0.003404                1.666
# 4             A2M-AS1         0.00646       0.002407                1.435
# ...               ...             ...            ...                  ...
# 37726  hsa-mir-550a-2              NA             NA                  NaN
# 37727           snoR1          0.0374      -0.012096                0.163
# 37728         snoU83B              NA             NA                  NaN
# 37729         snoZ196              NA             NA                  NaN
# 37730         snoZ278              NA             NA                  NaN
#
# ...

# %%
# phase D
phase_d = df[df["Phase"] == "D"]
display(phase_d[["Gene", "Phase D p-value", "Phase D effect", "Phase"]])
print(phase_d.Gene.to_list())

phase_d.to_csv("phase_d_genes.csv", index=False)
# Out:
#              Gene Phase D p-value Phase D effect Phase
# 51          ABCA8             0.0        7.37272     D
# 74          ABCC9             0.0       5.523023     D
# 560    AC005165.1             0.0       2.961955     D
# 1017   AC007091.1             0.0       6.530972     D
# 1308   AC008060.1             0.0       6.244598     D
# ...           ...             ...            ...   ...
# 37072        ZIC4             0.0       6.540266     D
# 37302      ZNF423             0.0       3.413034     D
# 37384      ZNF536             0.0       5.421753     D
# 37450      ZNF608             0.0         2.5012     D
# 37701      ZSCAN9             0.0        4.37378     D
#
# [719 rows x 4 columns]
# ...

# %%
# phase c+
phase_c = df[df["Phase"] == "C+"]
display(phase_c[["Gene", "Phase C p-value", "Phase C effect", "Phase"]])
print(phase_c.Gene.to_list())

phase_c.to_csv("phase_c_plus_genes.csv", index=False)
# Out:
#              Gene Phase C p-value Phase C effect Phase
# 22           AAK1             0.0       0.000716    C+
# 322    AC004158.1             0.0       0.002635    C+
# 552    AC005154.1             0.0       0.001395    C+
# 683    AC005562.1             0.0       0.001377    C+
# 2101   AC010615.4             0.0       0.001315    C+
# ...           ...             ...            ...   ...
# 37350      ZNF493             0.0       0.001048    C+
# 37377      ZNF528             0.0       0.001227    C+
# 37451      ZNF609             0.0       0.000976    C+
# 37473      ZNF638             0.0       0.000802    C+
# 37622      ZNF831             0.0       0.001673    C+
#
# [327 rows x 4 columns]
# ...

# %%
# phase c-
phase_c = df[df["Phase"] == "C-"]
display(phase_c[["Gene", "Phase C p-value", "Phase C effect", "Phase"]])
print(phase_c.Gene.to_list())

phase_c.to_csv("phase_c_minus_genes.csv", index=False)
# Out:
#              Gene Phase C p-value Phase C effect Phase
# 40           ABAT             0.0      -0.001111    C-
# 1445   AC008591.1             0.0      -0.001579    C-
# 4515   AC069437.1             0.0      -0.001738    C-
# 4860   AC079385.1             0.0      -0.002295    C-
# 5229   AC090124.1             0.0      -0.005723    C-
# ...           ...             ...            ...   ...
# 36722       YPEL1             0.0      -0.002457    C-
# 37088       ZMAT4             0.0      -0.001203    C-
# 37620       ZNF83             0.0      -0.003241    C-
# 37661       ZNRF3             0.0      -0.001219    C-
# 37707      ZSWIM6             0.0      -0.001151    C-
#
# [220 rows x 4 columns]
# ...
